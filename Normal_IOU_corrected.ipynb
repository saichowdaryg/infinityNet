# %%
import tensorflow as tf
import numpy as np
import importlib
from train import provider
from train import box_util
# Out:
# /home/vamsi/miniconda2/envs/py36/lib/python2.7/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
reload(box_util)
reload(provider)
# Out:
# <module 'train.provider' from 'train/provider.pyc'>

# %%
NUM_POINT=2048
TRAIN_DATASET = provider.FrustumDataset(npoints=NUM_POINT, split='train',\
                            rotate_to_center=True, random_flip=False, random_shift=False, one_hot=True)

# %%
VAL_DATASET = provider.FrustumDataset(npoints=NUM_POINT, split='val',\
                            rotate_to_center=True, random_flip=False, random_shift=False, one_hot=True)

# %%
point_set,labels,c,d,e,f,g,h,i = TRAIN_DATASET.__getitem__(0)

# %%
labels.shape
# Out:
# (2048,)

# %%
def indices(window_len, stride_len, point_set, labels, corners_gt):
    IOU = []
    start = []
    end = []
    IOU_1 = []
    IOU_2 = []
    corner = []
    j = np.min(point_set,0)[2]
    i = np.min(point_set,0)[2]+window_len
    idtuple=set()
    while i<=np.max(point_set,0)[2]:
            max_ind = np.searchsorted(point_set[:,2], i)
            min_ind = np.searchsorted(point_set[:,2], j)
            if (min_ind,max_ind) not in idtuple and max_ind-min_ind>5:
                #print('fgbd')
                idtuple.add((min_ind,max_ind))
                labels_window = np.zeros_like(point_set[:,0])
                labels_window[min_ind:max_ind] = 1.0
                union = np.sum(np.logical_or(labels, labels_window))
                inter = np.sum(np.logical_and(labels, labels_window))
                if (inter*1.0/union) < 0.3 or (inter*1.0/union) >0.7 :
                    end.append(max_ind)
                    start.append(min_ind)
                    IOU.append(inter*1.0/union)
            j = j+stride_len
            i = j+window_len
    IOU = np.array(IOU)>=0.7
    return np.array(start),np.array(end), np.array(IOU)

# %%
pedc = 0
key = 'train'
count = 0
count_0 = 0
count1 = 0
count2 = 0
count3 = 0
total = 0
m = 0
for m in range(TRAIN_DATASET.__len__()):
    
    point_set,labels,a,b,c,d,e,f,cls = TRAIN_DATASET.__getitem__(m)
    if cls[1]==1 :
        pedc += 1
        print(pedc)
        #print(point_set.shape)
        #print(np.min(point_set[:,2]))
        #print(point_set.shape)
        #point_set = TRAIN_DATASET.get_center_view_point_set(m)
        index = np.argsort(point_set[:,2])
        point_set = point_set[index]
        labels = labels[index]
        
        if key=='train':
            corners_gt = TRAIN_DATASET.get_center_view_box3d(m)
        if key=='val':
            corners_gt = VAL_DATASET.get_center_view_box3d(m)
            
        #print(point_set.shape)
         
        s,e,l = indices(0.85,0.1,point_set,labels, corners_gt)
        
        #inm = np.argmax(l1)
        #print(inm)
        print(l.shape)
        #print(l2[inm])
        #print(c[inm])
        if np.sum(l>=0.7)>0:
            count += 1
        if np.sum(l>=0.85)>0:
            count1 += 1
# Out:
# 1
# (79,)
# 2
# (85,)
# 3
# (82,)
# 4
# (79,)
# 5
# (82,)
# 6
# (22,)
# 7
# (22,)
# 8
# (23,)
# 9
# (23,)
# 10
# (25,)
# 11
# (81,)
# 12
# (76,)
# 13
# (101,)
# 14
# (121,)
# 15
# (116,)
# 16
# (108,)
# 17
# (85,)
# 18
# (74,)
# 19
# (99,)
# 20
# (85,)
# 21
# (20,)
# 22
# (12,)
# 23
# (18,)
# 24
# (17,)
# 25
# (24,)
# 26
# (23,)
# 27
# (31,)
# 28
# (24,)
# 29
# (33,)
# 30
# (24,)
# 31
# (88,)
# 32
# (74,)
# 33
# (87,)
# 34
# (70,)
# 35
# (95,)
# 36
# (53,)
# 37
# (56,)
# 38
# (46,)
# 39
# (62,)
# 40
# (52,)
# 41
# (55,)
# 42
# (78,)
# 43
# (59,)
# 44
# (69,)
# 45
# (46,)
# 46
# (84,)
# 47
# (77,)
# 48
# (108,)
# 49
# (88,)
# 50
# (101,)
# 51
# (163,)
# 52
# (125,)
# 53
# (136,)
# 54
# (121,)
# 55
# (157,)
# 56
# (19,)
# 57
# (25,)
# 58
# (24,)
# 59
# (19,)
# 60
# (25,)
# 61
# (72,)
# 62
# (68,)
# 63
# (71,)
# 64
# (71,)
# 65
# (73,)
# 66
# (95,)
# 67
# (112,)
# 68
# (111,)
# 69
# (102,)
# 70
# (99,)
# 71
# (47,)
# 72
# (44,)
# 73
# (48,)
# 74
# (49,)
# 75
# (39,)
# 76
# (33,)
# 77
# (32,)
# 78
# (29,)
# 79
# (30,)
# 80
# (28,)
# 81
# (94,)
# 82
# (103,)
# 83
# (91,)
# 84
# (104,)
# 85
# (83,)
# 86
# (13,)
# 87
# (19,)
# 88
# (17,)
# 89
# (21,)
# 90
# (16,)
# 91
# (20,)
# 92
# (24,)
# 93
# (26,)
# 94
# (24,)
# 95
# (28,)
# 96
# (125,)
# 97
# (127,)
# 98
# (141,)
# 99
# (129,)
# 100
# (141,)
# 101
# (69,)
# 102
# (90,)
# 103
# (70,)
# 104
# (67,)
# 105
# (58,)
# 106
# (104,)
# 107
# (97,)
# 108
# (97,)
# 109
# (100,)
# 110
# (89,)
# 111
# (90,)
# 112
# (90,)
# 113
# (109,)
# 114
# (87,)
# 115
# (86,)
# 116
# (1,)
# 117
# (6,)
# 118
# (6,)
# 119
# (64,)
# 120
# (56,)
# 121
# (62,)
# 122
# (77,)
# 123
# (86,)
# 124
# (44,)
# 125
# (49,)
# 126
# (51,)
# 127
# (44,)
# 128
# (47,)
# 129
# (53,)
# 130
# (55,)
# 131
# (50,)
# 132
# (51,)
# 133
# (56,)
# 134
# (51,)
# 135
# (59,)
# 136
# (48,)
# 137
# (58,)
# 138
# (59,)
# 139
# (16,)
# 140
# (27,)
# 141
# (15,)
# 142
# (18,)
# 143
# (16,)
# 144
# (69,)
# 145
# (63,)
# 146
# (62,)
# 147
# (63,)
# 148
# (64,)
# 149
# (63,)
# 150
# (72,)
# 151
# (69,)
# 152
# (69,)
# 153
# (64,)
# 154
# (12,)
# 155
# (11,)
# 156
# (4,)
# 157
# (12,)
# 158
# (12,)
# 159
# (18,)
# 160
# (12,)
# 161
# (16,)
# 162
# (22,)
# 163
# (22,)
# 164
# (4,)
# 165
# (7,)
# 166
# (47,)
# 167
# (39,)
# 168
# (53,)
# 169
# (53,)
# 170
# (55,)
# 171
# (55,)
# 172
# (59,)
# 173
# (55,)
# 174
# (57,)
# 175
# (55,)
# 176
# (27,)
# 177
# (24,)
# 178
# (19,)
# 179
# (30,)
# 180
# (27,)
# 181
# (33,)
# 182
# (25,)
# 183
# (28,)
# 184
# (30,)
# 185
# (27,)
# 186
# (29,)
# 187
# (23,)
# 188
# (34,)
# 189
# (42,)
# 190
# (24,)
# 191
# (12,)
# 192
# (12,)
# 193
# (4,)
# 194
# (3,)
# 195
# (3,)
# 196
# (11,)
# 197
# (10,)
# 198
# (13,)
# 199
# (7,)
# 200
# (11,)
# 201
# (11,)
# 202
# (13,)
# 203
# (16,)
# 204
# (17,)
# 205
# (18,)
# 206
# (128,)
# 207
# (134,)
# 208
# (98,)
# 209
# (150,)
# 210
# (88,)
# 211
# (107,)
# 212
# (92,)
# 213
# (126,)
# 214
# (162,)
# 215
# (103,)
# 216
# (19,)
# 217
# (16,)
# 218
# (20,)
# 219
# (19,)
# 220
# (24,)
# 221
# (17,)
# 222
# (18,)
# 223
# (15,)
# 224
# (15,)
# 225
# (17,)
# 226
# (17,)
# 227
# (15,)
# 228
# (17,)
# 229
# (21,)
# 230
# (24,)
# 231
# (33,)
# 232
# (27,)
# 233
# (29,)
# 234
# (29,)
# 235
# (32,)
# 236
# (67,)
# 237
# (57,)
# 238
# (52,)
# 239
# (66,)
# 240
# (61,)
# 241
# (85,)
# 242
# (71,)
# 243
# (72,)
# 244
# (75,)
# 245
# (73,)
# 246
# (21,)
# 247
# (19,)
# 248
# (28,)
# 249
# (24,)
# 250
# (23,)
# 251
# (35,)
# 252
# (46,)
# 253
# (44,)
# 254
# (40,)
# 255
# (32,)
# 256
# (31,)
# 257
# (20,)
# 258
# (33,)
# 259
# (35,)
# 260
# (36,)
# 261
# (78,)
# 262
# (73,)
# 263
# (66,)
# 264
# (81,)
# 265
# (68,)
# 266
# (39,)
# 267
# (33,)
# 268
# (45,)
# 269
# (34,)
# 270
# (42,)
# 271
# (58,)
# 272
# (57,)
# 273
# (61,)
# 274
# (61,)
# 275
# (56,)
# 276
# (26,)
# 277
# (25,)
# 278
# (28,)
# 279
# (21,)
# 280
# (24,)
# 281
# (120,)
# 282
# (111,)
# 283
# (115,)
# 284
# (108,)
# 285
# (105,)
# 286
# (59,)
# 287
# (103,)
# 288
# (39,)
# 289
# (103,)
# 290
# (85,)
# 291
# (40,)
# 292
# (43,)
# 293
# (42,)
# 294
# (38,)
# 295
# (33,)
# 296
# (25,)
# 297
# (28,)
# 298
# (29,)
# 299
# (31,)
# 300
# (32,)
# 301
# (66,)
# 302
# (57,)
# 303
# (71,)
# 304
# (52,)
# 305
# (62,)
# 306
# (66,)
# 307
# (65,)
# 308
# (62,)
# 309
# (65,)
# 310
# (65,)
# 311
# (50,)
# 312
# (47,)
# 313
# (47,)
# 314
# (57,)
# 315
# (55,)
# 316
# (28,)
# 317
# (16,)
# 318
# (31,)
# 319
# (21,)
# 320
# (27,)
# 321
# (18,)
# 322
# (20,)
# 323
# (20,)
# 324
# (28,)
# 325
# (23,)
# 326
# (105,)
# 327
# (69,)
# 328
# (130,)
# 329
# (90,)
# 330
# (127,)
# 331
# (25,)
# 332
# (26,)
# 333
# (29,)
# 334
# (28,)
# 335
# (16,)
# 336
# (15,)
# 337
# (14,)
# 338
# (14,)
# 339
# (15,)
# 340
# (19,)
# 341
# (67,)
# 342
# (63,)
# 343
# (63,)
# 344
# (78,)
# 345
# (72,)
# 346
# (65,)
# 347
# (56,)
# 348
# (66,)
# 349
# (65,)
# 350
# (66,)
# 351
# (56,)
# 352
# (36,)
# 353
# (55,)
# 354
# (38,)
# 355
# (48,)
# 356
# (44,)
# 357
# (41,)
# 358
# (31,)
# 359
# (41,)
# 360
# (34,)
# 361
# (78,)
# 362
# (86,)
# 363
# (95,)
# 364
# (79,)
# 365
# (77,)
# 366
# (62,)
# 367
# (72,)
# 368
# (82,)
# 369
# (80,)
# 370
# (84,)
# 371
# (53,)
# 372
# (55,)
# 373
# (52,)
# 374
# (47,)
# 375
# (50,)
# 376
# (58,)
# 377
# (62,)
# 378
# (56,)
# 379
# (61,)
# 380
# (60,)
# 381
# (58,)
# 382
# (77,)
# 383
# (65,)
# 384
# (65,)
# 385
# (41,)
# 386
# (73,)
# 387
# (68,)
# 388
# (71,)
# 389
# (72,)
# 390
# (79,)
# 391
# (26,)
# 392
# (25,)
# 393
# (19,)
# 394
# (24,)
# 395
# (20,)
# 396
# (97,)
# 397
# (106,)
# 398
# (79,)
# 399
# (85,)
# 400
# (91,)
# 401
# (39,)
# 402
# (34,)
# 403
# (46,)
# 404
# (35,)
# 405
# (33,)
# 406
# (42,)
# 407
# (43,)
# 408
# (46,)
# 409
# (44,)
# 410
# (41,)
# 411
# (27,)
# 412
# (36,)
# 413
# (32,)
# 414
# (28,)
# 415
# (31,)
# 416
# (17,)
# 417
# (17,)
# 418
# (17,)
# 419
# (14,)
# 420
# (18,)
# 421
# (13,)
# 422
# (3,)
# 423
# (10,)
# 424
# (3,)
# 425
# (10,)
# 426
# (46,)
# 427
# (51,)
# 428
# (43,)
# 429
# (53,)
# 430
# (49,)
# 431
# (41,)
# 432
# (38,)
# 433
# (41,)
# 434
# (51,)
# 435
# (44,)
# 436
# (38,)
# 437
# (37,)
# 438
# (43,)
# 439
# (41,)
# 440
# (40,)
# 441
# (46,)
# 442
# (44,)
# 443
# (45,)
# 444
# (45,)
# 445
# (39,)
# 446
# (49,)
# 447
# (35,)
# 448
# (51,)
# 449
# (44,)
# 450
# (47,)
# 451
# (53,)
# 452
# (41,)
# 453
# (48,)
# 454
# (53,)
# 455
# (47,)
# 456
# (37,)
# 457
# (45,)
# 458
# (45,)
# 459
# (21,)
# 460
# (46,)
# 461
# (33,)
# 462
# (39,)
# 463
# (39,)
# 464
# (52,)
# 465
# (37,)
# 466
# (70,)
# 467
# (60,)
# 468
# (60,)
# 469
# (65,)
# 470
# (63,)
# 471
# (18,)
# 472
# (18,)
# 473
# (15,)
# 474
# (16,)
# 475
# (15,)
# 476
# (100,)
# 477
# (89,)
# 478
# (93,)
# 479
# (90,)
# 480
# (95,)
# 481
# (91,)
# 482
# (77,)
# 483
# (91,)
# 484
# (89,)
# 485
# (82,)
# 486
# (24,)
# 487
# (25,)
# 488
# (26,)
# 489
# (23,)
# 490
# (24,)
# 491
# (62,)
# 492
# (63,)
# 493
# (61,)
# 494
# (64,)
# 495
# (62,)
# 496
# (34,)
# 497
# (40,)
# 498
# (43,)
# 499
# (29,)
# 500
# (45,)
# 501
# (55,)
# 502
# (48,)
# 503
# (76,)
# 504
# (76,)
# 505
# (74,)
# 506
# (63,)
# 507
# (63,)
# 508
# (59,)
# 509
# (51,)
# 510
# (42,)
# 511
# (65,)
# 512
# (61,)
# 513
# (65,)
# 514
# (63,)
# 515
# (65,)
# 516
# (25,)
# 517
# (22,)
# 518
# (24,)
# 519
# (24,)
# 520
# (24,)
# 521
# (88,)
# 522
# (91,)
# 523
# (101,)
# 524
# (86,)
# 525
# (51,)
# 526
# (20,)
# 527
# (26,)
# 528
# (21,)
# 529
# (17,)
# 530
# (22,)
# 531
# (148,)
# 532
# (167,)
# 533
# (135,)
# 534
# (145,)
# 535
# (130,)
# 536
# (142,)
# 537
# (143,)
# 538
# (141,)
# 539
# (135,)
# 540
# (122,)
# 541
# (153,)
# 542
# (188,)
# 543
# (166,)
# 544
# (182,)
# 545
# (146,)
# 546
# (72,)
# 547
# (57,)
# 548
# (56,)
# 549
# (52,)
# 550
# (59,)
# 551
# (48,)
# 552
# (46,)
# 553
# (54,)
# 554
# (49,)
# 555
# (38,)
# 556
# (66,)
# 557
# (56,)
# 558
# (81,)
# 559
# (59,)
# 560
# (65,)
# 561
# (83,)
# 562
# (69,)
# 563
# (76,)
# 564
# (71,)
# 565
# (82,)
# 566
# (142,)
# 567
# (148,)
# 568
# (139,)
# 569
# (170,)
# 570
# (159,)
# 571
# (70,)
# 572
# (74,)
# 573
# (75,)
# 574
# (69,)
# 575
# (61,)
# 576
# (98,)
# 577
# (110,)
# 578
# (66,)
# 579
# (74,)
# 580
# (79,)
# 581
# (50,)
# 582
# (48,)
# 583
# (38,)
# 584
# (36,)
# 585
# (40,)
# 586
# (40,)
# 587
# (39,)
# 588
# (42,)
# 589
# (45,)
# 590
# (45,)
# 591
# (70,)
# 592
# (71,)
# 593
# (66,)
# 594
# (77,)
# 595
# (77,)
# 596
# (55,)
# 597
# (40,)
# 598
# (36,)
# 599
# (44,)
# 600
# (36,)
# 601
# (16,)
# 602
# (19,)
# 603
# (24,)
# 604
# (7,)
# 605
# (21,)
# 606
# (23,)
# 607
# (16,)
# 608
# (29,)
# 609
# (24,)
# 610
# (36,)
# 611
# (46,)
# 612
# (56,)
# 613
# (53,)
# 614
# (56,)
# 615
# (57,)
# 616
# (27,)
# 617
# (22,)
# 618
# (25,)
# 619
# (25,)
# 620
# (25,)
# 621
# (56,)
# 622
# (55,)
# 623
# (56,)
# 624
# (60,)
# 625
# (65,)
# 626
# (121,)
# 627
# (106,)
# 628
# (127,)
# 629
# (112,)
# 630
# (105,)
# 631
# (35,)
# 632
# (47,)
# 633
# (50,)
# 634
# (48,)
# 635
# (40,)
# 636
# (42,)
# 637
# (26,)
# 638
# (37,)
# 639
# (33,)
# 640
# (30,)
# 641
# (19,)
# 642
# (19,)
# 643
# (23,)
# 644
# (16,)
# 645
# (20,)
# 646
# (23,)
# 647
# (27,)
# 648
# (27,)
# 649
# (28,)
# 650
# (21,)
# 651
# (149,)
# 652
# (160,)
# 653
# (143,)
# 654
# (149,)
# 655
# (150,)
# 656
# (112,)
# 657
# (105,)
# 658
# (98,)
# 659
# (97,)
# 660
# (115,)
# 661
# (85,)
# 662
# (75,)
# 663
# (64,)
# 664
# (80,)
# 665
# (47,)
# 666
# (57,)
# 667
# (58,)
# 668
# (57,)
# 669
# (60,)
# 670
# (55,)
# 671
# (31,)
# 672
# (30,)
# 673
# (29,)
# 674
# (30,)
# 675
# (30,)
# 676
# (83,)
# 677
# (88,)
# 678
# (96,)
# 679
# (93,)
# 680
# (82,)
# 681
# (34,)
# 682
# (43,)
# 683
# (32,)
# 684
# (50,)
# 685
# (37,)
# 686
# (122,)
# 687
# (153,)
# 688
# (143,)
# 689
# (136,)
# 690
# (144,)
# 691
# (25,)
# 692
# (44,)
# 693
# (31,)
# 694
# (23,)
# 695
# (40,)
# 696
# (12,)
# 697
# (14,)
# 698
# (14,)
# 699
# (16,)
# 700
# (10,)
# 701
# (9,)
# 702
# (8,)
# 703
# (9,)
# 704
# (5,)
# 705
# (7,)
# 706
# (83,)
# 707
# (59,)
# 708
# (65,)
# 709
# (55,)
# 710
# (67,)
# 711
# (117,)
# 712
# (121,)
# 713
# (136,)
# 714
# (118,)
# 715
# (111,)
# 716
# (147,)
# 717
# (130,)
# 718
# (128,)
# 719
# (138,)
# 720
# (129,)
# 721
# (134,)
# 722
# (99,)
# 723
# (133,)
# 724
# (133,)
# 725
# (122,)
# 726
# (85,)
# 727
# (115,)
# 728
# (90,)
# 729
# (80,)
# 730
# (131,)
# 731
# (72,)
# 732
# (71,)
# 733
# (76,)
# 734
# (69,)
# 735
# (72,)
# 736
# (66,)
# 737
# (61,)
# 738
# (66,)
# 739
# (71,)
# 740
# (60,)
# 741
# (42,)
# 742
# (32,)
# 743
# (29,)
# 744
# (31,)
# 745
# (45,)
# 746
# (15,)
# 747
# (16,)
# 748
# (17,)
# 749
# (19,)
# 750
# (13,)
# 751
# (4,)
# 752
# (0,)
# 753
# (4,)
# 754
# (3,)
# 755
# (3,)
# 756
# (72,)
# 757
# (68,)
# 758
# (60,)
# 759
# (61,)
# 760
# (65,)
# 761
# (24,)
# 762
# (22,)
# 763
# (19,)
# 764
# (24,)
# 765
# (24,)
# 766
# (46,)
# 767
# (55,)
# 768
# (72,)
# 769
# (53,)
# 770
# (60,)
# 771
# (35,)
# 772
# (40,)
# 773
# (34,)
# 774
# (34,)
# 775
# (43,)
# 776
# (48,)
# 777
# (78,)
# 778
# (79,)
# 779
# (52,)
# 780
# (67,)
# 781
# (100,)
# 782
# (89,)
# 783
# (90,)
# 784
# (103,)
# 785
# (71,)
# 786
# (131,)
# 787
# (103,)
# 788
# (136,)
# 789
# (104,)
# 790
# (152,)
# 791
# (155,)
# 792
# (178,)
# 793
# (148,)
# 794
# (172,)
# 795
# (179,)
# 796
# (102,)
# 797
# (106,)
# 798
# (109,)
# 799
# (101,)
# 800
# (86,)
# 801
# (125,)
# 802
# (83,)
# 803
# (93,)
# 804
# (172,)
# 805
# (104,)
# 806
# (161,)
# 807
# (128,)
# 808
# (136,)
# 809
# (141,)
# 810
# (163,)
# 811
# (111,)
# 812
# (100,)
# 813
# (106,)
# 814
# (113,)
# 815
# (105,)
# 816
# (68,)
# 817
# (74,)
# 818
# (77,)
# 819
# (59,)
# 820
# (70,)
# 821
# (22,)
# 822
# (19,)
# 823
# (25,)
# 824
# (26,)
# 825
# (18,)
# 826
# (75,)
# 827
# (57,)
# 828
# (67,)
# 829
# (68,)
# 830
# (66,)
# 831
# (39,)
# 832
# (52,)
# 833
# (39,)
# 834
# (33,)
# 835
# (41,)
# 836
# (65,)
# 837
# (57,)
# 838
# (59,)
# 839
# (62,)
# 840
# (60,)
# 841
# (57,)
# 842
# (59,)
# 843
# (59,)
# 844
# (43,)
# 845
# (58,)
# 846
# (78,)
# 847
# (76,)
# 848
# (95,)
# 849
# (65,)
# 850
# (105,)
# 851
# (63,)
# 852
# (69,)
# 853
# (58,)
# 854
# (67,)
# 855
# (57,)
# 856
# (50,)
# 857
# (46,)
# 858
# (52,)
# 859
# (47,)
# 860
# (43,)
# 861
# (21,)
# 862
# (24,)
# 863
# (21,)
# 864
# (24,)
# 865
# (25,)
# 866
# (61,)
# 867
# (57,)
# 868
# (77,)
# 869
# (92,)
# 870
# (68,)
# 871
# (48,)
# 872
# (44,)
# 873
# (48,)
# 874
# (52,)
# 875
# (67,)
# 876
# (73,)
# 877
# (53,)
# 878
# (58,)
# 879
# (50,)
# 880
# (47,)
# 881
# (26,)
# 882
# (20,)
# 883
# (22,)
# 884
# (22,)
# 885
# (24,)
# 886
# (38,)
# 887
# (53,)
# 888
# (53,)
# 889
# (56,)
# 890
# (49,)
# 891
# (97,)
# 892
# (99,)
# 893
# (96,)
# 894
# (94,)
# 895
# (98,)
# 896
# (65,)
# 897
# (70,)
# 898
# (69,)
# 899
# (71,)
# 900
# (72,)
# 901
# (17,)
# 902
# (15,)
# 903
# (17,)
# 904
# (21,)
# 905
# (17,)
# 906
# (26,)
# 907
# (22,)
# 908
# (21,)
# 909
# (25,)
# 910
# (25,)
# 911
# (82,)
# 912
# (86,)
# 913
# (82,)
# 914
# (85,)
# 915
# (83,)
# 916
# (101,)
# 917
# (97,)
# 918
# (101,)
# 919
# (93,)
# 920
# (96,)
# 921
# (115,)
# 922
# (124,)
# 923
# (86,)
# 924
# (133,)
# 925
# (103,)
# 926
# (52,)
# 927
# (59,)
# 928
# (58,)
# 929
# (57,)
# 930
# (60,)
# 931
# (97,)
# 932
# (72,)
# 933
# (86,)
# 934
# (96,)
# 935
# (91,)
# 936
# (59,)
# 937
# (65,)
# 938
# (55,)
# 939
# (52,)
# 940
# (59,)
# 941
# (73,)
# 942
# (78,)
# 943
# (77,)
# 944
# (70,)
# 945
# (73,)
# 946
# (80,)
# 947
# (139,)
# 948
# (103,)
# 949
# (108,)
# 950
# (103,)
# 951
# (7,)
# 952
# (8,)
# 953
# (16,)
# 954
# (16,)
# 955
# (7,)
# 956
# (35,)
# 957
# (38,)
# 958
# (39,)
# 959
# (40,)
# 960
# (39,)
# 961
# (58,)
# 962
# (68,)
# 963
# (59,)
# 964
# (63,)
# 965
# (64,)
# 966
# (50,)
# 967
# (59,)
# 968
# (50,)
# 969
# (56,)
# 970
# (55,)
# 971
# (113,)
# 972
# (112,)
# 973
# (109,)
# 974
# (118,)
# 975
# (106,)
# 976
# (11,)
# 977
# (14,)
# 978
# (12,)
# 979
# (12,)
# 980
# (16,)
# 981
# (7,)
# 982
# (38,)
# 983
# (41,)
# 984
# (52,)
# 985
# (41,)
# 986
# (24,)
# 987
# (56,)
# 988
# (101,)
# 989
# (91,)
# 990
# (91,)
# 991
# (101,)
# 992
# (87,)
# 993
# (75,)
# 994
# (84,)
# 995
# (84,)
# 996
# (88,)
# 997
# (62,)
# 998
# (36,)
# 999
# (46,)
# 1000
# (51,)
# 1001
# (56,)
# 1002
# (78,)
# 1003
# (78,)
# 1004
# (76,)
# 1005
# (74,)
# 1006
# (75,)
# 1007
# (46,)
# 1008
# (52,)
# 1009
# (51,)
# 1010
# (61,)
# 1011
# (55,)
# 1012
# (90,)
# 1013
# (88,)
# 1014
# (81,)
# 1015
# (94,)
# 1016
# (93,)
# 1017
# (30,)
# 1018
# (27,)
# 1019
# (31,)
# 1020
# (29,)
# 1021
# (34,)
# 1022
# (33,)
# 1023
# (36,)
# 1024
# (33,)
# 1025
# (35,)
# 1026
# (36,)
# 1027
# (5,)
# 1028
# (3,)
# 1029
# (4,)
# 1030
# (3,)
# 1031
# (4,)
# 1032
# (29,)
# 1033
# (21,)
# 1034
# (17,)
# 1035
# (29,)
# 1036
# (18,)
# 1037
# (46,)
# 1038
# (54,)
# 1039
# (49,)
# 1040
# (42,)
# 1041
# (47,)
# 1042
# (31,)
# 1043
# (33,)
# 1044
# (37,)
# 1045
# (36,)
# 1046
# (26,)
# 1047
# (101,)
# 1048
# (115,)
# 1049
# (88,)
# 1050
# (136,)
# 1051
# (100,)
# 1052
# (176,)
# 1053
# (199,)
# 1054
# (163,)
# 1055
# (148,)
# 1056
# (185,)
# 1057
# (83,)
# 1058
# (125,)
# 1059
# (105,)
# 1060
# (94,)
# 1061
# (92,)
# 1062
# (127,)
# 1063
# (131,)
# 1064
# (124,)
# 1065
# (112,)
# 1066
# (133,)
# 1067
# (127,)
# 1068
# (146,)
# 1069
# (148,)
# 1070
# (133,)
# 1071
# (128,)
# 1072
# (120,)
# 1073
# (144,)
# 1074
# (137,)
# 1075
# (121,)
# 1076
# (139,)
# 1077
# (142,)
# 1078
# (131,)
# 1079
# (165,)
# 1080
# (159,)
# 1081
# (156,)
# 1082
# (180,)
# 1083
# (162,)
# 1084
# (147,)
# 1085
# (152,)
# 1086
# (167,)
# 1087
# (96,)
# 1088
# (100,)
# 1089
# (87,)
# 1090
# (100,)
# 1091
# (88,)
# 1092
# (126,)
# 1093
# (137,)
# 1094
# (142,)
# 1095
# (143,)
# 1096
# (151,)
# 1097
# (57,)
# 1098
# (50,)
# 1099
# (51,)
# 1100
# (56,)
# 1101
# (45,)
# 1102
# (31,)
# 1103
# (34,)
# 1104
# (24,)
# 1105
# (28,)
# 1106
# (32,)
# 1107
# (30,)
# 1108
# (36,)
# 1109
# (33,)
# 1110
# (30,)
# 1111
# (40,)
# 1112
# (10,)
# 1113
# (10,)
# 1114
# (15,)
# 1115
# (13,)
# 1116
# (21,)
# 1117
# (61,)
# 1118
# (48,)
# 1119
# (46,)
# 1120
# (49,)
# 1121
# (53,)
# 1122
# (32,)
# 1123
# (33,)
# 1124
# (29,)
# 1125
# (34,)
# 1126
# (36,)
# 1127
# (68,)
# 1128
# (70,)
# 1129
# (45,)
# 1130
# (73,)
# 1131
# (43,)
# 1132
# (8,)
# 1133
# (6,)
# 1134
# (6,)
# 1135
# (13,)
# 1136
# (7,)
# 1137
# (18,)
# 1138
# (10,)
# 1139
# (10,)
# 1140
# (11,)
# 1141
# (18,)
# 1142
# (83,)
# 1143
# (77,)
# 1144
# (80,)
# 1145
# (82,)
# 1146
# (79,)
# 1147
# (42,)
# 1148
# (49,)
# 1149
# (36,)
# 1150
# (39,)
# 1151
# (42,)
# 1152
# (31,)
# 1153
# (25,)
# 1154
# (26,)
# 1155
# (24,)
# 1156
# (29,)
# 1157
# (29,)
# 1158
# (29,)
# 1159
# (29,)
# 1160
# (32,)
# 1161
# (28,)
# 1162
# (66,)
# 1163
# (64,)
# 1164
# (67,)
# 1165
# (63,)
# 1166
# (66,)
# 1167
# (26,)
# 1168
# (33,)
# 1169
# (28,)
# 1170
# (31,)
# 1171
# (26,)
# 1172
# (66,)
# 1173
# (58,)
# 1174
# (65,)
# 1175
# (46,)
# 1176
# (49,)
# 1177
# (16,)
# 1178
# (11,)
# 1179
# (22,)
# 1180
# (14,)
# 1181
# (19,)
# 1182
# (45,)
# 1183
# (44,)
# 1184
# (35,)
# 1185
# (64,)
# 1186
# (36,)
# 1187
# (73,)
# 1188
# (70,)
# 1189
# (70,)
# 1190
# (67,)
# 1191
# (71,)
# 1192
# (12,)
# 1193
# (9,)
# 1194
# (18,)
# 1195
# (12,)
# 1196
# (10,)
# 1197
# (15,)
# 1198
# (16,)
# 1199
# (25,)
# 1200
# (27,)
# 1201
# (19,)
# 1202
# (24,)
# 1203
# (19,)
# 1204
# (21,)
# 1205
# (32,)
# 1206
# (32,)
# 1207
# (47,)
# 1208
# (47,)
# 1209
# (44,)
# 1210
# (50,)
# 1211
# (40,)
# 1212
# (36,)
# 1213
# (26,)
# 1214
# (33,)
# 1215
# (35,)
# 1216
# (35,)
# 1217
# (46,)
# 1218
# (40,)
# 1219
# (48,)
# 1220
# (45,)
# 1221
# (43,)
# 1222
# (40,)
# 1223
# (39,)
# 1224
# (28,)
# 1225
# (29,)
# 1226
# (28,)
# 1227
# (33,)
# 1228
# (22,)
# 1229
# (28,)
# 1230
# (25,)
# 1231
# (30,)
# 1232
# (12,)
# 1233
# (14,)
# 1234
# (10,)
# 1235
# (17,)
# 1236
# (13,)
# 1237
# (110,)
# 1238
# (96,)
# 1239
# (84,)
# 1240
# (91,)
# 1241
# (98,)
# 1242
# (30,)
# 1243
# (32,)
# 1244
# (27,)
# 1245
# (30,)
# 1246
# (26,)
# 1247
# (56,)
# 1248
# (55,)
# 1249
# (75,)
# 1250
# (50,)
# 1251
# (68,)
# 1252
# (76,)
# 1253
# (104,)
# 1254
# (74,)
# 1255
# (101,)
# 1256
# (75,)
# 1257
# (61,)
# 1258
# (54,)
# 1259
# (55,)
# 1260
# (54,)
# 1261
# (60,)
# 1262
# (124,)
# 1263
# (149,)
# 1264
# (125,)
# 1265
# (147,)
# 1266
# (149,)
# 1267
# (145,)
# 1268
# (110,)
# 1269
# (131,)
# 1270
# (118,)
# 1271
# (118,)
# 1272
# (15,)
# 1273
# (14,)
# 1274
# (17,)
# 1275
# (12,)
# 1276
# (16,)
# 1277
# (57,)
# 1278
# (59,)
# 1279
# (81,)
# 1280
# (52,)
# 1281
# (59,)
# 1282
# (26,)
# 1283
# (29,)
# 1284
# (28,)
# 1285
# (26,)
# 1286
# (31,)
# 1287
# (43,)
# 1288
# (40,)
# 1289
# (43,)
# 1290
# (47,)
# 1291
# (52,)
# 1292
# (40,)
# 1293
# (28,)
# 1294
# (45,)
# 1295
# (28,)
# 1296
# (43,)
# 1297
# (60,)
# 1298
# (59,)
# 1299
# (49,)
# 1300
# (54,)
# 1301
# (55,)
# 1302
# (26,)
# 1303
# (28,)
# 1304
# (27,)
# 1305
# (25,)
# 1306
# (15,)
# 1307
# (18,)
# 1308
# (34,)
# 1309
# (37,)
# 1310
# (29,)
# 1311
# (18,)
# 1312
# (36,)
# 1313
# (26,)
# 1314
# (35,)
# 1315
# (37,)
# 1316
# (43,)
# 1317
# (39,)
# 1318
# (27,)
# 1319
# (36,)
# 1320
# (35,)
# 1321
# (41,)
# 1322
# (25,)
# 1323
# (31,)
# 1324
# (26,)
# 1325
# (27,)
# 1326
# (25,)
# 1327
# (24,)
# 1328
# (19,)
# 1329
# (33,)
# 1330
# (29,)
# 1331
# (18,)
# 1332
# (60,)
# 1333
# (63,)
# 1334
# (61,)
# 1335
# (66,)
# 1336
# (62,)
# 1337
# (136,)
# 1338
# (127,)
# 1339
# (104,)
# 1340
# (131,)
# 1341
# (117,)
# 1342
# (41,)
# 1343
# (37,)
# 1344
# (35,)
# 1345
# (41,)
# 1346
# (40,)
# 1347
# (48,)
# 1348
# (49,)
# 1349
# (57,)
# 1350
# (44,)
# 1351
# (47,)
# 1352
# (51,)
# 1353
# (41,)
# 1354
# (37,)
# 1355
# (44,)
# 1356
# (40,)
# 1357
# (0,)
# 1358
# (0,)
# 1359
# (0,)
# 1360
# (0,)
# 1361
# (0,)
# 1362
# (4,)
# 1363
# (0,)
# 1364
# (0,)
# 1365
# (1,)
# 1366
# (4,)
# 1367
# (63,)
# 1368
# (56,)
# 1369
# (45,)
# 1370
# (58,)
# 1371
# (51,)
# 1372
# (42,)
# 1373
# (44,)
# 1374
# (38,)
# 1375
# (39,)
# 1376
# (39,)
# 1377
# (11,)
# 1378
# (9,)
# 1379
# (3,)
# 1380
# (5,)
# 1381
# (6,)
# 1382
# (10,)
# 1383
# (14,)
# 1384
# (10,)
# 1385
# (9,)
# 1386
# (14,)
# 1387
# (70,)
# 1388
# (63,)
# 1389
# (68,)
# 1390
# (64,)
# 1391
# (67,)
# 1392
# (49,)
# 1393
# (46,)
# 1394
# (58,)
# 1395
# (50,)
# 1396
# (59,)
# 1397
# (83,)
# 1398
# (79,)
# 1399
# (81,)
# 1400
# (78,)
# 1401
# (76,)
# 1402
# (78,)
# 1403
# (72,)
# 1404
# (72,)
# 1405
# (69,)
# 1406
# (70,)
# 1407
# (56,)
# 1408
# (55,)
# 1409
# (53,)
# 1410
# (57,)
# 1411
# (58,)
# 1412
# (76,)
# 1413
# (78,)
# 1414
# (72,)
# 1415
# (75,)
# 1416
# (73,)
# 1417
# (141,)
# 1418
# (166,)
# 1419
# (142,)
# 1420
# (154,)
# 1421
# (155,)
# 1422
# (160,)
# 1423
# (198,)
# 1424
# (197,)
# 1425
# (170,)
# 1426
# (180,)
# 1427
# (54,)
# 1428
# (52,)
# 1429
# (51,)
# 1430
# (63,)
# 1431
# (46,)
# 1432
# (39,)
# 1433
# (41,)
# 1434
# (39,)
# 1435
# (38,)
# 1436
# (41,)
# 1437
# (194,)
# 1438
# (187,)
# 1439
# (182,)
# 1440
# (218,)
# 1441
# (185,)
# 1442
# (110,)
# 1443
# (129,)
# 1444
# (128,)
# 1445
# (119,)
# 1446
# (142,)
# 1447
# (94,)
# 1448
# (109,)
# 1449
# (94,)
# 1450
# (107,)
# 1451
# (102,)
# 1452
# (50,)
# 1453
# (44,)
# 1454
# (56,)
# 1455
# (57,)
# 1456
# (56,)
# 1457
# (43,)
# 1458
# (39,)
# 1459
# (49,)
# 1460
# (40,)
# 1461
# (50,)
# 1462
# (51,)
# 1463
# (39,)
# 1464
# (56,)
# 1465
# (55,)
# 1466
# (49,)
# 1467
# (66,)
# 1468
# (74,)
# 1469
# (71,)
# 1470
# (72,)
# 1471
# (78,)
# 1472
# (13,)
# 1473
# (19,)
# 1474
# (16,)
# 1475
# (24,)
# 1476
# (18,)
# 1477
# (113,)
# 1478
# (111,)
# 1479
# (115,)
# 1480
# (124,)
# 1481
# (112,)
# 1482
# (99,)
# 1483
# (92,)
# 1484
# (99,)
# 1485
# (105,)
# 1486
# (105,)
# 1487
# (30,)
# 1488
# (32,)
# 1489
# (30,)
# 1490
# (34,)
# 1491
# (31,)
# 1492
# (92,)
# 1493
# (88,)
# 1494
# (88,)
# 1495
# (98,)
# 1496
# (92,)
# 1497
# (70,)
# 1498
# (65,)
# 1499
# (76,)
# 1500
# (72,)
# 1501
# (74,)
# 1502
# (72,)
# 1503
# (91,)
# 1504
# (86,)
# 1505
# (90,)
# 1506
# (80,)
# 1507
# (124,)
# 1508
# (107,)
# 1509
# (101,)
# 1510
# (104,)
# 1511
# (113,)
# 1512
# (59,)
# 1513
# (64,)
# 1514
# (64,)
# 1515
# (58,)
# 1516
# (52,)
# 1517
# (35,)
# 1518
# (31,)
# 1519
# (35,)
# 1520
# (37,)
# 1521
# (28,)
# 1522
# (25,)
# 1523
# (24,)
# 1524
# (24,)
# 1525
# (22,)
# 1526
# (23,)
# 1527
# (24,)
# 1528
# (24,)
# 1529
# (26,)
# 1530
# (25,)
# 1531
# (19,)
# 1532
# (20,)
# 1533
# (25,)
# 1534
# (25,)
# 1535
# (19,)
# 1536
# (23,)
# 1537
# (45,)
# 1538
# (49,)
# 1539
# (55,)
# 1540
# (45,)
# 1541
# (46,)
# 1542
# (30,)
# 1543
# (29,)
# 1544
# (37,)
# 1545
# (28,)
# 1546
# (25,)
# 1547
# (29,)
# 1548
# (32,)
# 1549
# (30,)
# 1550
# (30,)
# 1551
# (30,)
# 1552
# (41,)
# 1553
# (53,)
# 1554
# (43,)
# 1555
# (52,)
# 1556
# (55,)
# 1557
# (170,)
# 1558
# (195,)
# 1559
# (132,)
# 1560
# (162,)
# 1561
# (163,)
# 1562
# (58,)
# 1563
# (71,)
# 1564
# (55,)
# 1565
# (74,)
# 1566
# (81,)
# 1567
# (59,)
# 1568
# (62,)
# 1569
# (48,)
# 1570
# (65,)
# 1571
# (39,)
# 1572
# (68,)
# 1573
# (76,)
# 1574
# (62,)
# 1575
# (63,)
# 1576
# (66,)
# 1577
# (80,)
# 1578
# (79,)
# 1579
# (80,)
# 1580
# (79,)
# 1581
# (78,)
# 1582
# (48,)
# 1583
# (49,)
# 1584
# (58,)
# 1585
# (46,)
# 1586
# (49,)
# 1587
# (38,)
# 1588
# (37,)
# 1589
# (43,)
# 1590
# (38,)
# 1591
# (38,)
# 1592
# (45,)
# 1593
# (37,)
# 1594
# (39,)
# 1595
# (30,)
# 1596
# (147,)
# 1597
# (152,)
# 1598
# (159,)
# 1599
# (154,)
# 1600
# (160,)
# 1601
# (41,)
# 1602
# (38,)
# 1603
# (41,)
# 1604
# (39,)
# 1605
# (41,)
# 1606
# (134,)
# 1607
# (150,)
# 1608
# (168,)
# 1609
# (150,)
# 1610
# (157,)
# 1611
# (117,)
# 1612
# (108,)
# 1613
# (101,)
# 1614
# (83,)
# 1615
# (75,)
# 1616
# (91,)
# 1617
# (130,)
# 1618
# (139,)
# 1619
# (149,)
# 1620
# (108,)
# 1621
# (37,)
# 1622
# (56,)
# 1623
# (54,)
# 1624
# (49,)
# 1625
# (56,)
# 1626
# (49,)
# 1627
# (48,)
# 1628
# (58,)
# 1629
# (54,)
# 1630
# (46,)
# 1631
# (61,)
# 1632
# (53,)
# 1633
# (58,)
# 1634
# (69,)
# 1635
# (63,)
# 1636
# (43,)
# 1637
# (53,)
# 1638
# (54,)
# 1639
# (55,)
# 1640
# (43,)
# 1641
# (59,)
# 1642
# (56,)
# 1643
# (60,)
# 1644
# (56,)
# 1645
# (59,)
# 1646
# (98,)
# 1647
# (90,)
# 1648
# (99,)
# 1649
# (95,)
# 1650
# (108,)
# 1651
# (134,)
# 1652
# (83,)
# 1653
# (112,)
# 1654
# (68,)
# 1655
# (87,)
# 1656
# (104,)
# 1657
# (63,)
# 1658
# (77,)
# 1659
# (107,)
# 1660
# (95,)
# 1661
# (62,)
# 1662
# (55,)
# 1663
# (56,)
# 1664
# (48,)
# 1665
# (50,)
# 1666
# (29,)
# 1667
# (28,)
# 1668
# (34,)
# 1669
# (33,)
# 1670
# (34,)
# 1671
# (36,)
# 1672
# (36,)
# 1673
# (39,)
# 1674
# (39,)
# 1675
# (40,)
# 1676
# (69,)
# 1677
# (70,)
# 1678
# (67,)
# 1679
# (52,)
# 1680
# (74,)
# 1681
# (44,)
# 1682
# (47,)
# 1683
# (45,)
# 1684
# (46,)
# 1685
# (49,)
# 1686
# (58,)
# 1687
# (75,)
# 1688
# (62,)
# 1689
# (75,)
# 1690
# (65,)
# 1691
# (67,)
# 1692
# (56,)
# 1693
# (64,)
# 1694
# (68,)
# 1695
# (68,)
# 1696
# (42,)
# 1697
# (39,)
# 1698
# (37,)
# 1699
# (44,)
# 1700
# (36,)
# 1701
# (8,)
# 1702
# (14,)
# 1703
# (6,)
# 1704
# (13,)
# 1705
# (10,)
# 1706
# (69,)
# 1707
# (66,)
# 1708
# (65,)
# 1709
# (68,)
# 1710
# (56,)
# 1711
# (71,)
# 1712
# (59,)
# 1713
# (59,)
# 1714
# (74,)
# 1715
# (65,)
# 1716
# (69,)
# 1717
# (65,)
# 1718
# (79,)
# 1719
# (67,)
# 1720
# (67,)
# 1721
# (38,)
# 1722
# (33,)
# 1723
# (40,)
# 1724
# (33,)
# 1725
# (34,)
# 1726
# (93,)
# 1727
# (85,)
# 1728
# (82,)
# 1729
# (87,)
# 1730
# (92,)
# 1731
# (174,)
# 1732
# (176,)
# 1733
# (168,)
# 1734
# (149,)
# 1735
# (165,)
# 1736
# (66,)
# 1737
# (59,)
# 1738
# (60,)
# 1739
# (64,)
# 1740
# (67,)
# 1741
# (41,)
# 1742
# (55,)
# 1743
# (51,)
# 1744
# (50,)
# 1745
# (52,)
# 1746
# (64,)
# 1747
# (59,)
# 1748
# (63,)
# 1749
# (62,)
# 1750
# (66,)
# 1751
# (32,)
# 1752
# (28,)
# 1753
# (22,)
# 1754
# (31,)
# 1755
# (25,)
# 1756
# (102,)
# 1757
# (109,)
# 1758
# (161,)
# 1759
# (153,)
# 1760
# (148,)
# 1761
# (139,)
# 1762
# (132,)
# 1763
# (145,)
# 1764
# (146,)
# 1765
# (147,)
# 1766
# (159,)
# 1767
# (166,)
# 1768
# (177,)
# 1769
# (195,)
# 1770
# (162,)
# 1771
# (24,)
# 1772
# (24,)
# 1773
# (23,)
# 1774
# (23,)
# 1775
# (26,)
# 1776
# (33,)
# 1777
# (39,)
# 1778
# (31,)
# 1779
# (35,)
# 1780
# (32,)
# 1781
# (191,)
# 1782
# (169,)
# 1783
# (168,)
# 1784
# (178,)
# 1785
# (161,)
# 1786
# (23,)
# 1787
# (43,)
# 1788
# (39,)
# 1789
# (34,)
# 1790
# (31,)
# 1791
# (65,)
# 1792
# (48,)
# 1793
# (75,)
# 1794
# (56,)
# 1795
# (58,)
# 1796
# (32,)
# 1797
# (33,)
# 1798
# (49,)
# 1799
# (41,)
# 1800
# (27,)
# 1801
# (29,)
# 1802
# (47,)
# 1803
# (52,)
# 1804
# (28,)
# 1805
# (41,)
# 1806
# (15,)
# 1807
# (15,)
# 1808
# (14,)
# 1809
# (16,)
# 1810
# (14,)
# 1811
# (47,)
# 1812
# (51,)
# 1813
# (51,)
# 1814
# (51,)
# 1815
# (44,)
# 1816
# (49,)
# 1817
# (39,)
# 1818
# (59,)
# 1819
# (42,)
# 1820
# (48,)
# 1821
# (182,)
# 1822
# (213,)
# 1823
# (183,)
# 1824
# (180,)
# 1825
# (178,)
# 1826
# (135,)
# 1827
# (165,)
# 1828
# (151,)
# 1829
# (138,)
# 1830
# (137,)
# 1831
# (128,)
# 1832
# (167,)
# 1833
# (154,)
# 1834
# (141,)
# 1835
# (165,)
# 1836
# (23,)
# 1837
# (23,)
# 1838
# (18,)
# 1839
# (19,)
# 1840
# (18,)
# 1841
# (167,)
# 1842
# (139,)
# 1843
# (152,)
# 1844
# (156,)
# 1845
# (152,)
# 1846
# (17,)
# 1847
# (21,)
# 1848
# (17,)
# 1849
# (22,)
# 1850
# (24,)
# 1851
# (27,)
# 1852
# (24,)
# 1853
# (21,)
# 1854
# (22,)
# 1855
# (21,)
# 1856
# (57,)
# 1857
# (51,)
# 1858
# (52,)
# 1859
# (55,)
# 1860
# (63,)
# 1861
# (63,)
# 1862
# (70,)
# 1863
# (70,)
# 1864
# (70,)
# 1865
# (62,)
# 1866
# (18,)
# 1867
# (16,)
# 1868
# (21,)
# 1869
# (22,)
# 1870
# (18,)
# 1871
# (13,)
# 1872
# (9,)
# 1873
# (5,)
# 1874
# (13,)
# 1875
# (9,)
# 1876
# (40,)
# 1877
# (42,)
# 1878
# (44,)
# 1879
# (34,)
# 1880
# (38,)
# 1881
# (14,)
# 1882
# (7,)
# 1883
# (8,)
# 1884
# (9,)
# 1885
# (9,)
# 1886
# (13,)
# 1887
# (6,)
# 1888
# (5,)
# 1889
# (6,)
# 1890
# (13,)
# 1891
# (54,)
# 1892
# (57,)
# 1893
# (45,)
# 1894
# (57,)
# 1895
# (50,)
# 1896
# (47,)
# 1897
# (48,)
# 1898
# (46,)
# 1899
# (44,)
# 1900
# (47,)
# 1901
# (42,)
# 1902
# (39,)
# 1903
# (43,)
# 1904
# (34,)
# 1905
# (49,)
# 1906
# (89,)
# 1907
# (89,)
# 1908
# (89,)
# 1909
# (86,)
# 1910
# (84,)
# 1911
# (77,)
# 1912
# (79,)
# 1913
# (79,)
# 1914
# (85,)
# 1915
# (82,)
# 1916
# (27,)
# 1917
# (30,)
# 1918
# (22,)
# 1919
# (33,)
# 1920
# (30,)
# 1921
# (46,)
# 1922
# (46,)
# 1923
# (35,)
# 1924
# (46,)
# 1925
# (43,)
# 1926
# (169,)
# 1927
# (162,)
# 1928
# (199,)
# 1929
# (165,)
# 1930
# (151,)
# 1931
# (169,)
# 1932
# (165,)
# 1933
# (156,)
# 1934
# (146,)
# 1935
# (163,)
# 1936
# (180,)
# 1937
# (185,)
# 1938
# (178,)
# 1939
# (158,)
# 1940
# (171,)
# 1941
# (51,)
# 1942
# (52,)
# 1943
# (47,)
# 1944
# (48,)
# 1945
# (50,)
# 1946
# (78,)
# 1947
# (66,)
# 1948
# (72,)
# 1949
# (66,)
# 1950
# (61,)
# 1951
# (87,)
# 1952
# (95,)
# 1953
# (88,)
# 1954
# (93,)
# 1955
# (92,)
# 1956
# (63,)
# 1957
# (49,)
# 1958
# (48,)
# 1959
# (39,)
# 1960
# (63,)
# 1961
# (87,)
# 1962
# (95,)
# 1963
# (93,)
# 1964
# (90,)
# 1965
# (91,)
# 1966
# (149,)
# 1967
# (189,)
# 1968
# (172,)
# 1969
# (179,)
# 1970
# (163,)
# 1971
# (39,)
# 1972
# (37,)
# 1973
# (35,)
# 1974
# (37,)
# 1975
# (42,)
# 1976
# (27,)
# 1977
# (25,)
# 1978
# (26,)
# 1979
# (27,)
# 1980
# (29,)
# 1981
# (139,)
# 1982
# (144,)
# 1983
# (133,)
# 1984
# (157,)
# 1985
# (147,)
# 1986
# (169,)
# 1987
# (192,)
# 1988
# (148,)
# 1989
# (195,)
# 1990
# (165,)
# 1991
# (166,)
# 1992
# (166,)
# 1993
# (221,)
# 1994
# (175,)
# 1995
# (182,)
# 1996
# (30,)
# 1997
# (35,)
# 1998
# (31,)
# 1999
# (34,)
# 2000
# (32,)
# 2001
# (34,)
# 2002
# (36,)
# 2003
# (31,)
# 2004
# (25,)
# 2005
# (30,)
# 2006
# (51,)
# 2007
# (48,)
# 2008
# (38,)
# 2009
# (31,)
# 2010
# (45,)
# 2011
# (49,)
# 2012
# (28,)
# 2013
# (32,)
# 2014
# (33,)
# 2015
# (38,)
# 2016
# (67,)
# 2017
# (67,)
# 2018
# (65,)
# 2019
# (68,)
# 2020
# (70,)
# 2021
# (51,)
# 2022
# (53,)
# 2023
# (43,)
# 2024
# (48,)
# 2025
# (54,)
# 2026
# (26,)
# 2027
# (24,)
# 2028
# (26,)
# 2029
# (22,)
# 2030
# (18,)
# 2031
# (30,)
# 2032
# (38,)
# 2033
# (32,)
# 2034
# (45,)
# 2035
# (39,)
# 2036
# (30,)
# 2037
# (30,)
# 2038
# (43,)
# 2039
# (26,)
# 2040
# (25,)
# 2041
# (39,)
# 2042
# (41,)
# 2043
# (41,)
# 2044
# (40,)
# 2045
# (34,)
# 2046
# (24,)
# 2047
# (25,)
# 2048
# (26,)
# 2049
# (37,)
# 2050
# (30,)
# 2051
# (26,)
# 2052
# (31,)
# 2053
# (29,)
# 2054
# (28,)
# 2055
# (28,)
# 2056
# (96,)
# 2057
# (139,)
# 2058
# (160,)
# 2059
# (71,)
# 2060
# (130,)
# 2061
# (17,)
# 2062
# (21,)
# 2063
# (18,)
# 2064
# (20,)
# 2065
# (25,)
# 2066
# (94,)
# 2067
# (59,)
# 2068
# (87,)
# 2069
# (101,)
# 2070
# (111,)
# 2071
# (60,)
# 2072
# (61,)
# 2073
# (59,)
# 2074
# (62,)
# 2075
# (59,)
# 2076
# (41,)
# 2077
# (40,)
# 2078
# (38,)
# 2079
# (33,)
# 2080
# (39,)
# 2081
# (68,)
# 2082
# (67,)
# 2083
# (68,)
# 2084
# (76,)
# 2085
# (70,)
# 2086
# (58,)
# 2087
# (61,)
# 2088
# (59,)
# 2089
# (59,)
# 2090
# (57,)
# 2091
# (89,)
# 2092
# (91,)
# 2093
# (83,)
# 2094
# (90,)
# 2095
# (96,)
# 2096
# (69,)
# 2097
# (73,)
# 2098
# (73,)
# 2099
# (67,)
# 2100
# (68,)
# 2101
# (20,)
# 2102
# (17,)
# 2103
# (11,)
# 2104
# (15,)
# 2105
# (17,)
# 2106
# (79,)
# 2107
# (109,)
# 2108
# (86,)
# 2109
# (86,)
# 2110
# (105,)
# 2111
# (181,)
# 2112
# (189,)
# 2113
# (188,)
# 2114
# (174,)
# 2115
# (164,)
# 2116
# (135,)
# 2117
# (127,)
# 2118
# (149,)
# 2119
# (133,)
# 2120
# (148,)
# 2121
# (21,)
# 2122
# (20,)
# 2123
# (20,)
# 2124
# (18,)
# 2125
# (25,)
# 2126
# (43,)
# 2127
# (41,)
# 2128
# (44,)
# 2129
# (50,)
# 2130
# (45,)
# 2131
# (95,)
# 2132
# (90,)
# 2133
# (91,)
# 2134
# (77,)
# 2135
# (85,)
# 2136
# (25,)
# 2137
# (28,)
# 2138
# (50,)
# 2139
# (42,)
# 2140
# (32,)
# 2141
# (46,)
# 2142
# (49,)
# 2143
# (50,)
# 2144
# (41,)
# 2145
# (46,)
# 2146
# (62,)
# 2147
# (57,)
# 2148
# (64,)
# 2149
# (54,)
# 2150
# (59,)
# 2151
# (89,)
# 2152
# (96,)
# 2153
# (92,)
# 2154
# (92,)
# 2155
# (97,)
# 2156
# (9,)
# 2157
# (7,)
# 2158
# (6,)
# 2159
# (6,)
# 2160
# (12,)
# 2161
# (230,)
# 2162
# (211,)
# 2163
# (206,)
# 2164
# (208,)
# 2165
# (209,)
# 2166
# (27,)
# 2167
# (34,)
# 2168
# (30,)
# 2169
# (39,)
# 2170
# (28,)
# 2171
# (89,)
# 2172
# (95,)
# 2173
# (83,)
# 2174
# (88,)
# 2175
# (102,)
# 2176
# (147,)
# 2177
# (179,)
# 2178
# (146,)
# 2179
# (178,)
# 2180
# (148,)
# 2181
# (83,)
# 2182
# (106,)
# 2183
# (88,)
# 2184
# (81,)
# 2185
# (109,)
# 2186
# (53,)
# 2187
# (51,)
# 2188
# (55,)
# 2189
# (54,)
# 2190
# (49,)
# 2191
# (78,)
# 2192
# (79,)
# 2193
# (84,)
# 2194
# (76,)
# 2195
# (81,)
# 2196
# (51,)
# 2197
# (60,)
# 2198
# (55,)
# 2199
# (70,)
# 2200
# (49,)
# 2201
# (65,)
# 2202
# (43,)
# 2203
# (59,)
# 2204
# (54,)
# 2205
# (51,)
# 2206
# (31,)
# 2207
# (34,)
# 2208
# (36,)
# 2209
# (36,)
# 2210
# (28,)
# 2211
# (76,)
# 2212
# (78,)
# 2213
# (77,)
# 2214
# (79,)
# 2215
# (79,)
# 2216
# (59,)
# 2217
# (63,)
# 2218
# (67,)
# 2219
# (54,)
# 2220
# (59,)
# 2221
# (42,)
# 2222
# (41,)
# 2223
# (38,)
# 2224
# (40,)
# 2225
# (45,)
# 2226
# (39,)
# 2227
# (32,)
# 2228
# (27,)
# 2229
# (36,)
# 2230
# (32,)
# 2231
# (69,)
# 2232
# (64,)
# 2233
# (62,)
# 2234
# (63,)
# 2235
# (73,)
# 2236
# (88,)
# 2237
# (88,)
# 2238
# (87,)
# 2239
# (83,)
# 2240
# (92,)
# 2241
# (110,)
# 2242
# (101,)
# 2243
# (103,)
# 2244
# (96,)
# 2245
# (112,)
# 2246
# (70,)
# 2247
# (69,)
# 2248
# (64,)
# 2249
# (76,)
# 2250
# (59,)
# 2251
# (91,)
# 2252
# (72,)
# 2253
# (86,)
# 2254
# (85,)
# 2255
# (86,)
# 2256
# (66,)
# 2257
# (65,)
# 2258
# (67,)
# 2259
# (71,)
# 2260
# (69,)
# 2261
# (249,)
# 2262
# (225,)
# 2263
# (276,)
# 2264
# (277,)
# 2265
# (263,)
# 2266
# (40,)
# 2267
# (34,)
# 2268
# (41,)
# 2269
# (36,)
# 2270
# (38,)
# 2271
# (60,)
# 2272
# (60,)
# 2273
# (63,)
# 2274
# (62,)
# 2275
# (56,)
# 2276
# (36,)
# 2277
# (51,)
# 2278
# (36,)
# 2279
# (37,)
# 2280
# (50,)
# 2281
# (84,)
# 2282
# (57,)
# 2283
# (66,)
# 2284
# (88,)
# 2285
# (98,)
# 2286
# (29,)
# 2287
# (27,)
# 2288
# (38,)
# 2289
# (25,)
# 2290
# (30,)
# 2291
# (49,)
# 2292
# (50,)
# 2293
# (47,)
# 2294
# (45,)
# 2295
# (55,)
# 2296
# (14,)
# 2297
# (68,)
# 2298
# (79,)
# 2299
# (72,)
# 2300
# (59,)
# 2301
# (85,)
# 2302
# (8,)
# 2303
# (15,)
# 2304
# (9,)
# 2305
# (11,)
# 2306
# (14,)
# 2307
# (121,)
# 2308
# (91,)
# 2309
# (120,)
# 2310
# (116,)
# 2311
# (109,)
# 2312
# (88,)
# 2313
# (140,)
# 2314
# (117,)
# 2315
# (132,)
# 2316
# (121,)
# 2317
# (84,)
# 2318
# (107,)
# 2319
# (79,)
# 2320
# (88,)
# 2321
# (83,)
# 2322
# (85,)
# 2323
# (91,)
# 2324
# (93,)
# 2325
# (78,)
# 2326
# (94,)
# 2327
# (100,)
# 2328
# (67,)
# 2329
# (77,)
# 2330
# (88,)
# 2331
# (101,)
# 2332
# (91,)
# 2333
# (71,)
# 2334
# (66,)
# 2335
# (67,)
# 2336
# (98,)
# 2337
# (30,)
# 2338
# (20,)
# 2339
# (23,)
# 2340
# (20,)
# 2341
# (24,)
# 2342
# (17,)
# 2343
# (17,)
# 2344
# (20,)
# 2345
# (19,)
# 2346
# (16,)
# 2347
# (12,)
# 2348
# (18,)
# 2349
# (15,)
# 2350
# (20,)
# 2351
# (28,)
# 2352
# (18,)
# 2353
# (17,)
# 2354
# (19,)
# 2355
# (23,)
# 2356
# (22,)
# 2357
# (32,)
# 2358
# (41,)
# 2359
# (38,)
# 2360
# (34,)
# 2361
# (42,)
# 2362
# (27,)
# 2363
# (23,)
# 2364
# (29,)
# 2365
# (29,)
# 2366
# (30,)
# 2367
# (22,)
# 2368
# (23,)
# 2369
# (20,)
# 2370
# (19,)
# 2371
# (19,)
# 2372
# (46,)
# 2373
# (62,)
# 2374
# (61,)
# 2375
# (60,)
# 2376
# (46,)
# 2377
# (67,)
# 2378
# (78,)
# 2379
# (56,)
# 2380
# (50,)
# 2381
# (55,)
# 2382
# (85,)
# 2383
# (80,)
# 2384
# (82,)
# 2385
# (83,)
# 2386
# (99,)
# 2387
# (66,)
# 2388
# (69,)
# 2389
# (59,)
# 2390
# (65,)
# 2391
# (79,)
# 2392
# (44,)
# 2393
# (46,)
# 2394
# (47,)
# 2395
# (45,)
# 2396
# (39,)
# 2397
# (92,)
# 2398
# (89,)
# 2399
# (97,)
# 2400
# (74,)
# 2401
# (104,)
# 2402
# (73,)
# 2403
# (89,)
# 2404
# (80,)
# 2405
# (68,)
# 2406
# (74,)
# 2407
# (100,)
# 2408
# (96,)
# 2409
# (98,)
# 2410
# (96,)
# 2411
# (94,)
# 2412
# (10,)
# 2413
# (16,)
# 2414
# (10,)
# 2415
# (8,)
# 2416
# (11,)
# 2417
# (27,)
# 2418
# (18,)
# 2419
# (28,)
# 2420
# (22,)
# 2421
# (24,)
# 2422
# (30,)
# 2423
# (30,)
# 2424
# (27,)
# 2425
# (24,)
# 2426
# (33,)
# 2427
# (24,)
# 2428
# (19,)
# 2429
# (21,)
# 2430
# (21,)
# 2431
# (23,)
# 2432
# (97,)
# 2433
# (103,)
# 2434
# (83,)
# 2435
# (88,)
# 2436
# (99,)
# 2437
# (58,)
# 2438
# (50,)
# 2439
# (56,)
# 2440
# (62,)
# 2441
# (59,)
# 2442
# (35,)
# 2443
# (40,)
# 2444
# (48,)
# 2445
# (38,)
# 2446
# (49,)
# 2447
# (179,)
# 2448
# (144,)
# 2449
# (122,)
# 2450
# (178,)
# 2451
# (183,)
# 2452
# (96,)
# 2453
# (118,)
# 2454
# (128,)
# 2455
# (110,)
# 2456
# (107,)
# 2457
# (104,)
# 2458
# (160,)
# 2459
# (129,)
# 2460
# (117,)
# 2461
# (134,)
# 2462
# (168,)
# 2463
# (179,)
# 2464
# (177,)
# 2465
# (176,)
# 2466
# (162,)
# 2467
# (87,)
# 2468
# (75,)
# 2469
# (85,)
# 2470
# (67,)
# 2471
# (75,)
# 2472
# (82,)
# 2473
# (77,)
# 2474
# (94,)
# 2475
# (87,)
# 2476
# (94,)
# 2477
# (39,)
# 2478
# (34,)
# 2479
# (35,)
# 2480
# (31,)
# 2481
# (23,)
# 2482
# (36,)
# 2483
# (27,)
# 2484
# (31,)
# 2485
# (30,)
# 2486
# (26,)
# 2487
# (150,)
# 2488
# (198,)
# 2489
# (177,)
# 2490
# (170,)
# 2491
# (190,)
# 2492
# (127,)
# 2493
# (125,)
# 2494
# (145,)
# 2495
# (132,)
# 2496
# (144,)
# 2497
# (75,)
# 2498
# (91,)
# 2499
# (94,)
# 2500
# (86,)
# 2501
# (97,)
# 2502
# (67,)
# 2503
# (81,)
# 2504
# (76,)
# 2505
# (66,)
# 2506
# (93,)
# 2507
# (25,)
# 2508
# (38,)
# 2509
# (25,)
# 2510
# (28,)
# 2511
# (32,)
# 2512
# (76,)
# 2513
# (65,)
# 2514
# (58,)
# 2515
# (62,)
# 2516
# (78,)
# 2517
# (98,)
# 2518
# (78,)
# 2519
# (85,)
# 2520
# (86,)
# 2521
# (90,)
# 2522
# (40,)
# 2523
# (65,)
# 2524
# (62,)
# 2525
# (59,)
# 2526
# (59,)
# 2527
# (70,)
# 2528
# (64,)
# 2529
# (65,)
# 2530
# (81,)
# 2531
# (64,)
# 2532
# (46,)
# 2533
# (43,)
# 2534
# (50,)
# 2535
# (67,)
# 2536
# (49,)
# 2537
# (72,)
# 2538
# (53,)
# 2539
# (55,)
# 2540
# (46,)
# 2541
# (54,)
# 2542
# (15,)
# 2543
# (21,)
# 2544
# (18,)
# 2545
# (21,)
# 2546
# (26,)
# 2547
# (115,)
# 2548
# (104,)
# 2549
# (110,)
# 2550
# (122,)
# 2551
# (120,)
# 2552
# (124,)
# 2553
# (123,)
# 2554
# (110,)
# 2555
# (124,)
# 2556
# (124,)
# 2557
# (77,)
# 2558
# (78,)
# 2559
# (72,)
# 2560
# (77,)
# 2561
# (78,)
# 2562
# (57,)
# 2563
# (53,)
# 2564
# (44,)
# 2565
# (48,)
# 2566
# (62,)
# 2567
# (24,)
# 2568
# (32,)
# 2569
# (24,)
# 2570
# (26,)
# 2571
# (23,)
# 2572
# (32,)
# 2573
# (29,)
# 2574
# (39,)
# 2575
# (35,)
# 2576
# (34,)
# 2577
# (41,)
# 2578
# (41,)
# 2579
# (44,)
# 2580
# (48,)
# 2581
# (45,)
# 2582
# (31,)
# 2583
# (33,)
# 2584
# (34,)
# 2585
# (32,)
# 2586
# (37,)
# 2587
# (90,)
# 2588
# (88,)
# 2589
# (86,)
# 2590
# (98,)
# 2591
# (97,)
# 2592
# (47,)
# 2593
# (33,)
# 2594
# (46,)
# 2595
# (51,)
# 2596
# (38,)
# 2597
# (99,)
# 2598
# (92,)
# 2599
# (92,)
# 2600
# (104,)
# 2601
# (92,)
# 2602
# (18,)
# 2603
# (19,)
# 2604
# (30,)
# 2605
# (27,)
# 2606
# (28,)
# 2607
# (33,)
# 2608
# (38,)
# 2609
# (38,)
# 2610
# (53,)
# 2611
# (41,)
# 2612
# (28,)
# 2613
# (29,)
# 2614
# (29,)
# 2615
# (34,)
# 2616
# (41,)
# 2617
# (91,)
# 2618
# (51,)
# 2619
# (70,)
# 2620
# (66,)
# 2621
# (62,)
# 2622
# (77,)
# 2623
# (82,)
# 2624
# (82,)
# 2625
# (71,)
# 2626
# (66,)
# 2627
# (52,)
# 2628
# (83,)
# 2629
# (47,)
# 2630
# (47,)
# 2631
# (82,)
# 2632
# (111,)
# 2633
# (115,)
# 2634
# (134,)
# 2635
# (133,)
# 2636
# (128,)
# 2637
# (145,)
# 2638
# (150,)
# 2639
# (98,)
# 2640
# (124,)
# 2641
# (117,)
# 2642
# (84,)
# 2643
# (83,)
# 2644
# (89,)
# 2645
# (66,)
# 2646
# (77,)
# 2647
# (113,)
# 2648
# (68,)
# 2649
# (82,)
# 2650
# (89,)
# 2651
# (67,)
# 2652
# (105,)
# 2653
# (159,)
# 2654
# (159,)
# 2655
# (140,)
# 2656
# (149,)
# 2657
# (68,)
# 2658
# (104,)
# 2659
# (94,)
# 2660
# (112,)
# 2661
# (93,)
# 2662
# (124,)
# 2663
# (97,)
# 2664
# (104,)
# 2665
# (106,)
# 2666
# (107,)
# 2667
# (47,)
# 2668
# (45,)
# 2669
# (36,)
# 2670
# (44,)
# 2671
# (35,)
# 2672
# (35,)
# 2673
# (31,)
# 2674
# (27,)
# 2675
# (36,)
# 2676
# (35,)
# 2677
# (22,)
# 2678
# (28,)
# 2679
# (28,)
# 2680
# (31,)
# 2681
# (31,)
# 2682
# (14,)
# 2683
# (9,)
# 2684
# (21,)
# 2685
# (17,)
# 2686
# (14,)
# 2687
# (26,)
# 2688
# (24,)
# 2689
# (26,)
# 2690
# (28,)
# 2691
# (28,)
# 2692
# (36,)
# 2693
# (46,)
# 2694
# (48,)
# 2695
# (51,)
# 2696
# (41,)
# 2697
# (38,)
# 2698
# (38,)
# 2699
# (36,)
# 2700
# (36,)
# 2701
# (49,)
# 2702
# (94,)
# 2703
# (99,)
# 2704
# (78,)
# 2705
# (111,)
# 2706
# (93,)
# 2707
# (25,)
# 2708
# (26,)
# 2709
# (26,)
# 2710
# (33,)
# 2711
# (19,)
# 2712
# (29,)
# 2713
# (49,)
# 2714
# (40,)
# 2715
# (42,)
# 2716
# (22,)
# 2717
# (12,)
# 2718
# (12,)
# 2719
# (12,)
# 2720
# (11,)
# 2721
# (12,)
# 2722
# (7,)
# 2723
# (8,)
# 2724
# (7,)
# 2725
# (39,)
# 2726
# (33,)
# 2727
# (29,)
# 2728
# (40,)
# 2729
# (34,)
# 2730
# (38,)
# 2731
# (44,)
# 2732
# (37,)
# 2733
# (38,)
# 2734
# (38,)
# 2735
# (62,)
# 2736
# (73,)
# 2737
# (51,)
# 2738
# (58,)
# 2739
# (47,)
# 2740
# (13,)
# 2741
# (14,)
# 2742
# (24,)
# 2743
# (12,)
# 2744
# (12,)
# 2745
# (68,)
# 2746
# (71,)
# 2747
# (71,)
# 2748
# (77,)
# 2749
# (72,)
# 2750
# (68,)
# 2751
# (69,)
# 2752
# (71,)
# 2753
# (62,)
# 2754
# (53,)
# 2755
# (43,)
# 2756
# (49,)
# 2757
# (54,)
# 2758
# (43,)
# 2759
# (41,)
# 2760
# (170,)
# 2761
# (174,)
# 2762
# (193,)
# 2763
# (168,)
# 2764
# (170,)
# 2765
# (168,)
# 2766
# (162,)
# 2767
# (179,)
# 2768
# (167,)
# 2769
# (184,)
# 2770
# (236,)
# 2771
# (254,)
# 2772
# (264,)
# 2773
# (250,)
# 2774
# (231,)
# 2775
# (204,)
# 2776
# (218,)
# 2777
# (201,)
# 2778
# (196,)
# 2779
# (196,)
# 2780
# (159,)
# 2781
# (180,)
# 2782
# (185,)
# 2783
# (189,)
# 2784
# (189,)
# 2785
# (121,)
# 2786
# (130,)
# 2787
# (131,)
# 2788
# (146,)
# 2789
# (138,)
# 2790
# (118,)
# 2791
# (136,)
# 2792
# (120,)
# 2793
# (105,)
# 2794
# (110,)
# 2795
# (79,)
# 2796
# (68,)
# 2797
# (91,)
# 2798
# (80,)
# 2799
# (68,)
# 2800
# (96,)
# 2801
# (102,)
# 2802
# (101,)
# 2803
# (92,)
# 2804
# (97,)
# 2805
# (63,)
# 2806
# (74,)
# 2807
# (66,)
# 2808
# (81,)
# 2809
# (57,)
# 2810
# (111,)
# 2811
# (108,)
# 2812
# (102,)
# 2813
# (96,)
# 2814
# (93,)
# 2815
# (49,)
# 2816
# (51,)
# 2817
# (55,)
# 2818
# (68,)
# 2819
# (52,)
# 2820
# (74,)
# 2821
# (75,)
# 2822
# (69,)
# 2823
# (77,)
# 2824
# (73,)
# 2825
# (32,)
# 2826
# (31,)
# 2827
# (31,)
# 2828
# (30,)
# 2829
# (27,)
# 2830
# (59,)
# 2831
# (74,)
# 2832
# (67,)
# 2833
# (75,)
# 2834
# (49,)
# 2835
# (52,)
# 2836
# (51,)
# 2837
# (50,)
# 2838
# (44,)
# 2839
# (46,)
# 2840
# (52,)
# 2841
# (43,)
# 2842
# (53,)
# 2843
# (43,)
# 2844
# (51,)
# 2845
# (49,)
# 2846
# (70,)
# 2847
# (75,)
# 2848
# (56,)
# 2849
# (51,)
# 2850
# (33,)
# 2851
# (41,)
# 2852
# (36,)
# 2853
# (36,)
# 2854
# (47,)
# 2855
# (36,)
# 2856
# (43,)
# 2857
# (43,)
# 2858
# (34,)
# 2859
# (28,)
# 2860
# (34,)
# 2861
# (50,)
# 2862
# (42,)
# 2863
# (38,)
# 2864
# (38,)
# 2865
# (45,)
# 2866
# (50,)
# 2867
# (45,)
# 2868
# (45,)
# 2869
# (44,)
# 2870
# (83,)
# 2871
# (93,)
# 2872
# (88,)
# 2873
# (92,)
# 2874
# (79,)
# 2875
# (44,)
# 2876
# (51,)
# 2877
# (40,)
# 2878
# (55,)
# 2879
# (54,)
# 2880
# (24,)
# 2881
# (23,)
# 2882
# (23,)
# 2883
# (26,)
# 2884
# (27,)
# 2885
# (128,)
# 2886
# (89,)
# 2887
# (90,)
# 2888
# (90,)
# 2889
# (101,)
# 2890
# (61,)
# 2891
# (66,)
# 2892
# (68,)
# 2893
# (62,)
# 2894
# (65,)
# 2895
# (46,)
# 2896
# (52,)
# 2897
# (61,)
# 2898
# (65,)
# 2899
# (51,)
# 2900
# (118,)
# 2901
# (112,)
# 2902
# (105,)
# 2903
# (114,)
# 2904
# (116,)
# 2905
# (5,)
# 2906
# (11,)
# 2907
# (4,)
# 2908
# (14,)
# 2909
# (8,)
# 2910
# (87,)
# 2911
# (98,)
# 2912
# (93,)
# 2913
# (81,)
# 2914
# (92,)
# 2915
# (85,)
# 2916
# (78,)
# 2917
# (88,)
# 2918
# (80,)
# 2919
# (85,)
# 2920
# (48,)
# 2921
# (34,)
# 2922
# (45,)
# 2923
# (54,)
# 2924
# (47,)
# 2925
# (38,)
# 2926
# (36,)
# 2927
# (31,)
# 2928
# (40,)
# 2929
# (37,)
# 2930
# (53,)
# 2931
# (66,)
# 2932
# (53,)
# 2933
# (55,)
# 2934
# (61,)
# 2935
# (47,)
# 2936
# (48,)
# 2937
# (45,)
# 2938
# (45,)
# 2939
# (45,)
# 2940
# (52,)
# 2941
# (52,)
# 2942
# (50,)
# 2943
# (52,)
# 2944
# (47,)
# 2945
# (35,)
# 2946
# (32,)
# 2947
# (41,)
# 2948
# (28,)
# 2949
# (36,)
# 2950
# (48,)
# 2951
# (52,)
# 2952
# (55,)
# 2953
# (31,)
# 2954
# (53,)
# 2955
# (29,)
# 2956
# (37,)
# 2957
# (30,)
# 2958
# (30,)
# 2959
# (32,)
# 2960
# (23,)
# 2961
# (16,)
# 2962
# (26,)
# 2963
# (16,)
# 2964
# (23,)
# 2965
# (25,)
# 2966
# (21,)
# 2967
# (23,)
# 2968
# (26,)
# 2969
# (22,)
# 2970
# (11,)
# 2971
# (12,)
# 2972
# (11,)
# 2973
# (20,)
# 2974
# (75,)
# 2975
# (66,)
# 2976
# (77,)
# 2977
# (72,)
# 2978
# (70,)
# 2979
# (102,)
# 2980
# (99,)
# 2981
# (108,)
# 2982
# (99,)
# 2983
# (110,)
# 2984
# (65,)
# 2985
# (68,)
# 2986
# (66,)
# 2987
# (60,)
# 2988
# (65,)
# 2989
# (59,)
# 2990
# (68,)
# 2991
# (54,)
# 2992
# (57,)
# 2993
# (74,)
# 2994
# (122,)
# 2995
# (131,)
# 2996
# (117,)
# 2997
# (118,)
# 2998
# (109,)
# 2999
# (71,)
# 3000
# (65,)
# 3001
# (60,)
# 3002
# (63,)
# 3003
# (48,)
# 3004
# (52,)
# 3005
# (54,)
# 3006
# (63,)
# 3007
# (58,)
# 3008
# (57,)
# 3009
# (136,)
# 3010
# (134,)
# 3011
# (139,)
# 3012
# (130,)
# 3013
# (133,)
# 3014
# (44,)
# 3015
# (40,)
# 3016
# (40,)
# 3017
# (56,)
# 3018
# (34,)
# 3019
# (115,)
# 3020
# (127,)
# 3021
# (102,)
# 3022
# (109,)
# 3023
# (114,)
# 3024
# (112,)
# 3025
# (90,)
# 3026
# (77,)
# 3027
# (105,)
# 3028
# (67,)
# 3029
# (90,)
# 3030
# (65,)
# 3031
# (79,)
# 3032
# (85,)
# 3033
# (97,)
# 3034
# (43,)
# 3035
# (47,)
# 3036
# (42,)
# 3037
# (44,)
# 3038
# (45,)
# 3039
# (91,)
# 3040
# (74,)
# 3041
# (86,)
# 3042
# (74,)
# 3043
# (81,)
# 3044
# (48,)
# 3045
# (53,)
# 3046
# (49,)
# 3047
# (45,)
# 3048
# (46,)
# 3049
# (61,)
# 3050
# (66,)
# 3051
# (63,)
# 3052
# (70,)
# 3053
# (55,)
# 3054
# (36,)
# 3055
# (40,)
# 3056
# (38,)
# 3057
# (37,)
# 3058
# (37,)
# 3059
# (24,)
# 3060
# (21,)
# 3061
# (21,)
# 3062
# (22,)
# 3063
# (30,)
# 3064
# (98,)
# 3065
# (94,)
# 3066
# (87,)
# 3067
# (89,)
# 3068
# (78,)
# 3069
# (58,)
# 3070
# (51,)
# 3071
# (58,)
# 3072
# (64,)
# 3073
# (70,)
# 3074
# (68,)
# 3075
# (64,)
# 3076
# (71,)
# 3077
# (71,)
# 3078
# (52,)
# 3079
# (44,)
# 3080
# (40,)
# 3081
# (43,)
# 3082
# (41,)
# 3083
# (41,)
# 3084
# (85,)
# 3085
# (103,)
# 3086
# (82,)
# 3087
# (93,)
# 3088
# (79,)
# 3089
# (26,)
# 3090
# (18,)
# 3091
# (17,)
# 3092
# (17,)
# 3093
# (13,)
# 3094
# (27,)
# 3095
# (47,)
# 3096
# (29,)
# 3097
# (40,)
# 3098
# (38,)
# 3099
# (98,)
# 3100
# (123,)
# 3101
# (120,)
# 3102
# (106,)
# 3103
# (104,)
# 3104
# (59,)
# 3105
# (56,)
# 3106
# (55,)
# 3107
# (49,)
# 3108
# (54,)
# 3109
# (89,)
# 3110
# (70,)
# 3111
# (86,)
# 3112
# (86,)
# 3113
# (69,)
# 3114
# (101,)
# 3115
# (107,)
# 3116
# (112,)
# 3117
# (83,)
# 3118
# (103,)
# 3119
# (20,)
# 3120
# (11,)
# 3121
# (11,)
# 3122
# (9,)
# 3123
# (9,)
# 3124
# (50,)
# 3125
# (42,)
# 3126
# (47,)
# 3127
# (51,)
# 3128
# (52,)
# 3129
# (27,)
# 3130
# (31,)
# 3131
# (27,)
# 3132
# (29,)
# 3133
# (31,)
# 3134
# (83,)
# 3135
# (78,)
# 3136
# (78,)
# 3137
# (73,)
# 3138
# (74,)
# 3139
# (95,)
# 3140
# (96,)
# 3141
# (92,)
# 3142
# (91,)
# 3143
# (88,)
# 3144
# (96,)
# 3145
# (82,)
# 3146
# (99,)
# 3147
# (94,)
# 3148
# (82,)
# 3149
# (185,)
# 3150
# (189,)
# 3151
# (217,)
# 3152
# (205,)
# 3153
# (211,)
# 3154
# (73,)
# 3155
# (85,)
# 3156
# (106,)
# 3157
# (93,)
# 3158
# (77,)
# 3159
# (38,)
# 3160
# (35,)
# 3161
# (38,)
# 3162
# (39,)
# 3163
# (28,)
# 3164
# (35,)
# 3165
# (29,)
# 3166
# (33,)
# 3167
# (26,)
# 3168
# (31,)
# 3169
# (28,)
# 3170
# (30,)
# 3171
# (28,)
# 3172
# (28,)
# 3173
# (29,)
# 3174
# (51,)
# 3175
# (50,)
# 3176
# (41,)
# 3177
# (38,)
# 3178
# (35,)
# 3179
# (40,)
# 3180
# (42,)
# 3181
# (38,)
# 3182
# (44,)
# 3183
# (37,)
# 3184
# (32,)
# 3185
# (33,)
# 3186
# (43,)
# 3187
# (37,)
# 3188
# (38,)
# 3189
# (3,)
# 3190
# (5,)
# 3191
# (4,)
# 3192
# (4,)
# 3193
# (4,)
# 3194
# (23,)
# 3195
# (20,)
# 3196
# (21,)
# 3197
# (22,)
# 3198
# (20,)
# 3199
# (51,)
# 3200
# (62,)
# 3201
# (54,)
# 3202
# (48,)
# 3203
# (62,)
# 3204
# (38,)
# 3205
# (45,)
# 3206
# (41,)
# 3207
# (38,)
# 3208
# (42,)
# 3209
# (145,)
# 3210
# (162,)
# 3211
# (180,)
# 3212
# (182,)
# 3213
# (124,)
# 3214
# (100,)
# 3215
# (101,)
# 3216
# (99,)
# 3217
# (107,)
# 3218
# (123,)
# 3219
# (149,)
# 3220
# (148,)
# 3221
# (150,)
# 3222
# (149,)
# 3223
# (154,)
# 3224
# (191,)
# 3225
# (190,)
# 3226
# (189,)
# 3227
# (199,)
# 3228
# (195,)
# 3229
# (18,)
# 3230
# (17,)
# 3231
# (28,)
# 3232
# (21,)
# 3233
# (21,)
# 3234
# (2,)
# 3235
# (0,)
# 3236
# (1,)
# 3237
# (49,)
# 3238
# (133,)
# 3239
# (141,)
# 3240
# (70,)
# 3241
# (87,)
# 3242
# (71,)
# 3243
# (68,)
# 3244
# (66,)
# 3245
# (68,)
# 3246
# (66,)
# 3247
# (92,)
# 3248
# (92,)
# 3249
# (96,)
# 3250
# (68,)
# 3251
# (105,)
# 3252
# (96,)
# 3253
# (75,)
# 3254
# (82,)
# 3255
# (95,)
# 3256
# (79,)
# 3257
# (34,)
# 3258
# (47,)
# 3259
# (42,)
# 3260
# (36,)
# 3261
# (43,)
# 3262
# (67,)
# 3263
# (68,)
# 3264
# (72,)
# 3265
# (67,)
# 3266
# (74,)
# 3267
# (78,)
# 3268
# (56,)
# 3269
# (68,)
# 3270
# (68,)
# 3271
# (72,)
# 3272
# (49,)
# 3273
# (56,)
# 3274
# (43,)
# 3275
# (66,)
# 3276
# (47,)
# 3277
# (57,)
# 3278
# (75,)
# 3279
# (69,)
# 3280
# (63,)
# 3281
# (65,)
# 3282
# (18,)
# 3283
# (15,)
# 3284
# (24,)
# 3285
# (17,)
# 3286
# (15,)
# 3287
# (28,)
# 3288
# (30,)
# 3289
# (26,)
# 3290
# (33,)
# 3291
# (35,)
# 3292
# (195,)
# 3293
# (169,)
# 3294
# (174,)
# 3295
# (183,)
# 3296
# (183,)
# 3297
# (163,)
# 3298
# (158,)
# 3299
# (166,)
# 3300
# (159,)
# 3301
# (168,)
# 3302
# (162,)
# 3303
# (170,)
# 3304
# (185,)
# 3305
# (197,)
# 3306
# (183,)
# 3307
# (231,)
# 3308
# (234,)
# 3309
# (233,)
# 3310
# (241,)
# 3311
# (243,)
# 3312
# (188,)
# 3313
# (186,)
# 3314
# (180,)
# 3315
# (185,)
# 3316
# (188,)
# 3317
# (68,)
# 3318
# (62,)
# 3319
# (67,)
# 3320
# (62,)
# 3321
# (65,)
# 3322
# (23,)
# 3323
# (25,)
# 3324
# (27,)
# 3325
# (13,)
# 3326
# (11,)
# 3327
# (41,)
# 3328
# (44,)
# 3329
# (44,)
# 3330
# (40,)
# 3331
# (35,)
# 3332
# (27,)
# 3333
# (27,)
# 3334
# (26,)
# 3335
# (28,)
# 3336
# (20,)
# 3337
# (48,)
# 3338
# (59,)
# 3339
# (53,)
# 3340
# (43,)
# 3341
# (58,)
# 3342
# (11,)
# 3343
# (18,)
# 3344
# (12,)
# 3345
# (16,)
# 3346
# (15,)
# 3347
# (22,)
# 3348
# (22,)
# 3349
# (19,)
# 3350
# (19,)
# 3351
# (27,)
# 3352
# (34,)
# 3353
# (30,)
# 3354
# (29,)
# 3355
# (27,)
# 3356
# (30,)
# 3357
# (9,)
# 3358
# (11,)
# 3359
# (12,)
# 3360
# (10,)
# 3361
# (10,)
# 3362
# (13,)
# 3363
# (15,)
# 3364
# (14,)
# 3365
# (13,)
# 3366
# (16,)
# 3367
# (62,)
# 3368
# (46,)
# 3369
# (57,)
# 3370
# (54,)
# 3371
# (56,)
# 3372
# (75,)
# 3373
# (78,)
# 3374
# (96,)
# 3375
# (67,)
# 3376
# (96,)
# 3377
# (23,)
# 3378
# (24,)
# 3379
# (20,)
# 3380
# (22,)
# 3381
# (20,)
# 3382
# (16,)
# 3383
# (19,)
# 3384
# (20,)
# 3385
# (20,)
# 3386
# (18,)
# 3387
# (5,)
# 3388
# (13,)
# 3389
# (5,)
# 3390
# (6,)
# 3391
# (5,)
# 3392
# (135,)
# 3393
# (150,)
# 3394
# (134,)
# 3395
# (118,)
# 3396
# (152,)
# 3397
# (64,)
# 3398
# (59,)
# 3399
# (56,)
# 3400
# (62,)
# 3401
# (57,)
# 3402
# (165,)
# 3403
# (186,)
# 3404
# (199,)
# 3405
# (209,)
# 3406
# (178,)
# 3407
# (28,)
# 3408
# (37,)
# 3409
# (28,)
# 3410
# (40,)
# 3411
# (36,)
# 3412
# (35,)
# 3413
# (32,)
# 3414
# (33,)
# 3415
# (49,)
# 3416
# (32,)
# 3417
# (17,)
# 3418
# (25,)
# 3419
# (22,)
# 3420
# (22,)
# 3421
# (23,)
# 3422
# (86,)
# 3423
# (97,)
# 3424
# (99,)
# 3425
# (91,)
# 3426
# (78,)
# 3427
# (148,)
# 3428
# (178,)
# 3429
# (161,)
# 3430
# (169,)
# 3431
# (141,)
# 3432
# (104,)
# 3433
# (114,)
# 3434
# (101,)
# 3435
# (103,)
# 3436
# (104,)
# 3437
# (76,)
# 3438
# (67,)
# 3439
# (89,)
# 3440
# (66,)
# 3441
# (87,)
# 3442
# (34,)
# 3443
# (37,)
# 3444
# (32,)
# 3445
# (26,)
# 3446
# (37,)
# 3447
# (75,)
# 3448
# (70,)
# 3449
# (66,)
# 3450
# (73,)
# 3451
# (74,)
# 3452
# (26,)
# 3453
# (24,)
# 3454
# (27,)
# 3455
# (28,)
# 3456
# (24,)
# 3457
# (83,)
# 3458
# (74,)
# 3459
# (84,)
# 3460
# (82,)
# 3461
# (84,)
# 3462
# (97,)
# 3463
# (93,)
# 3464
# (90,)
# 3465
# (96,)
# 3466
# (95,)
# 3467
# (48,)
# 3468
# (49,)
# 3469
# (61,)
# 3470
# (57,)
# 3471
# (56,)
# 3472
# (45,)
# 3473
# (66,)
# 3474
# (52,)
# 3475
# (56,)
# 3476
# (56,)
# 3477
# (29,)
# 3478
# (32,)
# 3479
# (47,)
# 3480
# (33,)
# 3481
# (29,)
# 3482
# (49,)
# 3483
# (48,)
# 3484
# (43,)
# 3485
# (46,)
# 3486
# (28,)
# 3487
# (69,)
# 3488
# (68,)
# 3489
# (73,)
# 3490
# (75,)
# 3491
# (57,)
# 3492
# (52,)
# 3493
# (29,)
# 3494
# (40,)
# 3495
# (39,)
# 3496
# (55,)
# 3497
# (31,)
# 3498
# (28,)
# 3499
# (29,)
# 3500
# (42,)
# 3501
# (28,)
# 3502
# (42,)
# 3503
# (49,)
# 3504
# (40,)
# 3505
# (42,)
# 3506
# (39,)
# 3507
# (42,)
# 3508
# (38,)
# 3509
# (30,)
# 3510
# (31,)
# 3511
# (44,)
# 3512
# (51,)
# 3513
# (50,)
# 3514
# (55,)
# 3515
# (50,)
# 3516
# (49,)
# 3517
# (69,)
# 3518
# (62,)
# 3519
# (60,)
# 3520
# (64,)
# 3521
# (63,)
# 3522
# (71,)
# 3523
# (68,)
# 3524
# (73,)
# 3525
# (72,)
# 3526
# (75,)
# 3527
# (68,)
# 3528
# (59,)
# 3529
# (60,)
# 3530
# (53,)
# 3531
# (66,)
# 3532
# (95,)
# 3533
# (92,)
# 3534
# (91,)
# 3535
# (94,)
# 3536
# (90,)
# 3537
# (41,)
# 3538
# (33,)
# 3539
# (44,)
# 3540
# (32,)
# 3541
# (33,)
# 3542
# (13,)
# 3543
# (13,)
# 3544
# (15,)
# 3545
# (18,)
# 3546
# (15,)
# 3547
# (168,)
# 3548
# (122,)
# 3549
# (140,)
# 3550
# (133,)
# 3551
# (160,)
# 3552
# (160,)
# 3553
# (173,)
# 3554
# (152,)
# 3555
# (206,)
# 3556
# (176,)
# 3557
# (203,)
# 3558
# (224,)
# 3559
# (200,)
# 3560
# (204,)
# 3561
# (171,)
# 3562
# (27,)
# 3563
# (30,)
# 3564
# (30,)
# 3565
# (28,)
# 3566
# (29,)
# 3567
# (28,)
# 3568
# (27,)
# 3569
# (39,)
# 3570
# (34,)
# 3571
# (40,)
# 3572
# (17,)
# 3573
# (24,)
# 3574
# (16,)
# 3575
# (21,)
# 3576
# (16,)
# 3577
# (28,)
# 3578
# (29,)
# 3579
# (29,)
# 3580
# (31,)
# 3581
# (31,)
# 3582
# (78,)
# 3583
# (53,)
# 3584
# (85,)
# 3585
# (90,)
# 3586
# (72,)
# 3587
# (23,)
# 3588
# (16,)
# 3589
# (20,)
# 3590
# (26,)
# 3591
# (18,)
# 3592
# (57,)
# 3593
# (57,)
# 3594
# (53,)
# 3595
# (59,)
# 3596
# (62,)
# 3597
# (39,)
# 3598
# (35,)
# 3599
# (44,)
# 3600
# (38,)
# 3601
# (36,)
# 3602
# (0,)
# 3603
# (0,)
# 3604
# (0,)
# 3605
# (0,)
# 3606
# (0,)
# 3607
# (0,)
# 3608
# (0,)
# 3609
# (0,)
# 3610
# (0,)
# 3611
# (0,)
# 3612
# (62,)
# 3613
# (66,)
# 3614
# (60,)
# 3615
# (75,)
# 3616
# (59,)
# 3617
# (33,)
# 3618
# (34,)
# 3619
# (15,)
# 3620
# (30,)
# 3621
# (33,)
# 3622
# (61,)
# 3623
# (79,)
# 3624
# (61,)
# 3625
# (70,)
# 3626
# (83,)
# 3627
# (90,)
# 3628
# (84,)
# 3629
# (96,)
# 3630
# (91,)
# 3631
# (85,)
# 3632
# (45,)
# 3633
# (50,)
# 3634
# (54,)
# 3635
# (49,)
# 3636
# (53,)
# 3637
# (68,)
# 3638
# (83,)
# 3639
# (63,)
# 3640
# (72,)
# 3641
# (68,)
# 3642
# (69,)
# 3643
# (58,)
# 3644
# (74,)
# 3645
# (63,)
# 3646
# (50,)
# 3647
# (16,)
# 3648
# (26,)
# 3649
# (29,)
# 3650
# (27,)
# 3651
# (18,)
# 3652
# (32,)
# 3653
# (31,)
# 3654
# (32,)
# 3655
# (37,)
# 3656
# (34,)
# 3657
# (112,)
# 3658
# (108,)
# 3659
# (112,)
# 3660
# (106,)
# 3661
# (109,)
# 3662
# (76,)
# 3663
# (69,)
# 3664
# (69,)
# 3665
# (63,)
# 3666
# (69,)
# 3667
# (80,)
# 3668
# (83,)
# 3669
# (84,)
# 3670
# (79,)
# 3671
# (82,)
# 3672
# (63,)
# 3673
# (66,)
# 3674
# (57,)
# 3675
# (56,)
# 3676
# (57,)
# 3677
# (93,)
# 3678
# (90,)
# 3679
# (89,)
# 3680
# (95,)
# 3681
# (96,)
# 3682
# (62,)
# 3683
# (61,)
# 3684
# (62,)
# 3685
# (61,)
# 3686
# (62,)
# 3687
# (63,)
# 3688
# (64,)
# 3689
# (62,)
# 3690
# (67,)
# 3691
# (63,)
# 3692
# (79,)
# 3693
# (85,)
# 3694
# (80,)
# 3695
# (74,)
# 3696
# (86,)
# 3697
# (39,)
# 3698
# (48,)
# 3699
# (47,)
# 3700
# (47,)
# 3701
# (47,)
# 3702
# (73,)
# 3703
# (79,)
# 3704
# (71,)
# 3705
# (76,)
# 3706
# (82,)
# 3707
# (39,)
# 3708
# (37,)
# 3709
# (37,)
# 3710
# (38,)
# 3711
# (38,)
# 3712
# (5,)
# 3713
# (6,)
# 3714
# (6,)
# 3715
# (6,)
# 3716
# (6,)
# 3717
# (6,)
# 3718
# (13,)
# 3719
# (10,)
# 3720
# (6,)
# 3721
# (6,)
# 3722
# (213,)
# 3723
# (219,)
# 3724
# (217,)
# 3725
# (221,)
# 3726
# (241,)
# 3727
# (45,)
# 3728
# (47,)
# 3729
# (40,)
# 3730
# (49,)
# 3731
# (45,)
# 3732
# (25,)
# 3733
# (24,)
# 3734
# (25,)
# 3735
# (27,)
# 3736
# (24,)
# 3737
# (107,)
# 3738
# (94,)
# 3739
# (91,)
# 3740
# (89,)
# 3741
# (83,)
# 3742
# (41,)
# 3743
# (40,)
# 3744
# (41,)
# 3745
# (41,)
# 3746
# (40,)
# 3747
# (15,)
# 3748
# (15,)
# 3749
# (14,)
# 3750
# (25,)
# 3751
# (15,)
# 3752
# (75,)
# 3753
# (63,)
# 3754
# (71,)
# 3755
# (65,)
# 3756
# (72,)
# 3757
# (53,)
# 3758
# (45,)
# 3759
# (57,)
# 3760
# (44,)
# 3761
# (39,)
# 3762
# (25,)
# 3763
# (30,)
# 3764
# (23,)
# 3765
# (27,)
# 3766
# (25,)
# 3767
# (122,)
# 3768
# (146,)
# 3769
# (122,)
# 3770
# (108,)
# 3771
# (128,)
# 3772
# (112,)
# 3773
# (118,)
# 3774
# (109,)
# 3775
# (167,)
# 3776
# (132,)
# 3777
# (97,)
# 3778
# (104,)
# 3779
# (149,)
# 3780
# (129,)
# 3781
# (136,)
# 3782
# (136,)
# 3783
# (189,)
# 3784
# (208,)
# 3785
# (167,)
# 3786
# (197,)
# 3787
# (181,)
# 3788
# (195,)
# 3789
# (159,)
# 3790
# (189,)
# 3791
# (177,)
# 3792
# (212,)
# 3793
# (231,)
# 3794
# (244,)
# 3795
# (226,)
# 3796
# (220,)
# 3797
# (146,)
# 3798
# (141,)
# 3799
# (117,)
# 3800
# (112,)
# 3801
# (116,)
# 3802
# (108,)
# 3803
# (99,)
# 3804
# (109,)
# 3805
# (130,)
# 3806
# (96,)
# 3807
# (99,)
# 3808
# (98,)
# 3809
# (93,)
# 3810
# (90,)
# 3811
# (97,)
# 3812
# (65,)
# 3813
# (60,)
# 3814
# (65,)
# 3815
# (61,)
# 3816
# (62,)
# 3817
# (63,)
# 3818
# (72,)
# 3819
# (66,)
# 3820
# (67,)
# 3821
# (62,)
# 3822
# (55,)
# 3823
# (64,)
# 3824
# (64,)
# 3825
# (51,)
# 3826
# (71,)
# 3827
# (23,)
# 3828
# (22,)
# 3829
# (28,)
# 3830
# (23,)
# 3831
# (22,)
# 3832
# (34,)
# 3833
# (34,)
# 3834
# (31,)
# 3835
# (45,)
# 3836
# (36,)
# 3837
# (42,)
# 3838
# (45,)
# 3839
# (31,)
# 3840
# (63,)
# 3841
# (45,)
# 3842
# (36,)
# 3843
# (27,)
# 3844
# (33,)
# 3845
# (40,)
# 3846
# (36,)
# 3847
# (16,)
# 3848
# (9,)
# 3849
# (15,)
# 3850
# (15,)
# 3851
# (14,)
# 3852
# (72,)
# 3853
# (75,)
# 3854
# (73,)
# 3855
# (72,)
# 3856
# (71,)
# 3857
# (150,)
# 3858
# (147,)
# 3859
# (125,)
# 3860
# (129,)
# 3861
# (146,)
# 3862
# (31,)
# 3863
# (28,)
# 3864
# (21,)
# 3865
# (31,)
# 3866
# (27,)
# 3867
# (44,)
# 3868
# (43,)
# 3869
# (53,)
# 3870
# (46,)
# 3871
# (43,)
# 3872
# (39,)
# 3873
# (41,)
# 3874
# (41,)
# 3875
# (35,)
# 3876
# (34,)
# 3877
# (46,)
# 3878
# (40,)
# 3879
# (43,)
# 3880
# (41,)
# 3881
# (49,)
# 3882
# (32,)
# 3883
# (34,)
# 3884
# (37,)
# 3885
# (37,)
# 3886
# (34,)
# 3887
# (19,)
# 3888
# (21,)
# 3889
# (19,)
# 3890
# (21,)
# 3891
# (21,)
# 3892
# (107,)
# 3893
# (94,)
# 3894
# (107,)
# 3895
# (110,)
# 3896
# (112,)
# 3897
# (41,)
# 3898
# (36,)
# 3899
# (32,)
# 3900
# (31,)
# 3901
# (43,)
# 3902
# (41,)
# 3903
# (40,)
# 3904
# (31,)
# 3905
# (32,)
# 3906
# (38,)
# 3907
# (76,)
# 3908
# (78,)
# 3909
# (58,)
# 3910
# (76,)
# 3911
# (74,)
# 3912
# (26,)
# 3913
# (27,)
# 3914
# (30,)
# 3915
# (46,)
# 3916
# (36,)
# 3917
# (47,)
# 3918
# (41,)
# 3919
# (42,)
# 3920
# (41,)
# 3921
# (43,)
# 3922
# (22,)
# 3923
# (29,)
# 3924
# (37,)
# 3925
# (27,)
# 3926
# (27,)
# 3927
# (77,)
# 3928
# (64,)
# 3929
# (82,)
# 3930
# (87,)
# 3931
# (73,)
# 3932
# (105,)
# 3933
# (95,)
# 3934
# (85,)
# 3935
# (90,)
# 3936
# (82,)
# 3937
# (71,)
# 3938
# (71,)
# 3939
# (64,)
# 3940
# (66,)
# 3941
# (65,)
# 3942
# (12,)
# 3943
# (7,)
# 3944
# (8,)
# 3945
# (13,)
# 3946
# (7,)
# 3947
# (32,)
# 3948
# (37,)
# 3949
# (41,)
# 3950
# (34,)
# 3951
# (32,)
# 3952
# (94,)
# 3953
# (103,)
# 3954
# (114,)
# 3955
# (109,)
# 3956
# (104,)
# 3957
# (82,)
# 3958
# (126,)
# 3959
# (106,)
# 3960
# (92,)
# 3961
# (90,)
# 3962
# (113,)
# 3963
# (121,)
# 3964
# (118,)
# 3965
# (116,)
# 3966
# (120,)
# 3967
# (54,)
# 3968
# (80,)
# 3969
# (79,)
# 3970
# (83,)
# 3971
# (77,)
# 3972
# (70,)
# 3973
# (66,)
# 3974
# (73,)
# 3975
# (74,)
# 3976
# (56,)
# 3977
# (47,)
# 3978
# (61,)
# 3979
# (56,)
# 3980
# (56,)
# 3981
# (46,)
# 3982
# (65,)
# 3983
# (71,)
# 3984
# (87,)
# 3985
# (100,)
# 3986
# (70,)
# 3987
# (66,)
# 3988
# (63,)
# 3989
# (63,)
# 3990
# (58,)
# 3991
# (59,)
# 3992
# (51,)
# 3993
# (41,)
# 3994
# (40,)
# 3995
# (55,)
# 3996
# (64,)
# 3997
# (50,)
# 3998
# (67,)
# 3999
# (65,)
# 4000
# (64,)
# 4001
# (69,)
# 4002
# (71,)
# 4003
# (62,)
# 4004
# (64,)
# 4005
# (57,)
# 4006
# (64,)
# 4007
# (40,)
# 4008
# (42,)
# 4009
# (43,)
# 4010
# (39,)
# 4011
# (39,)
# 4012
# (35,)
# 4013
# (36,)
# 4014
# (43,)
# 4015
# (29,)
# 4016
# (31,)
# 4017
# (58,)
# 4018
# (58,)
# 4019
# (63,)
# 4020
# (66,)
# 4021
# (61,)
# 4022
# (45,)
# 4023
# (51,)
# 4024
# (52,)
# 4025
# (42,)
# 4026
# (49,)
# 4027
# (67,)
# 4028
# (85,)
# 4029
# (76,)
# 4030
# (94,)
# 4031
# (84,)
# 4032
# (28,)
# 4033
# (28,)
# 4034
# (50,)
# 4035
# (56,)
# 4036
# (42,)
# 4037
# (80,)
# 4038
# (82,)
# 4039
# (80,)
# 4040
# (72,)
# 4041
# (74,)
# 4042
# (23,)
# 4043
# (12,)
# 4044
# (24,)
# 4045
# (28,)
# 4046
# (12,)
# 4047
# (94,)
# 4048
# (89,)
# 4049
# (79,)
# 4050
# (92,)
# 4051
# (89,)
# 4052
# (61,)
# 4053
# (56,)
# 4054
# (46,)
# 4055
# (48,)
# 4056
# (56,)
# 4057
# (56,)
# 4058
# (56,)
# 4059
# (53,)
# 4060
# (62,)
# 4061
# (59,)
# 4062
# (53,)
# 4063
# (52,)
# 4064
# (50,)
# 4065
# (67,)
# 4066
# (49,)
# 4067
# (24,)
# 4068
# (15,)
# 4069
# (17,)
# 4070
# (24,)
# 4071
# (21,)
# 4072
# (58,)
# 4073
# (55,)
# 4074
# (56,)
# 4075
# (60,)
# 4076
# (59,)
# 4077
# (66,)
# 4078
# (63,)
# 4079
# (65,)
# 4080
# (66,)
# 4081
# (68,)
# 4082
# (16,)
# 4083
# (16,)
# 4084
# (15,)
# 4085
# (14,)
# 4086
# (23,)
# 4087
# (46,)
# 4088
# (57,)
# 4089
# (47,)
# 4090
# (47,)
# 4091
# (52,)
# 4092
# (28,)
# 4093
# (27,)
# 4094
# (29,)
# 4095
# (29,)
# 4096
# (24,)
# 4097
# (78,)
# 4098
# (83,)
# 4099
# (76,)
# 4100
# (70,)
# 4101
# (81,)
# 4102
# (31,)
# 4103
# (38,)
# 4104
# (29,)
# 4105
# (34,)
# 4106
# (27,)
# 4107
# (22,)
# 4108
# (25,)
# 4109
# (21,)
# 4110
# (19,)
# 4111
# (23,)
# 4112
# (12,)
# 4113
# (9,)
# 4114
# (5,)
# 4115
# (14,)
# 4116
# (12,)
# 4117
# (24,)
# 4118
# (28,)
# 4119
# (22,)
# 4120
# (31,)
# 4121
# (22,)
# 4122
# (89,)
# 4123
# (96,)
# 4124
# (82,)
# 4125
# (96,)
# 4126
# (97,)
# 4127
# (39,)
# 4128
# (42,)
# 4129
# (42,)
# 4130
# (33,)
# 4131
# (42,)
# 4132
# (50,)
# 4133
# (53,)
# 4134
# (59,)
# 4135
# (62,)
# 4136
# (58,)
# 4137
# (39,)
# 4138
# (61,)
# 4139
# (50,)
# 4140
# (39,)
# 4141
# (36,)
# 4142
# (117,)
# 4143
# (123,)
# 4144
# (116,)
# 4145
# (103,)
# 4146
# (112,)
# 4147
# (45,)
# 4148
# (32,)
# 4149
# (40,)
# 4150
# (43,)
# 4151
# (48,)
# 4152
# (84,)
# 4153
# (85,)
# 4154
# (76,)
# 4155
# (85,)
# 4156
# (93,)
# 4157
# (65,)
# 4158
# (74,)
# 4159
# (67,)
# 4160
# (43,)
# 4161
# (64,)
# 4162
# (60,)
# 4163
# (69,)
# 4164
# (83,)
# 4165
# (65,)
# 4166
# (65,)
# 4167
# (50,)
# 4168
# (47,)
# 4169
# (64,)
# 4170
# (55,)
# 4171
# (45,)
# 4172
# (56,)
# 4173
# (64,)
# 4174
# (66,)
# 4175
# (53,)
# 4176
# (65,)
# 4177
# (23,)
# 4178
# (20,)
# 4179
# (27,)
# 4180
# (26,)
# 4181
# (25,)
# 4182
# (99,)
# 4183
# (71,)
# 4184
# (85,)
# 4185
# (67,)
# 4186
# (107,)
# 4187
# (69,)
# 4188
# (69,)
# 4189
# (73,)
# 4190
# (68,)
# 4191
# (70,)
# 4192
# (45,)
# 4193
# (44,)
# 4194
# (42,)
# 4195
# (45,)
# 4196
# (38,)
# 4197
# (8,)
# 4198
# (1,)
# 4199
# (0,)
# 4200
# (0,)
# 4201
# (1,)
# 4202
# (9,)
# 4203
# (9,)
# 4204
# (5,)
# 4205
# (5,)
# 4206
# (6,)
# 4207
# (38,)
# 4208
# (44,)
# 4209
# (39,)
# 4210
# (38,)
# 4211
# (38,)
# 4212
# (86,)
# 4213
# (73,)
# 4214
# (87,)
# 4215
# (84,)
# 4216
# (81,)
# 4217
# (62,)
# 4218
# (66,)
# 4219
# (52,)
# 4220
# (55,)
# 4221
# (69,)
# 4222
# (48,)
# 4223
# (48,)
# 4224
# (41,)
# 4225
# (45,)
# 4226
# (51,)
# 4227
# (23,)
# 4228
# (32,)
# 4229
# (21,)
# 4230
# (29,)
# 4231
# (21,)
# 4232
# (53,)
# 4233
# (55,)
# 4234
# (55,)
# 4235
# (54,)
# 4236
# (54,)
# 4237
# (63,)
# 4238
# (56,)
# 4239
# (60,)
# 4240
# (63,)
# 4241
# (59,)
# 4242
# (42,)
# 4243
# (43,)
# 4244
# (36,)
# 4245
# (37,)
# 4246
# (44,)
# 4247
# (49,)
# 4248
# (60,)
# 4249
# (57,)
# 4250
# (54,)
# 4251
# (44,)
# 4252
# (12,)
# 4253
# (16,)
# 4254
# (15,)
# 4255
# (25,)
# 4256
# (16,)
# 4257
# (12,)
# 4258
# (9,)
# 4259
# (12,)
# 4260
# (10,)
# 4261
# (83,)
# 4262
# (86,)
# 4263
# (84,)
# 4264
# (79,)
# 4265
# (76,)
# 4266
# (77,)
# 4267
# (86,)
# 4268
# (83,)
# 4269
# (90,)
# 4270
# (84,)
# 4271
# (59,)
# 4272
# (78,)
# 4273
# (66,)
# 4274
# (64,)
# 4275
# (55,)
# 4276
# (23,)
# 4277
# (23,)
# 4278
# (22,)
# 4279
# (21,)
# 4280
# (21,)
# 4281
# (32,)
# 4282
# (35,)
# 4283
# (41,)
# 4284
# (34,)
# 4285
# (41,)
# 4286
# (42,)
# 4287
# (42,)
# 4288
# (30,)
# 4289
# (38,)
# 4290
# (50,)
# 4291
# (84,)
# 4292
# (79,)
# 4293
# (80,)
# 4294
# (85,)
# 4295
# (88,)
# 4296
# (28,)
# 4297
# (35,)
# 4298
# (33,)
# 4299
# (39,)
# 4300
# (30,)
# 4301
# (19,)
# 4302
# (21,)
# 4303
# (20,)
# 4304
# (19,)
# 4305
# (77,)
# 4306
# (73,)
# 4307
# (74,)
# 4308
# (78,)
# 4309
# (72,)
# 4310
# (157,)
# 4311
# (147,)
# 4312
# (162,)
# 4313
# (152,)
# 4314
# (110,)
# 4315
# (163,)
# 4316
# (143,)
# 4317
# (139,)
# 4318
# (152,)
# 4319
# (142,)
# 4320
# (213,)
# 4321
# (248,)
# 4322
# (257,)
# 4323
# (209,)
# 4324
# (217,)
# 4325
# (25,)
# 4326
# (25,)
# 4327
# (32,)
# 4328
# (29,)
# 4329
# (30,)
# 4330
# (21,)
# 4331
# (19,)
# 4332
# (22,)
# 4333
# (20,)
# 4334
# (29,)
# 4335
# (34,)
# 4336
# (35,)
# 4337
# (29,)
# 4338
# (23,)
# 4339
# (27,)
# 4340
# (30,)
# 4341
# (23,)
# 4342
# (23,)
# 4343
# (25,)
# 4344
# (24,)
# 4345
# (73,)
# 4346
# (72,)
# 4347
# (75,)
# 4348
# (70,)
# 4349
# (70,)
# 4350
# (43,)
# 4351
# (35,)
# 4352
# (48,)
# 4353
# (44,)
# 4354
# (34,)
# 4355
# (32,)
# 4356
# (38,)
# 4357
# (41,)
# 4358
# (36,)
# 4359
# (37,)
# 4360
# (19,)
# 4361
# (19,)
# 4362
# (19,)
# 4363
# (22,)
# 4364
# (23,)
# 4365
# (50,)
# 4366
# (36,)
# 4367
# (40,)
# 4368
# (51,)
# 4369
# (50,)
# 4370
# (37,)
# 4371
# (34,)
# 4372
# (35,)
# 4373
# (34,)
# 4374
# (50,)
# 4375
# (122,)
# 4376
# (157,)
# 4377
# (152,)
# 4378
# (120,)
# 4379
# (143,)
# 4380
# (154,)
# 4381
# (147,)
# 4382
# (153,)
# 4383
# (167,)
# 4384
# (160,)
# 4385
# (173,)
# 4386
# (227,)
# 4387
# (152,)
# 4388
# (192,)
# 4389
# (187,)
# 4390
# (34,)
# 4391
# (31,)
# 4392
# (34,)
# 4393
# (40,)
# 4394
# (26,)
# 4395
# (36,)
# 4396
# (38,)
# 4397
# (29,)
# 4398
# (36,)
# 4399
# (36,)
# 4400
# (41,)
# 4401
# (40,)
# 4402
# (33,)
# 4403
# (35,)
# 4404
# (32,)
# 4405
# (55,)
# 4406
# (57,)
# 4407
# (50,)
# 4408
# (60,)
# 4409
# (45,)
# ...
# (24,)
# 9308
# (47,)
# 9309
# (32,)
# 9310
# (87,)
# 9311
# (80,)
# 9312
# (83,)
# 9313
# (81,)
# 9314
# (78,)
# 9315
# (86,)
# 9316
# (111,)
# 9317
# (109,)
# 9318
# (108,)
# 9319
# (99,)
# 9320
# (83,)
# 9321
# (75,)
# 9322
# (76,)
# 9323
# (87,)
# 9324
# (88,)
# 9325
# (66,)
# 9326
# (68,)
# 9327
# (64,)
# 9328
# (68,)
# 9329
# (65,)
# 9330
# (48,)
# 9331
# (32,)
# 9332
# (45,)
# 9333
# (37,)
# 9334
# (48,)
# 9335
# (59,)
# 9336
# (57,)
# 9337
# (59,)
# 9338
# (57,)
# 9339
# (53,)
# 9340
# (69,)
# 9341
# (58,)
# 9342
# (55,)
# 9343
# (76,)
# 9344
# (60,)
# 9345
# (58,)
# 9346
# (67,)
# 9347
# (55,)
# 9348
# (62,)
# 9349
# (54,)
# 9350
# (16,)
# 9351
# (19,)
# 9352
# (19,)
# 9353
# (15,)
# 9354
# (22,)
# 9355
# (15,)
# 9356
# (10,)
# 9357
# (11,)
# 9358
# (16,)
# 9359
# (11,)
# 9360
# (13,)
# 9361
# (18,)
# 9362
# (16,)
# 9363
# (16,)
# 9364
# (11,)
# 9365
# (126,)
# 9366
# (121,)
# 9367
# (116,)
# 9368
# (124,)
# 9369
# (129,)
# 9370
# (137,)
# 9371
# (136,)
# 9372
# (138,)
# 9373
# (135,)
# 9374
# (139,)
# 9375
# (29,)
# 9376
# (17,)
# 9377
# (20,)
# 9378
# (31,)
# 9379
# (22,)
# 9380
# (38,)
# 9381
# (41,)
# 9382
# (44,)
# 9383
# (40,)
# 9384
# (43,)
# 9385
# (36,)
# 9386
# (36,)
# 9387
# (32,)
# 9388
# (34,)
# 9389
# (33,)
# 9390
# (29,)
# 9391
# (36,)
# 9392
# (36,)
# 9393
# (30,)
# 9394
# (37,)
# 9395
# (86,)
# 9396
# (78,)
# 9397
# (77,)
# 9398
# (88,)
# 9399
# (73,)
# 9400
# (61,)
# 9401
# (60,)
# 9402
# (79,)
# 9403
# (75,)
# 9404
# (87,)
# 9405
# (51,)
# 9406
# (58,)
# 9407
# (51,)
# 9408
# (60,)
# 9409
# (46,)
# 9410
# (42,)
# 9411
# (60,)
# 9412
# (35,)
# 9413
# (47,)
# 9414
# (51,)
# 9415
# (65,)
# 9416
# (49,)
# 9417
# (60,)
# 9418
# (76,)
# 9419
# (48,)
# 9420
# (41,)
# 9421
# (42,)
# 9422
# (49,)
# 9423
# (47,)
# 9424
# (47,)
# 9425
# (36,)
# 9426
# (29,)
# 9427
# (44,)
# 9428
# (32,)
# 9429
# (37,)
# 9430
# (37,)
# 9431
# (29,)
# 9432
# (34,)
# 9433
# (22,)
# 9434
# (31,)
# 9435
# (47,)
# 9436
# (57,)
# 9437
# (60,)
# 9438
# (59,)
# 9439
# (54,)
# 9440
# (25,)
# 9441
# (18,)
# 9442
# (22,)
# 9443
# (29,)
# 9444
# (30,)
# 9445
# (35,)
# 9446
# (35,)
# 9447
# (29,)
# 9448
# (45,)
# 9449
# (45,)
# 9450
# (59,)
# 9451
# (59,)
# 9452
# (59,)
# 9453
# (59,)
# 9454
# (57,)
# 9455
# (21,)
# 9456
# (19,)
# 9457
# (22,)
# 9458
# (28,)
# 9459
# (21,)
# 9460
# (234,)
# 9461
# (217,)
# 9462
# (193,)
# 9463
# (247,)
# 9464
# (256,)
# 9465
# (21,)
# 9466
# (26,)
# 9467
# (34,)
# 9468
# (30,)
# 9469
# (34,)
# 9470
# (35,)
# 9471
# (46,)
# 9472
# (50,)
# 9473
# (52,)
# 9474
# (57,)
# 9475
# (19,)
# 9476
# (25,)
# 9477
# (24,)
# 9478
# (17,)
# 9479
# (18,)
# 9480
# (20,)
# 9481
# (18,)
# 9482
# (17,)
# 9483
# (17,)
# 9484
# (15,)
# 9485
# (38,)
# 9486
# (37,)
# 9487
# (39,)
# 9488
# (50,)
# 9489
# (46,)
# 9490
# (10,)
# 9491
# (20,)
# 9492
# (9,)
# 9493
# (9,)
# 9494
# (11,)
# 9495
# (14,)
# 9496
# (16,)
# 9497
# (12,)
# 9498
# (6,)
# 9499
# (6,)
# 9500
# (76,)
# 9501
# (78,)
# 9502
# (75,)
# 9503
# (67,)
# 9504
# (80,)
# 9505
# (77,)
# 9506
# (74,)
# 9507
# (71,)
# 9508
# (61,)
# 9509
# (63,)
# 9510
# (30,)
# 9511
# (33,)
# 9512
# (33,)
# 9513
# (27,)
# 9514
# (18,)
# 9515
# (9,)
# 9516
# (13,)
# 9517
# (12,)
# 9518
# (10,)
# 9519
# (11,)
# 9520
# (73,)
# 9521
# (82,)
# 9522
# (81,)
# 9523
# (79,)
# 9524
# (82,)
# 9525
# (18,)
# 9526
# (27,)
# 9527
# (23,)
# 9528
# (22,)
# 9529
# (20,)
# 9530
# (49,)
# 9531
# (49,)
# 9532
# (50,)
# 9533
# (56,)
# 9534
# (47,)
# 9535
# (68,)
# 9536
# (67,)
# 9537
# (77,)
# 9538
# (72,)
# 9539
# (70,)
# 9540
# (71,)
# 9541
# (65,)
# 9542
# (83,)
# 9543
# (69,)
# 9544
# (90,)
# 9545
# (31,)
# 9546
# (31,)
# 9547
# (31,)
# 9548
# (18,)
# 9549
# (26,)
# 9550
# (21,)
# 9551
# (18,)
# 9552
# (20,)
# 9553
# (19,)
# 9554
# (20,)
# 9555
# (13,)
# 9556
# (18,)
# 9557
# (18,)
# 9558
# (15,)
# 9559
# (12,)
# 9560
# (52,)
# 9561
# (44,)
# 9562
# (47,)
# 9563
# (51,)
# 9564
# (49,)
# 9565
# (35,)
# 9566
# (38,)
# 9567
# (26,)
# 9568
# (27,)
# 9569
# (32,)
# 9570
# (57,)
# 9571
# (58,)
# 9572
# (81,)
# 9573
# (78,)
# 9574
# (71,)
# 9575
# (45,)
# 9576
# (45,)
# 9577
# (40,)
# 9578
# (40,)
# 9579
# (37,)
# 9580
# (26,)
# 9581
# (23,)
# 9582
# (25,)
# 9583
# (24,)
# 9584
# (27,)
# 9585
# (68,)
# 9586
# (86,)
# 9587
# (72,)
# 9588
# (72,)
# 9589
# (76,)
# 9590
# (98,)
# 9591
# (95,)
# 9592
# (73,)
# 9593
# (75,)
# 9594
# (73,)
# 9595
# (68,)
# 9596
# (75,)
# 9597
# (81,)
# 9598
# (72,)
# 9599
# (73,)
# 9600
# (61,)
# 9601
# (64,)
# 9602
# (69,)
# 9603
# (65,)
# 9604
# (61,)
# 9605
# (39,)
# 9606
# (50,)
# 9607
# (41,)
# 9608
# (38,)
# 9609
# (37,)
# 9610
# (40,)
# 9611
# (36,)
# 9612
# (45,)
# 9613
# (50,)
# 9614
# (49,)
# 9615
# (91,)
# 9616
# (91,)
# 9617
# (92,)
# 9618
# (92,)
# 9619
# (91,)
# 9620
# (61,)
# 9621
# (59,)
# 9622
# (59,)
# 9623
# (62,)
# 9624
# (61,)
# 9625
# (72,)
# 9626
# (76,)
# 9627
# (63,)
# 9628
# (68,)
# 9629
# (67,)
# 9630
# (72,)
# 9631
# (70,)
# 9632
# (67,)
# 9633
# (69,)
# 9634
# (71,)
# 9635
# (43,)
# 9636
# (31,)
# 9637
# (49,)
# 9638
# (44,)
# 9639
# (36,)
# 9640
# (71,)
# 9641
# (77,)
# 9642
# (68,)
# 9643
# (61,)
# 9644
# (70,)
# 9645
# (55,)
# 9646
# (55,)
# 9647
# (63,)
# 9648
# (47,)
# 9649
# (49,)
# 9650
# (76,)
# 9651
# (73,)
# 9652
# (80,)
# 9653
# (82,)
# 9654
# (88,)
# 9655
# (71,)
# 9656
# (74,)
# 9657
# (66,)
# 9658
# (78,)
# 9659
# (71,)
# 9660
# (76,)
# 9661
# (79,)
# 9662
# (79,)
# 9663
# (78,)
# 9664
# (78,)
# 9665
# (58,)
# 9666
# (125,)
# 9667
# (123,)
# 9668
# (140,)
# 9669
# (137,)
# 9670
# (27,)
# 9671
# (16,)
# 9672
# (18,)
# 9673
# (20,)
# 9674
# (20,)
# 9675
# (44,)
# 9676
# (51,)
# 9677
# (29,)
# 9678
# (42,)
# 9679
# (28,)
# 9680
# (50,)
# 9681
# (51,)
# 9682
# (50,)
# 9683
# (51,)
# 9684
# (49,)
# 9685
# (29,)
# 9686
# (29,)
# 9687
# (30,)
# 9688
# (31,)
# 9689
# (31,)
# 9690
# (110,)
# 9691
# (115,)
# 9692
# (110,)
# 9693
# (90,)
# 9694
# (107,)
# 9695
# (27,)
# 9696
# (27,)
# 9697
# (25,)
# 9698
# (35,)
# 9699
# (27,)
# 9700
# (25,)
# 9701
# (19,)
# 9702
# (16,)
# 9703
# (28,)
# 9704
# (16,)
# 9705
# (61,)
# 9706
# (49,)
# 9707
# (67,)
# 9708
# (73,)
# 9709
# (68,)
# 9710
# (112,)
# 9711
# (103,)
# 9712
# (108,)
# 9713
# (106,)
# 9714
# (99,)
# 9715
# (79,)
# 9716
# (101,)
# 9717
# (84,)
# 9718
# (102,)
# 9719
# (102,)
# 9720
# (19,)
# 9721
# (17,)
# 9722
# (17,)
# 9723
# (23,)
# 9724
# (18,)
# 9725
# (38,)
# 9726
# (40,)
# 9727
# (42,)
# 9728
# (42,)
# 9729
# (46,)
# 9730
# (47,)
# 9731
# (50,)
# 9732
# (42,)
# 9733
# (48,)
# 9734
# (40,)
# 9735
# (54,)
# 9736
# (53,)
# 9737
# (70,)
# 9738
# (68,)
# 9739
# (59,)
# 9740
# (76,)
# 9741
# (83,)
# 9742
# (77,)
# 9743
# (78,)
# 9744
# (80,)
# 9745
# (29,)
# 9746
# (25,)
# 9747
# (25,)
# 9748
# (34,)
# 9749
# (30,)
# 9750
# (23,)
# 9751
# (25,)
# 9752
# (24,)
# 9753
# (27,)
# 9754
# (26,)
# 9755
# (44,)
# 9756
# (46,)
# 9757
# (42,)
# 9758
# (40,)
# 9759
# (49,)
# 9760
# (36,)
# 9761
# (39,)
# 9762
# (34,)
# 9763
# (20,)
# 9764
# (27,)
# 9765
# (144,)
# 9766
# (125,)
# 9767
# (124,)
# 9768
# (124,)
# 9769
# (121,)
# 9770
# (55,)
# 9771
# (59,)
# 9772
# (57,)
# 9773
# (60,)
# 9774
# (58,)
# 9775
# (80,)
# 9776
# (79,)
# 9777
# (91,)
# 9778
# (76,)
# 9779
# (95,)
# 9780
# (81,)
# 9781
# (84,)
# 9782
# (87,)
# 9783
# (80,)
# 9784
# (80,)
# 9785
# (66,)
# 9786
# (66,)
# 9787
# (64,)
# 9788
# (62,)
# 9789
# (62,)
# 9790
# (53,)
# 9791
# (54,)
# 9792
# (54,)
# 9793
# (53,)
# 9794
# (51,)
# 9795
# (64,)
# 9796
# (65,)
# 9797
# (60,)
# 9798
# (71,)
# 9799
# (61,)
# 9800
# (46,)
# 9801
# (43,)
# 9802
# (31,)
# 9803
# (43,)
# 9804
# (26,)
# 9805
# (67,)
# 9806
# (56,)
# 9807
# (64,)
# 9808
# (58,)
# 9809
# (57,)
# 9810
# (64,)
# 9811
# (52,)
# 9812
# (60,)
# 9813
# (68,)
# 9814
# (59,)
# 9815
# (34,)
# 9816
# (35,)
# 9817
# (27,)
# 9818
# (36,)
# 9819
# (40,)
# 9820
# (30,)
# 9821
# (33,)
# 9822
# (28,)
# 9823
# (24,)
# 9824
# (25,)
# 9825
# (40,)
# 9826
# (49,)
# 9827
# (47,)
# 9828
# (37,)
# 9829
# (45,)
# 9830
# (71,)
# 9831
# (64,)
# 9832
# (71,)
# 9833
# (65,)
# 9834
# (71,)
# 9835
# (49,)
# 9836
# (38,)
# 9837
# (21,)
# 9838
# (46,)
# 9839
# (31,)
# 9840
# (34,)
# 9841
# (36,)
# 9842
# (41,)
# 9843
# (32,)
# 9844
# (33,)
# 9845
# (0,)
# 9846
# (0,)
# 9847
# (3,)
# 9848
# (0,)
# 9849
# (0,)
# 9850
# (0,)
# 9851
# (0,)
# 9852
# (42,)
# 9853
# (39,)
# 9854
# (39,)
# 9855
# (31,)
# 9856
# (43,)
# 9857
# (97,)
# 9858
# (95,)
# 9859
# (95,)
# 9860
# (105,)
# 9861
# (89,)
# 9862
# (92,)
# 9863
# (101,)
# 9864
# (104,)
# 9865
# (103,)
# 9866
# (93,)
# 9867
# (120,)
# 9868
# (125,)
# 9869
# (120,)
# 9870
# (122,)
# 9871
# (121,)
# 9872
# (50,)
# 9873
# (53,)
# 9874
# (45,)
# 9875
# (44,)
# 9876
# (42,)
# 9877
# (69,)
# 9878
# (68,)
# 9879
# (65,)
# 9880
# (68,)
# 9881
# (66,)
# 9882
# (82,)
# 9883
# (81,)
# 9884
# (89,)
# 9885
# (91,)
# 9886
# (91,)
# 9887
# (60,)
# 9888
# (48,)
# 9889
# (46,)
# 9890
# (51,)
# 9891
# (51,)
# 9892
# (32,)
# 9893
# (29,)
# 9894
# (29,)
# 9895
# (31,)
# 9896
# (33,)
# 9897
# (44,)
# 9898
# (50,)
# 9899
# (50,)
# 9900
# (52,)
# 9901
# (55,)
# 9902
# (86,)
# 9903
# (86,)
# 9904
# (85,)
# 9905
# (86,)
# 9906
# (91,)
# 9907
# (67,)
# 9908
# (70,)
# 9909
# (74,)
# 9910
# (80,)
# 9911
# (73,)
# 9912
# (73,)
# 9913
# (70,)
# 9914
# (54,)
# 9915
# (49,)
# 9916
# (56,)
# 9917
# (14,)
# 9918
# (12,)
# 9919
# (16,)
# 9920
# (23,)
# 9921
# (13,)
# 9922
# (22,)
# 9923
# (20,)
# 9924
# (25,)
# 9925
# (24,)
# 9926
# (23,)
# 9927
# (16,)
# 9928
# (25,)
# 9929
# (23,)
# 9930
# (16,)
# 9931
# (19,)
# 9932
# (22,)
# 9933
# (21,)
# 9934
# (26,)
# 9935
# (21,)
# 9936
# (27,)
# 9937
# (72,)
# 9938
# (64,)
# 9939
# (63,)
# 9940
# (69,)
# 9941
# (58,)
# 9942
# (56,)
# 9943
# (70,)
# 9944
# (66,)
# 9945
# (75,)
# 9946
# (71,)
# 9947
# (124,)
# 9948
# (108,)
# 9949
# (117,)
# 9950
# (111,)
# 9951
# (130,)
# 9952
# (154,)
# 9953
# (154,)
# 9954
# (140,)
# 9955
# (160,)
# 9956
# (166,)
# 9957
# (9,)
# 9958
# (9,)
# 9959
# (10,)
# 9960
# (10,)
# 9961
# (12,)
# 9962
# (20,)
# 9963
# (21,)
# 9964
# (21,)
# 9965
# (18,)
# 9966
# (24,)
# 9967
# (22,)
# 9968
# (22,)
# 9969
# (23,)
# 9970
# (23,)
# 9971
# (21,)
# 9972
# (32,)
# 9973
# (34,)
# 9974
# (34,)
# 9975
# (30,)
# 9976
# (38,)
# 9977
# (42,)
# 9978
# (44,)
# 9979
# (53,)
# 9980
# (44,)
# 9981
# (54,)
# 9982
# (88,)
# 9983
# (91,)
# 9984
# (89,)
# 9985
# (90,)
# 9986
# (86,)
# 9987
# (33,)
# 9988
# (46,)
# 9989
# (52,)
# 9990
# (45,)
# 9991
# (49,)
# 9992
# (61,)
# 9993
# (55,)
# 9994
# (55,)
# 9995
# (59,)
# 9996
# (51,)
# 9997
# (35,)
# 9998
# (34,)
# 9999
# (32,)
# 10000
# (25,)
# 10001
# (25,)
# 10002
# (103,)
# 10003
# (100,)
# 10004
# (109,)
# 10005
# (102,)
# 10006
# (98,)
# 10007
# (112,)
# 10008
# (96,)
# 10009
# (127,)
# 10010
# (111,)
# 10011
# (95,)
# 10012
# (57,)
# 10013
# (86,)
# 10014
# (55,)
# 10015
# (127,)
# 10016
# (68,)
# 10017
# (81,)
# 10018
# (45,)
# 10019
# (44,)
# 10020
# (82,)
# 10021
# (55,)
# 10022
# (30,)
# 10023
# (25,)
# 10024
# (32,)
# 10025
# (32,)
# 10026
# (29,)
# 10027
# (62,)
# 10028
# (64,)
# 10029
# (65,)
# 10030
# (67,)
# 10031
# (64,)
# 10032
# (66,)
# 10033
# (74,)
# 10034
# (66,)
# 10035
# (67,)
# 10036
# (72,)
# 10037
# (52,)
# 10038
# (58,)
# 10039
# (58,)
# 10040
# (54,)
# 10041
# (45,)
# 10042
# (46,)
# 10043
# (59,)
# 10044
# (45,)
# 10045
# (54,)
# 10046
# (56,)
# 10047
# (42,)
# 10048
# (40,)
# 10049
# (50,)
# 10050
# (42,)
# 10051
# (50,)
# 10052
# (9,)
# 10053
# (57,)
# 10054
# (60,)
# 10055
# (62,)
# 10056
# (61,)
# 10057
# (57,)
# 10058
# (75,)
# 10059
# (99,)
# 10060
# (57,)
# 10061
# (82,)
# 10062
# (96,)
# 10063
# (89,)
# 10064
# (83,)
# 10065
# (93,)
# 10066
# (86,)
# 10067
# (89,)
# 10068
# (78,)
# 10069
# (75,)
# 10070
# (95,)
# 10071
# (81,)
# 10072
# (85,)
# 10073
# (49,)
# 10074
# (38,)
# 10075
# (52,)
# 10076
# (21,)
# 10077
# (55,)
# 10078
# (31,)
# 10079
# (35,)
# 10080
# (36,)
# 10081
# (33,)
# 10082
# (33,)
# 10083
# (31,)
# 10084
# (17,)
# 10085
# (25,)
# 10086
# (26,)
# 10087
# (32,)
# 10088
# (23,)
# 10089
# (10,)
# 10090
# (14,)
# 10091
# (21,)
# 10092
# (17,)
# 10093
# (28,)
# 10094
# (27,)
# 10095
# (26,)
# 10096
# (23,)
# 10097
# (29,)
# 10098
# (27,)
# 10099
# (23,)
# 10100
# (22,)
# 10101
# (22,)
# 10102
# (28,)
# 10103
# (57,)
# 10104
# (70,)
# 10105
# (66,)
# 10106
# (53,)
# 10107
# (64,)
# 10108
# (159,)
# 10109
# (107,)
# 10110
# (139,)
# 10111
# (154,)
# 10112
# (158,)
# 10113
# (127,)
# 10114
# (129,)
# 10115
# (155,)
# 10116
# (158,)
# 10117
# (136,)
# 10118
# (23,)
# 10119
# (27,)
# 10120
# (27,)
# 10121
# (20,)
# 10122
# (28,)
# 10123
# (20,)
# 10124
# (27,)
# 10125
# (22,)
# 10126
# (20,)
# 10127
# (21,)
# 10128
# (70,)
# 10129
# (68,)
# 10130
# (70,)
# 10131
# (59,)
# 10132
# (69,)
# 10133
# (48,)
# 10134
# (42,)
# 10135
# (50,)
# 10136
# (52,)
# 10137
# (40,)
# 10138
# (109,)
# 10139
# (101,)
# 10140
# (105,)
# 10141
# (105,)
# 10142
# (111,)
# 10143
# (85,)
# 10144
# (84,)
# 10145
# (87,)
# 10146
# (82,)
# 10147
# (83,)
# 10148
# (78,)
# 10149
# (83,)
# 10150
# (83,)
# 10151
# (81,)
# 10152
# (85,)
# 10153
# (55,)
# 10154
# (58,)
# 10155
# (56,)
# 10156
# (62,)
# 10157
# (52,)
# 10158
# (28,)
# 10159
# (40,)
# 10160
# (35,)
# 10161
# (38,)
# 10162
# (39,)
# 10163
# (65,)
# 10164
# (65,)
# 10165
# (84,)
# 10166
# (73,)
# 10167
# (74,)
# 10168
# (40,)
# 10169
# (27,)
# 10170
# (34,)
# 10171
# (34,)
# 10172
# (32,)
# 10173
# (19,)
# 10174
# (26,)
# 10175
# (30,)
# 10176
# (19,)
# 10177
# (23,)
# 10178
# (12,)
# 10179
# (8,)
# 10180
# (7,)
# 10181
# (10,)
# 10182
# (11,)
# 10183
# (98,)
# 10184
# (88,)
# 10185
# (101,)
# 10186
# (92,)
# 10187
# (85,)
# 10188
# (56,)
# 10189
# (71,)
# 10190
# (53,)
# 10191
# (57,)
# 10192
# (53,)
# 10193
# (65,)
# 10194
# (66,)
# 10195
# (63,)
# 10196
# (72,)
# 10197
# (73,)
# 10198
# (38,)
# 10199
# (30,)
# 10200
# (43,)
# 10201
# (39,)
# 10202
# (40,)
# 10203
# (64,)
# 10204
# (67,)
# 10205
# (59,)
# 10206
# (59,)
# 10207
# (66,)
# 10208
# (41,)
# 10209
# (28,)
# 10210
# (41,)
# 10211
# (32,)
# 10212
# (34,)
# 10213
# (50,)
# 10214
# (61,)
# 10215
# (54,)
# 10216
# (56,)
# 10217
# (51,)
# 10218
# (53,)
# 10219
# (44,)
# 10220
# (43,)
# 10221
# (51,)
# 10222
# (45,)
# 10223
# (43,)
# 10224
# (44,)
# 10225
# (42,)
# 10226
# (42,)
# 10227
# (35,)
# 10228
# (141,)
# 10229
# (163,)
# 10230
# (178,)
# 10231
# (171,)
# 10232
# (176,)
# 10233
# (151,)
# 10234
# (170,)
# 10235
# (157,)
# 10236
# (158,)
# 10237
# (163,)
# 10238
# (68,)
# 10239
# (62,)
# 10240
# (65,)
# 10241
# (68,)
# 10242
# (65,)
# 10243
# (24,)
# 10244
# (26,)
# 10245
# (27,)
# 10246
# (22,)
# 10247
# (27,)
# 10248
# (48,)
# 10249
# (36,)
# 10250
# (55,)
# 10251
# (44,)
# 10252
# (42,)
# 10253
# (10,)
# 10254
# (11,)
# 10255
# (12,)
# 10256
# (13,)
# 10257
# (12,)
# 10258
# (86,)
# 10259
# (79,)
# 10260
# (79,)
# 10261
# (85,)
# 10262
# (78,)
# 10263
# (74,)
# 10264
# (69,)
# 10265
# (73,)
# 10266
# (64,)
# 10267
# (67,)
# 10268
# (74,)
# 10269
# (76,)
# 10270
# (80,)
# 10271
# (74,)
# 10272
# (76,)
# 10273
# (74,)
# 10274
# (70,)
# 10275
# (64,)
# 10276
# (58,)
# 10277
# (68,)
# 10278
# (81,)
# 10279
# (78,)
# 10280
# (72,)
# 10281
# (69,)
# 10282
# (66,)
# 10283
# (104,)
# 10284
# (92,)
# 10285
# (71,)
# 10286
# (79,)
# 10287
# (91,)
# 10288
# (38,)
# 10289
# (32,)
# 10290
# (33,)
# 10291
# (26,)
# 10292
# (20,)
# 10293
# (46,)
# 10294
# (44,)
# 10295
# (55,)
# 10296
# (48,)
# 10297
# (49,)
# 10298
# (39,)
# 10299
# (35,)
# 10300
# (56,)
# 10301
# (38,)
# 10302
# (30,)
# 10303
# (29,)
# 10304
# (27,)
# 10305
# (26,)
# 10306
# (21,)
# 10307
# (38,)
# 10308
# (43,)
# 10309
# (35,)
# 10310
# (34,)
# 10311
# (25,)
# 10312
# (42,)
# 10313
# (36,)
# 10314
# (41,)
# 10315
# (44,)
# 10316
# (40,)
# 10317
# (39,)
# 10318
# (40,)
# 10319
# (43,)
# 10320
# (41,)
# 10321
# (44,)
# 10322
# (43,)
# 10323
# (56,)
# 10324
# (58,)
# 10325
# (76,)
# 10326
# (61,)
# 10327
# (71,)
# 10328
# (59,)
# 10329
# (65,)
# 10330
# (67,)
# 10331
# (48,)
# 10332
# (42,)
# 10333
# (41,)
# 10334
# (23,)
# 10335
# (40,)
# 10336
# (28,)
# 10337
# (26,)
# 10338
# (32,)
# 10339
# (30,)
# 10340
# (49,)
# 10341
# (33,)
# 10342
# (41,)
# 10343
# (39,)
# 10344
# (57,)
# 10345
# (55,)
# 10346
# (48,)
# 10347
# (60,)
# 10348
# (62,)
# 10349
# (66,)
# 10350
# (58,)
# 10351
# (63,)
# 10352
# (62,)
# 10353
# (42,)
# 10354
# (51,)
# 10355
# (49,)
# 10356
# (48,)
# 10357
# (41,)
# 10358
# (49,)
# 10359
# (45,)
# 10360
# (43,)
# 10361
# (45,)
# 10362
# (46,)
# 10363
# (20,)
# 10364
# (13,)
# 10365
# (17,)
# 10366
# (31,)
# 10367
# (9,)
# 10368
# (31,)
# 10369
# (26,)
# 10370
# (23,)
# 10371
# (26,)
# 10372
# (24,)
# 10373
# (48,)
# 10374
# (49,)
# 10375
# (47,)
# 10376
# (46,)
# 10377
# (49,)
# 10378
# (67,)
# 10379
# (60,)
# 10380
# (60,)
# 10381
# (65,)
# 10382
# (70,)
# 10383
# (56,)
# 10384
# (57,)
# 10385
# (53,)
# 10386
# (54,)
# 10387
# (54,)
# 10388
# (107,)
# 10389
# (103,)
# 10390
# (92,)
# 10391
# (88,)
# 10392
# (97,)
# 10393
# (70,)
# 10394
# (84,)
# 10395
# (68,)
# 10396
# (78,)
# 10397
# (74,)
# 10398
# (39,)
# 10399
# (35,)
# 10400
# (28,)
# 10401
# (27,)
# 10402
# (24,)
# 10403
# (72,)
# 10404
# (70,)
# 10405
# (72,)
# 10406
# (83,)
# 10407
# (72,)
# 10408
# (35,)
# 10409
# (42,)
# 10410
# (31,)
# 10411
# (34,)
# 10412
# (41,)
# 10413
# (75,)
# 10414
# (78,)
# 10415
# (77,)
# 10416
# (78,)
# 10417
# (68,)
# 10418
# (60,)
# 10419
# (55,)
# 10420
# (55,)
# 10421
# (57,)
# 10422
# (57,)
# 10423
# (66,)
# 10424
# (53,)
# 10425
# (61,)
# 10426
# (49,)
# 10427
# (52,)
# 10428
# (48,)
# 10429
# (46,)
# 10430
# (42,)
# 10431
# (51,)
# 10432
# (46,)
# 10433
# (58,)
# 10434
# (72,)
# 10435
# (49,)
# 10436
# (70,)
# 10437
# (59,)
# 10438
# (25,)
# 10439
# (24,)
# 10440
# (17,)
# 10441
# (20,)
# 10442
# (19,)
# 10443
# (26,)
# 10444
# (34,)
# 10445
# (27,)
# 10446
# (42,)
# 10447
# (26,)
# 10448
# (10,)
# 10449
# (16,)
# 10450
# (13,)
# 10451
# (16,)
# 10452
# (14,)
# 10453
# (18,)
# 10454
# (15,)
# 10455
# (19,)
# 10456
# (31,)
# 10457
# (17,)
# 10458
# (40,)
# 10459
# (35,)
# 10460
# (38,)
# 10461
# (41,)
# 10462
# (36,)
# 10463
# (0,)
# 10464
# (0,)
# 10465
# (5,)
# 10466
# (0,)
# 10467
# (0,)
# 10468
# (45,)
# 10469
# (34,)
# 10470
# (32,)
# 10471
# (40,)
# 10472
# (44,)
# 10473
# (44,)
# 10474
# (45,)
# 10475
# (43,)
# 10476
# (43,)
# 10477
# (50,)
# 10478
# (45,)
# 10479
# (51,)
# 10480
# (36,)
# 10481
# (51,)
# 10482
# (44,)
# 10483
# (135,)
# 10484
# (111,)
# 10485
# (128,)
# 10486
# (110,)
# 10487
# (100,)
# 10488
# (43,)
# 10489
# (32,)
# 10490
# (37,)
# 10491
# (40,)
# 10492
# (39,)
# 10493
# (43,)
# 10494
# (52,)
# 10495
# (44,)
# 10496
# (55,)
# 10497
# (47,)
# 10498
# (78,)
# 10499
# (72,)
# 10500
# (64,)
# 10501
# (68,)
# 10502
# (87,)
# 10503
# (13,)
# 10504
# (14,)
# 10505
# (10,)
# 10506
# (10,)
# 10507
# (13,)
# 10508
# (40,)
# 10509
# (38,)
# 10510
# (42,)
# 10511
# (43,)
# 10512
# (36,)
# 10513
# (32,)
# 10514
# (37,)
# 10515
# (35,)
# 10516
# (32,)
# 10517
# (27,)
# 10518
# (38,)
# 10519
# (34,)
# 10520
# (44,)
# 10521
# (40,)
# 10522
# (42,)
# 10523
# (24,)
# 10524
# (26,)
# 10525
# (24,)
# 10526
# (23,)
# 10527
# (24,)
# 10528
# (69,)
# 10529
# (68,)
# 10530
# (70,)
# 10531
# (67,)
# 10532
# (66,)
# 10533
# (77,)
# 10534
# (85,)
# 10535
# (75,)
# 10536
# (78,)
# 10537
# (78,)
# 10538
# (42,)
# 10539
# (51,)
# 10540
# (45,)
# 10541
# (42,)
# 10542
# (44,)
# 10543
# (37,)
# 10544
# (41,)
# 10545
# (40,)
# 10546
# (38,)
# 10547
# (46,)
# 10548
# (91,)
# 10549
# (89,)
# 10550
# (80,)
# 10551
# (82,)
# 10552
# (74,)
# 10553
# (46,)
# 10554
# (48,)
# 10555
# (43,)
# 10556
# (48,)
# 10557
# (50,)
# 10558
# (69,)
# 10559
# (67,)
# 10560
# (69,)
# 10561
# (86,)
# 10562
# (77,)
# 10563
# (39,)
# 10564
# (43,)
# 10565
# (41,)
# 10566
# (45,)
# 10567
# (41,)
# 10568
# (60,)
# 10569
# (61,)
# 10570
# (64,)
# 10571
# (50,)
# 10572
# (65,)
# 10573
# (65,)
# 10574
# (61,)
# 10575
# (53,)
# 10576
# (59,)
# 10577
# (65,)
# 10578
# (60,)
# 10579
# (85,)
# 10580
# (96,)
# 10581
# (86,)
# 10582
# (92,)
# 10583
# (36,)
# 10584
# (37,)
# 10585
# (36,)
# 10586
# (36,)
# 10587
# (35,)
# 10588
# (23,)
# 10589
# (25,)
# 10590
# (19,)
# 10591
# (17,)
# 10592
# (14,)
# 10593
# (110,)
# 10594
# (109,)
# 10595
# (113,)
# 10596
# (116,)
# 10597
# (108,)
# 10598
# (57,)
# 10599
# (63,)
# 10600
# (53,)
# 10601
# (71,)
# 10602
# (66,)
# 10603
# (33,)
# 10604
# (41,)
# 10605
# (40,)
# 10606
# (43,)
# 10607
# (43,)
# 10608
# (55,)
# 10609
# (62,)
# 10610
# (58,)
# 10611
# (55,)
# 10612
# (62,)
# 10613
# (75,)
# 10614
# (76,)
# 10615
# (73,)
# 10616
# (73,)
# 10617
# (68,)
# 10618
# (45,)
# 10619
# (40,)
# 10620
# (40,)
# 10621
# (56,)
# 10622
# (57,)
# 10623
# (42,)
# 10624
# (68,)
# 10625
# (56,)
# 10626
# (67,)
# 10627
# (43,)
# 10628
# (28,)
# 10629
# (15,)
# 10630
# (20,)
# 10631
# (23,)
# 10632
# (14,)
# 10633
# (22,)
# 10634
# (21,)
# 10635
# (25,)
# 10636
# (19,)
# 10637
# (24,)
# 10638
# (9,)
# 10639
# (10,)
# 10640
# (12,)
# 10641
# (11,)
# 10642
# (12,)
# 10643
# (51,)
# 10644
# (40,)
# 10645
# (40,)
# 10646
# (54,)
# 10647
# (60,)
# 10648
# (25,)
# 10649
# (28,)
# 10650
# (29,)
# 10651
# (26,)
# 10652
# (28,)
# 10653
# (62,)
# 10654
# (73,)
# 10655
# (67,)
# 10656
# (59,)
# 10657
# (67,)
# 10658
# (89,)
# 10659
# (86,)
# 10660
# (88,)
# 10661
# (88,)
# 10662
# (85,)
# 10663
# (26,)
# 10664
# (28,)
# 10665
# (35,)
# 10666
# (34,)
# 10667
# (32,)
# 10668
# (35,)
# 10669
# (54,)
# 10670
# (49,)
# 10671
# (46,)
# 10672
# (44,)
# 10673
# (11,)
# 10674
# (19,)
# 10675
# (25,)
# 10676
# (14,)
# 10677
# (17,)
# 10678
# (13,)
# 10679
# (9,)
# 10680
# (9,)
# 10681
# (12,)
# 10682
# (36,)
# 10683
# (36,)
# 10684
# (32,)
# 10685
# (39,)
# 10686
# (34,)
# 10687
# (35,)
# 10688
# (28,)
# 10689
# (32,)
# 10690
# (30,)
# 10691
# (29,)

# %%
print(count, count1)
# Out:
# (10248, 8845)

# %%
def indices(window_len, stride_len, point_set, labels, corners_gt):
    IOU = []
    start = []
    end = []
    IOU_1 = []
    IOU_2 = []
    #corner = []
    j = np.min(point_set,0)[2]
    i = np.min(point_set,0)[2]+window_len
    idtuple=set()
    while i<=np.max(point_set,0)[2]:
            max_ind = np.searchsorted(point_set[:,2], i)
            min_ind = np.searchsorted(point_set[:,2], j)
            if (min_ind,max_ind) not in idtuple and max_ind-min_ind>5:
                #print('fgbd')
                idtuple.add((min_ind,max_ind))
                #labels_window = np.zeros_like(point_set[:,0])
                #labels_window[min_ind:max_ind] = 1.0
                #union = np.sum(np.logical_or(labels, labels_window))
                #print(union)
                #inter = np.sum(np.logical_and(labels, labels_window))
                #if (inter*1.0/union) < 0.3 or (inter*1.0/union) >=0.7 : # or 
                
                window_points=point_set[min_ind:1+ max_ind][:, :3]
                min_x, min_y, min_z = np.min(window_points,axis=0)
                max_x, max_y, max_z = np.max(window_points,axis=0)
                #corners = [[max_x,max_y,max_z],[max_x,max_y,min_z],[min_x,max_y,min_z],[min_x,max_y,max_z],\
                #           [max_x,min_y,max_z],[max_x,min_y,min_z],[min_x,min_y,min_z],[min_x,min_y,max_z]]
                corners = [[min_x,max_y,max_z],[min_x,max_y,min_z],[max_x,max_y,min_z],[max_x,max_y,max_z],\
                               [min_x,min_y,max_z],[min_x,min_y,min_z],[max_x,min_y,min_z],[max_x,min_y,max_z]]
                corners=np.array(corners)
                iou_3d, IOU_2D,inter_area, inter_vol = box_util.box3d_iou(corners, corners_gt)
                if inter_area<0.3 or inter_area>=0.6 :
                    #corner.append(corners)
                    #print(corners)
                    
                    end.append(max_ind)
                    start.append(min_ind)
                    #IOU.append(inter*1.0/union)
                    IOU_1.append(inter_area)
                    IOU_2.append(inter_vol)
            j = j+stride_len
            i = j+window_len
    IOU_1 = (np.array(IOU_1)>=0.6)
    return np.array(start),np.array(end), np.array(IOU), np.array(IOU_1), np.array(IOU_2)#, np.array(corner)

# %%
TRAIN_DATASET.get_center_view_box3d(1)
# Out:
# array([[ 0.63603565,  1.47      ,  8.95986384],
#        [ 0.7288103 ,  1.47      ,  8.48891494],
#        [-0.44856195,  1.47      ,  8.25697831],
#        [-0.5413366 ,  1.47      ,  8.72792721],
#        [ 0.63603565, -0.42      ,  8.95986384],
#        [ 0.7288103 , -0.42      ,  8.48891494],
#        [-0.44856195, -0.42      ,  8.25697831],
#        [-0.5413366 , -0.42      ,  8.72792721]])

# %%
pedc = 0
key = 'train'
count = 0
count_0 = 0
count1 = 0
count2 = 0
count3 = 0
total = 0
m = 0
for m in range(TRAIN_DATASET.__len__()):
    
    point_set,labels,a,b,c,d,e,f,cls = TRAIN_DATASET.__getitem__(m)
    if cls[1]==1 :
        pedc += 1
        print(pedc)
        #print(point_set.shape)
        #print(np.min(point_set[:,2]))
        #print(point_set.shape)
        #point_set = TRAIN_DATASET.get_center_view_point_set(m)
        index = np.argsort(point_set[:,2])
        point_set = point_set[index]
        labels = labels[index]
        
        if key=='train':
            corners_gt = TRAIN_DATASET.get_center_view_box3d(m)
        if key=='val':
            corners_gt = VAL_DATASET.get_center_view_box3d(m)
            
        #print(point_set.shape)
         
        s,e,l,l1,l2 = indices(0.9,0.1,point_set,labels, corners_gt)
        
        #inm = np.argmax(l1)
        #print(inm)
        print(l1.shape)
        #print(l2[inm])
        #print(c[inm])

        if np.sum(l1>=0.7) >0:
            count += 1
        if np.sum(l1>=0.6) >0 :
            count_0 += 1
        if np.sum(l1>=0.5) >0:
            count1 += 1
            if np.sum(l2>=0.5) >0:
                count2 += 1
        if np.sum(l2>=0.5) >0:
            count3 += 1
# Out:
# 1
# (76,)
# 2
# (85,)
# 3
# (79,)
# 4
# (81,)
# 5
# (81,)
# 6
# (21,)
# 7
# (21,)
# 8
# (23,)
# 9
# (23,)
# 10
# (23,)
# 11
# (87,)
# 12
# (85,)
# 13
# (102,)
# 14
# (130,)
# 15
# (120,)
# 16
# (114,)
# 17
# (84,)
# 18
# (77,)
# 19
# (103,)
# 20
# (83,)
# 21
# (17,)
# 22
# (11,)
# 23
# (15,)
# 24
# (16,)
# 25
# (23,)
# 26
# (24,)
# 27
# (27,)
# 28
# (25,)
# 29
# (27,)
# 30
# (25,)
# 31
# (90,)
# 32
# (71,)
# 33
# (85,)
# 34
# (67,)
# 35
# (99,)
# 36
# (53,)
# 37
# (53,)
# 38
# (45,)
# 39
# (60,)
# 40
# (55,)
# 41
# (52,)
# 42
# (70,)
# 43
# (60,)
# 44
# (64,)
# 45
# (50,)
# 46
# (81,)
# 47
# (74,)
# 48
# (106,)
# 49
# (84,)
# 50
# (100,)
# 51
# (170,)
# 52
# (122,)
# 53
# (129,)
# 54
# (119,)
# 55
# (155,)
# 56
# (16,)
# 57
# (25,)
# 58
# (23,)
# 59
# (18,)
# 60
# (24,)
# 61
# (71,)
# 62
# (71,)
# 63
# (72,)
# 64
# (72,)
# 65
# (72,)
# 66
# (95,)
# 67
# (116,)
# 68
# (111,)
# 69
# (100,)
# 70
# (100,)
# 71
# (43,)
# 72
# (42,)
# 73
# (47,)
# 74
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-73-cbd9be6bd28b> in <module>()
#      29         #print(point_set.shape)
#      30
# ---> 31         s,e,l,l1,l2 = indices(0.9,0.1,point_set,labels, corners_gt)
#      32
#      33         #inm = np.argmax(l1)
#
# <ipython-input-71-fa796582673c> in indices(window_len, stride_len, point_set, labels, corners_gt)
#      29                 corners = [[min_x,max_y,max_z],[min_x,max_y,min_z],[max_x,max_y,min_z],[max_x,max_y,max_z],                               [min_x,min_y,max_z],[min_x,min_y,min_z],[max_x,min_y,min_z],[max_x,min_y,max_z]]
#      30                 corners=np.array(corners)
# ---> 31                 iou_3d, IOU_2D,inter_area, inter_vol = box_util.box3d_iou(corners, corners_gt)
#      32                 if inter_area<0.3 or inter_area>=0.6 :
#      33                     #corner.append(corners)
#
# /home/vamsi/Downloads/frustum-pointnets/train/box_util.pyc in box3d_iou(corners1, corners2)
#     102     area1 = poly_area(np.array(rect1)[:,0], np.array(rect1)[:,1])
#     103     area2 = poly_area(np.array(rect2)[:,0], np.array(rect2)[:,1])
# --> 104     inter, inter_area = convex_hull_intersection(rect1, rect2)
#     105     iou_2d = inter_area/(area1+area2-inter_area)
#     106     ymax = min(corners1[0,1], corners2[0,1])
#
# /home/vamsi/Downloads/frustum-pointnets/train/box_util.pyc in convex_hull_intersection(p1, p2)
#      66         return a list of (x,y) for the intersection and its volume
#      67     """
# ---> 68     inter_p = polygon_clip(p1,p2)
#      69     if inter_p is not None:
#      70         hull_inter = ConvexHull(inter_p)
#
# /home/vamsi/Downloads/frustum-pointnets/train/box_util.pyc in polygon_clip(subjectPolygon, clipPolygon)
#      45       for subjectVertex in inputList:
#      46          e = subjectVertex
# ---> 47          if inside(e):
#      48             if not inside(s):
#      49                outputList.append(computeIntersection())
#
# /home/vamsi/Downloads/frustum-pointnets/train/box_util.pyc in inside(p)
#      24    """
#      25    def inside(p):
# ---> 26       return(cp2[0]-cp1[0])*(p[1]-cp1[1]) > (cp2[1]-cp1[1])*(p[0]-cp1[0])
#      27
#      28    def computeIntersection():
#
# KeyboardInterrupt:

# %%
print(count, count_0, count1, count2, count3)
# Out:
# (0, 0, 0, 0, 0)

# %%
pedc = 0
key = 'train'
count = 0
count_0 = 0
count1 = 0
count2 = 0
count3 = 0
total = 0
m = 0
for m in range(TRAIN_DATASET.__len__()):
    
    point_set,labels,a,b,c,d,e,f,cls = TRAIN_DATASET.__getitem__(m)
    if cls[1]==1 :
        pedc += 1
        print(pedc)
        #print(point_set.shape)
        #print(np.min(point_set[:,2]))
        #print(point_set.shape)
        #point_set = TRAIN_DATASET.get_center_view_point_set(m)
        index = np.argsort(point_set[:,2])
        point_set = point_set[index]
        labels = labels[index]
        
        if key=='train':
            corners_gt = TRAIN_DATASET.get_center_view_box3d(m)
        if key=='val':
            corners_gt = VAL_DATASET.get_center_view_box3d(m)
            
        #print(point_set.shape)
         
        s,e,l,l1,l2, c = indices(1.0,0.1,point_set,labels, corners_gt)
        
        #inm = np.argmax(l1)
        #print(inm)
        #print(l1[inm])
        #print(l2[inm])
        #print(c[inm])

        if np.sum(l1>=0.7) >0:
            count += 1
        if np.sum(l1>=0.6) >0 :
            count_0 += 1
        if np.sum(l1>=0.5) >0:
            count1 += 1
            if np.sum(l2>=0.5) >0:
                count2 += 1
        if np.sum(l2>=0.5) >0:
            count3 += 1
# Out:
# (1562, 4)
# 1
# (1559, 4)
# 2
# (1507, 4)
# 3
# (1515, 4)
# 4
# (1606, 4)
# 5
# (980, 4)
# (1055, 4)
# (1155, 4)
# (1133, 4)
# (1058, 4)
# (184, 4)
# (242, 4)
# (211, 4)
# (222, 4)
# (186, 4)
# (70, 4)
# (78, 4)
# (83, 4)
# (82, 4)
# (67, 4)
# (242, 4)
# (210, 4)
# (241, 4)
# (285, 4)
# (235, 4)
# (1201, 4)
# (1512, 4)
# (921, 4)
# (1131, 4)
# (1002, 4)
# (1575, 4)
# (1897, 4)
# (1569, 4)
# (1889, 4)
# (1840, 4)
# (104, 4)
# 6
# (97, 4)
# 7
# (98, 4)
# 8
# (108, 4)
# 9
# (118, 4)
# 10
# (506, 4)
# (507, 4)
# (590, 4)
# (492, 4)
# (640, 4)
# (213, 4)
# (260, 4)
# (266, 4)
# (235, 4)
# (218, 4)
# (333, 4)
# (288, 4)
# (364, 4)
# (296, 4)
# (313, 4)
# (151, 4)
# (139, 4)
# (158, 4)
# (180, 4)
# (156, 4)
# (122, 4)
# (114, 4)
# (102, 4)
# (101, 4)
# (88, 4)
# (40, 4)
# (51, 4)
# (46, 4)
# (19, 4)
# (45, 4)
# (536, 4)
# 11
# (471, 4)
# 12
# (555, 4)
# 13
# (601, 4)
# 14
# (547, 4)
# 15
# (582, 4)
# 16
# (515, 4)
# 17
# (469, 4)
# 18
# (620, 4)
# 19
# (531, 4)
# 20
# (255, 4)
# (224, 4)
# (233, 4)
# (268, 4)
# (250, 4)
# (66, 4)
# 21
# (49, 4)
# 22
# (59, 4)
# 23
# (59, 4)
# 24
# (66, 4)
# 25
# (527, 4)
# (524, 4)
# (468, 4)
# (501, 4)
# (473, 4)
# (136, 4)
# 26
# (175, 4)
# 27
# (131, 4)
# 28
# (153, 4)
# 29
# (143, 4)
# 30
# (500, 4)
# (426, 4)
# (426, 4)
# (428, 4)
# (402, 4)
# (102, 4)
# (93, 4)
# (102, 4)
# (103, 4)
# (104, 4)
# (115, 4)
# (93, 4)
# (110, 4)
# (101, 4)
# (29, 4)
# (29, 4)
# (188, 4)
# (199, 4)
# (201, 4)
# (212, 4)
# (170, 4)
# (220, 4)
# (261, 4)
# (204, 4)
# (241, 4)
# (217, 4)
# (96, 4)
# (96, 4)
# (118, 4)
# (98, 4)
# (115, 4)
# (42, 4)
# (31, 4)
# (36, 4)
# (2019, 4)
# (1199, 4)
# (951, 4)
# (1029, 4)
# (916, 4)
# (1301, 4)
# (271, 4)
# (235, 4)
# (293, 4)
# (330, 4)
# (318, 4)
# (323, 4)
# (387, 4)
# (391, 4)
# (364, 4)
# (382, 4)
# (67, 4)
# (66, 4)
# (1389, 4)
# (1374, 4)
# (1399, 4)
# (1365, 4)
# (1458, 4)
# (1606, 4)
# (1393, 4)
# (1425, 4)
# (1439, 4)
# (1467, 4)
# (67, 4)
# (66, 4)
# (66, 4)
# (19, 4)
# (20, 4)
# (252, 4)
# (354, 4)
# (321, 4)
# (383, 4)
# (363, 4)
# (162, 4)
# (177, 4)
# (188, 4)
# (135, 4)
# (171, 4)
# (762, 4)
# (534, 4)
# (731, 4)
# (636, 4)
# (731, 4)
# (210, 4)
# (192, 4)
# (153, 4)
# (192, 4)
# (154, 4)
# (1378, 4)
# (1197, 4)
# (1167, 4)
# (1597, 4)
# (1345, 4)
# (1177, 4)
# (991, 4)
# (1400, 4)
# (1274, 4)
# (1132, 4)
# (540, 4)
# (645, 4)
# (512, 4)
# (617, 4)
# (561, 4)
# (350, 4)
# (398, 4)
# (447, 4)
# (317, 4)
# (400, 4)
# (203, 4)
# (220, 4)
# (182, 4)
# (190, 4)
# (196, 4)
# (49, 4)
# (60, 4)
# (137, 4)
# (140, 4)
# (133, 4)
# (153, 4)
# (130, 4)
# (295, 4)
# 31
# (277, 4)
# 32
# (302, 4)
# 33
# (276, 4)
# 34
# (315, 4)
# 35
# (318, 4)
# 36
# (309, 4)
# 37
# (269, 4)
# 38
# (325, 4)
# 39
# (291, 4)
# 40
# (165, 4)
# 41
# (197, 4)
# 42
# (157, 4)
# 43
# (174, 4)
# 44
# (158, 4)
# 45
# (188, 4)
# 46
# (176, 4)
# 47
# (215, 4)
# 48
# (188, 4)
# 49
# (199, 4)
# 50
# (942, 4)
# (1085, 4)
# (968, 4)
# (1095, 4)
# (1010, 4)
# (1338, 4)
# (1002, 4)
# (1339, 4)
# (1156, 4)
# (1048, 4)
# (411, 4)
# (390, 4)
# (363, 4)
# (482, 4)
# (434, 4)
# (171, 4)
# (145, 4)
# (128, 4)
# (167, 4)
# (132, 4)
# (149, 4)
# (171, 4)
# (154, 4)
# (153, 4)
# (134, 4)
# (60, 4)
# (56, 4)
# (49, 4)
# (76, 4)
# (69, 4)
# (42, 4)
# (52, 4)
# (34, 4)
# (151, 4)
# (123, 4)
# (129, 4)
# (139, 4)
# (130, 4)
# (74, 4)
# (74, 4)
# (71, 4)
# (76, 4)
# (70, 4)
# (648, 4)
# (859, 4)
# (670, 4)
# (752, 4)
# (667, 4)
# (155, 4)
# (125, 4)
# (177, 4)
# (147, 4)
# (143, 4)
# (92, 4)
# (97, 4)
# (75, 4)
# (88, 4)
# (81, 4)
# (283, 4)
# (218, 4)
# (245, 4)
# (252, 4)
# (252, 4)
# (1603, 4)
# (1283, 4)
# (1189, 4)
# (1709, 4)
# (1402, 4)
# (525, 4)
# (515, 4)
# (640, 4)
# (546, 4)
# (522, 4)
# (479, 4)
# (445, 4)
# (373, 4)
# (410, 4)
# (409, 4)
# (195, 4)
# (243, 4)
# (242, 4)
# (190, 4)
# (150, 4)
# (1584, 4)
# 51
# (1380, 4)
# 52
# (1555, 4)
# 53
# (1489, 4)
# 54
# (1467, 4)
# 55
# (1797, 4)
# (693, 4)
# (851, 4)
# (816, 4)
# (783, 4)
# (684, 4)
# (589, 4)
# (585, 4)
# (537, 4)
# (553, 4)
# (619, 4)
# (56, 4)
# 56
# (71, 4)
# 57
# (59, 4)
# 58
# (54, 4)
# 59
# (74, 4)
# 60
# (300, 4)
# (301, 4)
# (304, 4)
# (368, 4)
# (338, 4)
# (1360, 4)
# (1584, 4)
# (1057, 4)
# (1072, 4)
# (1416, 4)
# (758, 4)
# (675, 4)
# (723, 4)
# (787, 4)
# (674, 4)
# (72, 4)
# (82, 4)
# (77, 4)
# (71, 4)
# (68, 4)
# (290, 4)
# (395, 4)
# (315, 4)
# (385, 4)
# (325, 4)
# (329, 4)
# (279, 4)
# (307, 4)
# (295, 4)
# (280, 4)
# (215, 4)
# (281, 4)
# (195, 4)
# (248, 4)
# (189, 4)
# (75, 4)
# (74, 4)
# (64, 4)
# (68, 4)
# (85, 4)
# (1044, 4)
# 61
# (1088, 4)
# 62
# (1083, 4)
# 63
# (1070, 4)
# 64
# (1162, 4)
# 65
# (98, 4)
# (105, 4)
# (117, 4)
# (132, 4)
# (99, 4)
# (64, 4)
# (68, 4)
# (67, 4)
# (61, 4)
# (60, 4)
# (60, 4)
# (66, 4)
# (42, 4)
# (62, 4)
# (59, 4)
# (23, 4)
# (20, 4)
# (1155, 4)
# (1044, 4)
# (1251, 4)
# (1064, 4)
# (929, 4)
# (188, 4)
# (138, 4)
# (173, 4)
# (189, 4)
# (168, 4)
# (242, 4)
# (351, 4)
# (324, 4)
# (265, 4)
# (303, 4)
# (47, 4)
# (36, 4)
# (43, 4)
# (38, 4)
# (46, 4)
# (181, 4)
# (136, 4)
# (179, 4)
# (182, 4)
# (188, 4)
# (1141, 4)
# (1323, 4)
# (1264, 4)
# (1558, 4)
# (1221, 4)
# (102, 4)
# (89, 4)
# (94, 4)
# (89, 4)
# (94, 4)
# (48, 4)
# (46, 4)
# (53, 4)
# (48, 4)
# (54, 4)
# (1426, 4)
# (1565, 4)
# (1539, 4)
# (1823, 4)
# (1512, 4)
# (1872, 4)
# (1836, 4)
# (1555, 4)
# (1796, 4)
# (880, 4)
# (738, 4)
# (935, 4)
# (1019, 4)
# (544, 4)
# (365, 4)
# (383, 4)
# (413, 4)
# (373, 4)
# (389, 4)
# (111, 4)
# (146, 4)
# (132, 4)
# (132, 4)
# (107, 4)
# (527, 4)
# (592, 4)
# (646, 4)
# (549, 4)
# (547, 4)
# (355, 4)
# (298, 4)
# (316, 4)
# (356, 4)
# (344, 4)
# (206, 4)
# (196, 4)
# (222, 4)
# (189, 4)
# (195, 4)
# (430, 4)
# (473, 4)
# (365, 4)
# (392, 4)
# (389, 4)
# (1088, 4)
# (1265, 4)
# (1352, 4)
# (1267, 4)
# (1324, 4)
# (1677, 4)
# 66
# (1807, 4)
# 67
# (1568, 4)
# 68
# (1680, 4)
# 69
# (1785, 4)
# 70
# (358, 4)
# (399, 4)
# (366, 4)
# (336, 4)
# (329, 4)
# (209, 4)
# (208, 4)
# (248, 4)
# (228, 4)
# (229, 4)
# (1315, 4)
# (1357, 4)
# (1665, 4)
# (1686, 4)
# (1676, 4)
# (81, 4)
# (81, 4)
# (101, 4)
# (87, 4)
# (87, 4)
# (833, 4)
# 71
# (805, 4)
# 72
# (1016, 4)
# 73
# (914, 4)
# 74
# (791, 4)
# 75
# (812, 4)
# 76
# (825, 4)
# 77
# (788, 4)
# 78
# (846, 4)
# 79
# (756, 4)
# 80
# (495, 4)
# 81
# (490, 4)
# 82
# (489, 4)
# 83
# (519, 4)
# 84
# (414, 4)
# 85
# (240, 4)
# (296, 4)
# (252, 4)
# (305, 4)
# (305, 4)
# (144, 4)
# (130, 4)
# (107, 4)
# (104, 4)
# (128, 4)
# (34, 4)
# 86
# (38, 4)
# 87
# (42, 4)
# 88
# (48, 4)
# 89
# (38, 4)
# 90
# (51, 4)
# 91
# (51, 4)
# 92
# (59, 4)
# 93
# (55, 4)
# 94
# (54, 4)
# 95
# (1739, 4)
# 96
# (1791, 4)
# 97
# (1955, 4)
# 98
# (1835, 4)
# 99
# (1986, 4)
# 100
# (1452, 4)
# 101
# (1639, 4)
# 102
# (1460, 4)
# 103
# (1432, 4)
# 104
# (1399, 4)
# 105
# (907, 4)
# 106
# (801, 4)
# 107
# (874, 4)
# 108
# (843, 4)
# 109
# (704, 4)
# 110
# (1023, 4)
# (963, 4)
# (891, 4)
# (1253, 4)
# (1296, 4)
# (913, 4)
# (924, 4)
# (791, 4)
# (758, 4)
# (826, 4)
# (453, 4)
# (357, 4)
# (458, 4)
# (452, 4)
# (452, 4)
# (208, 4)
# (254, 4)
# (201, 4)
# (231, 4)
# (198, 4)
# (80, 4)
# (72, 4)
# (80, 4)
# (56, 4)
# (60, 4)
# (60, 4)
# (42, 4)
# (42, 4)
# (41, 4)
# (1978, 4)
# (1978, 4)
# (1656, 4)
# (1826, 4)
# (53, 4)
# (45, 4)
# (49, 4)
# (299, 4)
# (345, 4)
# (316, 4)
# (270, 4)
# (341, 4)
# (18, 4)
# (20, 4)
# (21, 4)
# (20, 4)
# (102, 4)
# (96, 4)
# (126, 4)
# (117, 4)
# (119, 4)
# (1827, 4)
# (1939, 4)
# (1962, 4)
# (1539, 4)
# (1274, 4)
# (1397, 4)
# (1250, 4)
# (1300, 4)
# (140, 4)
# (156, 4)
# (196, 4)
# (156, 4)
# (217, 4)
# (234, 4)
# (186, 4)
# (155, 4)
# (201, 4)
# (181, 4)
# (98, 4)
# (119, 4)
# (131, 4)
# (111, 4)
# (108, 4)
# (167, 4)
# (179, 4)
# (179, 4)
# (190, 4)
# (155, 4)
# (77, 4)
# (68, 4)
# (65, 4)
# (48, 4)
# (176, 4)
# (208, 4)
# (196, 4)
# (193, 4)
# (234, 4)
# (596, 4)
# 111
# (564, 4)
# 112
# (660, 4)
# 113
# (552, 4)
# 114
# (562, 4)
# 115
# (648, 4)
# (534, 4)
# (659, 4)
# (487, 4)
# (685, 4)
# (1699, 4)
# (1720, 4)
# (1922, 4)
# (1931, 4)
# (1564, 4)
# (525, 4)
# (398, 4)
# (515, 4)
# (464, 4)
# (432, 4)
# (966, 4)
# (958, 4)
# (789, 4)
# (1000, 4)
# (950, 4)
# (762, 4)
# (780, 4)
# (851, 4)
# (788, 4)
# (803, 4)
# (272, 4)
# (207, 4)
# (250, 4)
# (174, 4)
# (206, 4)
# (116, 4)
# (129, 4)
# (139, 4)
# (831, 4)
# (972, 4)
# (1018, 4)
# (856, 4)
# (1008, 4)
# (56, 4)
# (54, 4)
# (77, 4)
# (57, 4)
# (65, 4)
# (18, 4)
# 116
# (22, 4)
# 117
# (22, 4)
# 118
# (746, 4)
# (1024, 4)
# (970, 4)
# (944, 4)
# (1057, 4)
# (175, 4)
# (151, 4)
# (171, 4)
# (204, 4)
# (164, 4)
# (65, 4)
# (75, 4)
# (69, 4)
# (69, 4)
# (69, 4)
# (24, 4)
# (21, 4)
# (288, 4)
# (301, 4)
# (260, 4)
# (357, 4)
# (273, 4)
# (313, 4)
# (359, 4)
# (316, 4)
# (257, 4)
# (273, 4)
# (138, 4)
# (171, 4)
# (138, 4)
# (169, 4)
# (154, 4)
# (108, 4)
# (99, 4)
# (106, 4)
# (108, 4)
# (115, 4)
# (133, 4)
# (158, 4)
# (146, 4)
# (144, 4)
# (140, 4)
# (362, 4)
# (491, 4)
# (471, 4)
# (477, 4)
# (392, 4)
# (1226, 4)
# (1025, 4)
# (1074, 4)
# (1190, 4)
# (1162, 4)
# (377, 4)
# (391, 4)
# (333, 4)
# (369, 4)
# (423, 4)
# (233, 4)
# (214, 4)
# (272, 4)
# (223, 4)
# (243, 4)
# (1250, 4)
# (1199, 4)
# (1216, 4)
# (1289, 4)
# (1192, 4)
# (121, 4)
# (89, 4)
# (90, 4)
# (86, 4)
# (117, 4)
# (32, 4)
# (37, 4)
# (404, 4)
# (293, 4)
# (367, 4)
# (309, 4)
# (298, 4)
# (175, 4)
# (202, 4)
# (221, 4)
# (222, 4)
# (272, 4)
# (77, 4)
# (81, 4)
# (95, 4)
# (97, 4)
# (71, 4)
# (373, 4)
# (429, 4)
# (452, 4)
# (377, 4)
# (438, 4)
# (272, 4)
# (224, 4)
# (250, 4)
# (258, 4)
# (135, 4)
# (112, 4)
# (150, 4)
# (119, 4)
# (97, 4)
# (1330, 4)
# (1686, 4)
# (1436, 4)
# (1773, 4)
# (1347, 4)
# (1972, 4)
# (2005, 4)
# (1180, 4)
# (1115, 4)
# (1420, 4)
# (1410, 4)
# (1288, 4)
# (330, 4)
# (475, 4)
# (392, 4)
# (391, 4)
# (429, 4)
# (1138, 4)
# (1128, 4)
# (1157, 4)
# (1082, 4)
# (1066, 4)
# (333, 4)
# (287, 4)
# (386, 4)
# (348, 4)
# (380, 4)
# (244, 4)
# (216, 4)
# (173, 4)
# (228, 4)
# (209, 4)
# (187, 4)
# (231, 4)
# (190, 4)
# (173, 4)
# (196, 4)
# (408, 4)
# 119
# (334, 4)
# 120
# (378, 4)
# 121
# (406, 4)
# 122
# (437, 4)
# 123
# (409, 4)
# (397, 4)
# (379, 4)
# (361, 4)
# (405, 4)
# (128, 4)
# (182, 4)
# (167, 4)
# (163, 4)
# (149, 4)
# (172, 4)
# (253, 4)
# (201, 4)
# (191, 4)
# (195, 4)
# (634, 4)
# 124
# (657, 4)
# 125
# (639, 4)
# 126
# (698, 4)
# 127
# (719, 4)
# 128
# (764, 4)
# 129
# (736, 4)
# 130
# (732, 4)
# 131
# (836, 4)
# 132
# (690, 4)
# 133
# (1805, 4)
# (89, 4)
# (88, 4)
# (96, 4)
# (88, 4)
# (85, 4)
# (592, 4)
# (615, 4)
# (557, 4)
# (638, 4)
# (702, 4)
# (671, 4)
# (885, 4)
# (780, 4)
# (649, 4)
# (869, 4)
# (430, 4)
# (374, 4)
# (424, 4)
# (366, 4)
# (519, 4)
# (133, 4)
# (167, 4)
# (172, 4)
# (152, 4)
# (159, 4)
# (181, 4)
# (186, 4)
# (169, 4)
# (164, 4)
# (162, 4)
# (337, 4)
# (306, 4)
# (342, 4)
# (110, 4)
# (98, 4)
# (89, 4)
# (91, 4)
# (106, 4)
# (56, 4)
# (66, 4)
# (72, 4)
# (63, 4)
# (196, 4)
# (192, 4)
# (198, 4)
# (183, 4)
# (199, 4)
# (304, 4)
# (298, 4)
# (255, 4)
# (287, 4)
# (255, 4)
# (217, 4)
# (242, 4)
# (230, 4)
# (230, 4)
# (207, 4)
# (1427, 4)
# (1237, 4)
# (1151, 4)
# (1181, 4)
# (1297, 4)
# (579, 4)
# (485, 4)
# (570, 4)
# (541, 4)
# (470, 4)
# (327, 4)
# (318, 4)
# (244, 4)
# (256, 4)
# (268, 4)
# (146, 4)
# (122, 4)
# (135, 4)
# (70, 4)
# (72, 4)
# (94, 4)
# (74, 4)
# (89, 4)
# (36, 4)
# (38, 4)
# (44, 4)
# (65, 4)
# (68, 4)
# (70, 4)
# (957, 4)
# (1310, 4)
# (1215, 4)
# (1256, 4)
# (1077, 4)
# (462, 4)
# (431, 4)
# (573, 4)
# (497, 4)
# (500, 4)
# (1134, 4)
# (1451, 4)
# (1242, 4)
# (1132, 4)
# (1291, 4)
# (1086, 4)
# (1319, 4)
# (1213, 4)
# (1330, 4)
# (1194, 4)
# (905, 4)
# (860, 4)
# (881, 4)
# (955, 4)
# (817, 4)
# (1467, 4)
# (1542, 4)
# (1505, 4)
# (1178, 4)
# (1399, 4)
# (192, 4)
# (224, 4)
# (167, 4)
# (254, 4)
# (211, 4)
# (513, 4)
# (512, 4)
# (536, 4)
# (497, 4)
# (495, 4)
# (423, 4)
# (416, 4)
# (328, 4)
# (364, 4)
# (450, 4)
# (1034, 4)
# (956, 4)
# (993, 4)
# (1118, 4)
# (935, 4)
# (288, 4)
# (245, 4)
# (318, 4)
# (351, 4)
# (263, 4)
# (574, 4)
# (564, 4)
# (458, 4)
# (469, 4)
# (562, 4)
# (108, 4)
# (113, 4)
# (128, 4)
# (99, 4)
# (128, 4)
# (274, 4)
# (287, 4)
# (227, 4)
# (249, 4)
# (225, 4)
# (84, 4)
# (105, 4)
# (73, 4)
# (84, 4)
# (104, 4)
# (182, 4)
# (193, 4)
# (191, 4)
# (232, 4)
# (239, 4)
# (384, 4)
# (399, 4)
# (373, 4)
# (377, 4)
# (384, 4)
# (73, 4)
# (84, 4)
# (59, 4)
# (62, 4)
# (71, 4)
# (521, 4)
# (418, 4)
# (535, 4)
# (500, 4)
# (543, 4)
# (415, 4)
# (389, 4)
# (467, 4)
# (500, 4)
# (467, 4)
# (1001, 4)
# (795, 4)
# (835, 4)
# (1012, 4)
# (1005, 4)
# (177, 4)
# 134
# (218, 4)
# 135
# (159, 4)
# 136
# (176, 4)
# 137
# (207, 4)
# 138
# (414, 4)
# (406, 4)
# (468, 4)
# (510, 4)
# (516, 4)
# (248, 4)
# (271, 4)
# (230, 4)
# (252, 4)
# (270, 4)
# (146, 4)
# (141, 4)
# (163, 4)
# (168, 4)
# (166, 4)
# (143, 4)
# (144, 4)
# (151, 4)
# (162, 4)
# (142, 4)
# (668, 4)
# (541, 4)
# (646, 4)
# (640, 4)
# (547, 4)
# (602, 4)
# (614, 4)
# (585, 4)
# (597, 4)
# (632, 4)
# (738, 4)
# (646, 4)
# (642, 4)
# (752, 4)
# (854, 4)
# (53, 4)
# (56, 4)
# (64, 4)
# (58, 4)
# (607, 4)
# (735, 4)
# (659, 4)
# (614, 4)
# (646, 4)
# (1285, 4)
# (1262, 4)
# (1129, 4)
# (1184, 4)
# (1299, 4)
# (1023, 4)
# (849, 4)
# (1036, 4)
# (791, 4)
# (901, 4)
# (269, 4)
# (272, 4)
# (306, 4)
# (268, 4)
# (277, 4)
# (160, 4)
# (128, 4)
# (146, 4)
# (199, 4)
# (208, 4)
# (259, 4)
# (218, 4)
# (221, 4)
# (226, 4)
# (239, 4)
# (899, 4)
# (1004, 4)
# (902, 4)
# (948, 4)
# (849, 4)
# (220, 4)
# (218, 4)
# (181, 4)
# (195, 4)
# (207, 4)
# (174, 4)
# (204, 4)
# (191, 4)
# (192, 4)
# (177, 4)
# (45, 4)
# (41, 4)
# (51, 4)
# (51, 4)
# (44, 4)
# (53, 4)
# (53, 4)
# (163, 4)
# (141, 4)
# (172, 4)
# (176, 4)
# (130, 4)
# (77, 4)
# (57, 4)
# (89, 4)
# (111, 4)
# (130, 4)
# (139, 4)
# (105, 4)
# (123, 4)
# (122, 4)
# (128, 4)
# (123, 4)
# (129, 4)
# (112, 4)
# (130, 4)
# (146, 4)
# (127, 4)
# (166, 4)
# (1244, 4)
# (1173, 4)
# (1297, 4)
# (1440, 4)
# (972, 4)
# (50, 4)
# (43, 4)
# 139
# (57, 4)
# 140
# (44, 4)
# 141
# (49, 4)
# 142
# (46, 4)
# 143
# (304, 4)
# (312, 4)
# (286, 4)
# (281, 4)
# (280, 4)
# (206, 4)
# (195, 4)
# (174, 4)
# (151, 4)
# (135, 4)
# (45, 4)
# (64, 4)
# (81, 4)
# (55, 4)
# (49, 4)
# (55, 4)
# (961, 4)
# (1135, 4)
# (1352, 4)
# (1204, 4)
# (935, 4)
# (372, 4)
# (398, 4)
# (391, 4)
# (436, 4)
# (391, 4)
# (200, 4)
# (196, 4)
# (229, 4)
# (159, 4)
# (180, 4)
# (62, 4)
# (62, 4)
# (42, 4)
# (42, 4)
# (36, 4)
# (55, 4)
# (79, 4)
# (69, 4)
# (85, 4)
# (102, 4)
# (42, 4)
# (1438, 4)
# 144
# (1412, 4)
# 145
# (1080, 4)
# 146
# (1094, 4)
# 147
# (1189, 4)
# 148
# (622, 4)
# (605, 4)
# (587, 4)
# (630, 4)
# (654, 4)
# (285, 4)
# (260, 4)
# (271, 4)
# (282, 4)
# (318, 4)
# (344, 4)
# (378, 4)
# (327, 4)
# (325, 4)
# (360, 4)
# (128, 4)
# (143, 4)
# (160, 4)
# (129, 4)
# (157, 4)
# (94, 4)
# (92, 4)
# (107, 4)
# (91, 4)
# (122, 4)
# (109, 4)
# (122, 4)
# (114, 4)
# (129, 4)
# (131, 4)
# (200, 4)
# (226, 4)
# (164, 4)
# (198, 4)
# (159, 4)
# (592, 4)
# (611, 4)
# (669, 4)
# (566, 4)
# (779, 4)
# (550, 4)
# (500, 4)
# (604, 4)
# (523, 4)
# (504, 4)
# (34, 4)
# (38, 4)
# (54, 4)
# (44, 4)
# (36, 4)
# (241, 4)
# (199, 4)
# (234, 4)
# (266, 4)
# (250, 4)
# (554, 4)
# (649, 4)
# (588, 4)
# (663, 4)
# (684, 4)
# (66, 4)
# (66, 4)
# (59, 4)
# (66, 4)
# (31, 4)
# (30, 4)
# (44, 4)
# (66, 4)
# (36, 4)
# (74, 4)
# (62, 4)
# (104, 4)
# (88, 4)
# (60, 4)
# (841, 4)
# (979, 4)
# (900, 4)
# (985, 4)
# (936, 4)
# (259, 4)
# 149
# (308, 4)
# 150
# (268, 4)
# 151
# (245, 4)
# 152
# (270, 4)
# 153
# (1771, 4)
# (1770, 4)
# (1848, 4)
# (1757, 4)
# (1971, 4)
# (1653, 4)
# (1673, 4)
# (1723, 4)
# (1588, 4)
# (1618, 4)
# (638, 4)
# (860, 4)
# (785, 4)
# (689, 4)
# (714, 4)
# (403, 4)
# (361, 4)
# (319, 4)
# (318, 4)
# (408, 4)
# (52, 4)
# 154
# (44, 4)
# 155
# (47, 4)
# 156
# (53, 4)
# 157
# (47, 4)
# 158
# (46, 4)
# 159
# (45, 4)
# 160
# (51, 4)
# 161
# (52, 4)
# 162
# (51, 4)
# 163
# (62, 4)
# (58, 4)
# (50, 4)
# (72, 4)
# (44, 4)
# (18, 4)
# 164
# (23, 4)
# 165
# (279, 4)
# (280, 4)
# (241, 4)
# (313, 4)
# (340, 4)
# (1642, 4)
# (1798, 4)
# (1793, 4)
# (1362, 4)
# (1663, 4)
# (1285, 4)
# (1151, 4)
# (1264, 4)
# (1171, 4)
# (1248, 4)
# (633, 4)
# (750, 4)
# (659, 4)
# (748, 4)
# (669, 4)
# (1510, 4)
# (320, 4)
# 166
# (269, 4)
# 167
# (326, 4)
# 168
# (334, 4)
# 169
# (322, 4)
# 170
# (377, 4)
# 171
# (407, 4)
# 172
# (434, 4)
# 173
# (394, 4)
# 174
# (357, 4)
# 175
# (168, 4)
# (185, 4)
# (173, 4)
# (162, 4)
# (214, 4)
# (46, 4)
# 176
# (43, 4)
# 177
# (41, 4)
# 178
# (50, 4)
# 179
# (48, 4)
# 180
# (1959, 4)
# (1765, 4)
# (2024, 4)
# (120, 4)
# 181
# (93, 4)
# 182
# (108, 4)
# 183
# (106, 4)
# 184
# (88, 4)
# 185
# (63, 4)
# 186
# (53, 4)
# 187
# (67, 4)
# 188
# (75, 4)
# 189
# (56, 4)
# 190
# (29, 4)
# 191
# (31, 4)
# 192
# (27, 4)
# 193
# (24, 4)
# 194
# (24, 4)
# 195
# (28, 4)
# 196
# (25, 4)
# 197
# (37, 4)
# 198
# (31, 4)
# 199
# (27, 4)
# 200
# (275, 4)
# (281, 4)
# (292, 4)
# (259, 4)
# (315, 4)
# (349, 4)
# (274, 4)
# (283, 4)
# (326, 4)
# (342, 4)
# (275, 4)
# (250, 4)
# (238, 4)
# (209, 4)
# (281, 4)
# (29, 4)
# 201
# (25, 4)
# 202
# (24, 4)
# 203
# (25, 4)
# 204
# (30, 4)
# 205
# (293, 4)
# 206
# (318, 4)
# 207
# (296, 4)
# 208
# (330, 4)
# 209
# (272, 4)
# 210
# (463, 4)
# 211
# (410, 4)
# 212
# (456, 4)
# 213
# (547, 4)
# 214
# (489, 4)
# 215
# (1367, 4)
# (1452, 4)
# (1485, 4)
# (1310, 4)
# (1238, 4)
# (1853, 4)
# (1838, 4)
# (1859, 4)
# (1665, 4)
# (1615, 4)
# (72, 4)
# (82, 4)
# (71, 4)
# (73, 4)
# (81, 4)
# (45, 4)
# 216
# (39, 4)
# 217
# (43, 4)
# 218
# (45, 4)
# 219
# (48, 4)
# 220
# (36, 4)
# 221
# (40, 4)
# 222
# (39, 4)
# 223
# (35, 4)
# 224
# (37, 4)
# 225
# (31, 4)
# 226
# (29, 4)
# 227
# (30, 4)
# 228
# (35, 4)
# 229
# (37, 4)
# 230
# (189, 4)
# (242, 4)
# (236, 4)
# (216, 4)
# (192, 4)
# (1996, 4)
# (1990, 4)
# (1417, 4)
# (1766, 4)
# (1076, 4)
# (951, 4)
# (1241, 4)
# (1260, 4)
# (930, 4)
# (1092, 4)
# (1102, 4)
# (1012, 4)
# (995, 4)
# (1025, 4)
# (452, 4)
# (465, 4)
# (528, 4)
# (483, 4)
# (427, 4)
# (386, 4)
# (485, 4)
# (477, 4)
# (456, 4)
# (419, 4)
# (224, 4)
# (222, 4)
# (248, 4)
# (213, 4)
# (208, 4)
# (123, 4)
# (127, 4)
# (132, 4)
# (125, 4)
# (133, 4)
# (142, 4)
# (156, 4)
# (152, 4)
# (146, 4)
# (165, 4)
# (323, 4)
# (262, 4)
# (300, 4)
# (338, 4)
# (350, 4)
# (76, 4)
# 231
# (59, 4)
# 232
# (75, 4)
# 233
# (71, 4)
# 234
# (77, 4)
# 235
# (509, 4)
# (476, 4)
# (418, 4)
# (551, 4)
# (476, 4)
# (96, 4)
# (102, 4)
# (73, 4)
# (92, 4)
# (97, 4)
# (125, 4)
# (112, 4)
# (129, 4)
# (147, 4)
# (190, 4)
# (93, 4)
# (105, 4)
# (113, 4)
# (111, 4)
# (98, 4)
# (156, 4)
# (169, 4)
# (124, 4)
# (154, 4)
# (168, 4)
# (1847, 4)
# (1782, 4)
# (2045, 4)
# (1755, 4)
# (1810, 4)
# (906, 4)
# (1208, 4)
# (1051, 4)
# (1201, 4)
# (1215, 4)
# (540, 4)
# (476, 4)
# (540, 4)
# (520, 4)
# (478, 4)
# (200, 4)
# (188, 4)
# (140, 4)
# (210, 4)
# (205, 4)
# (47, 4)
# (45, 4)
# (39, 4)
# (45, 4)
# (83, 4)
# (145, 4)
# (129, 4)
# (128, 4)
# (146, 4)
# (139, 4)
# (140, 4)
# (162, 4)
# (171, 4)
# 236
# (126, 4)
# 237
# (135, 4)
# 238
# (172, 4)
# 239
# (145, 4)
# 240
# (216, 4)
# (196, 4)
# (200, 4)
# (174, 4)
# (175, 4)
# (45, 4)
# (54, 4)
# (55, 4)
# (53, 4)
# (55, 4)
# (104, 4)
# (119, 4)
# (121, 4)
# (124, 4)
# (122, 4)
# (222, 4)
# 241
# (195, 4)
# 242
# (228, 4)
# 243
# (210, 4)
# 244
# (228, 4)
# 245
# (921, 4)
# (970, 4)
# (887, 4)
# (729, 4)
# (743, 4)
# (1487, 4)
# (1398, 4)
# (1236, 4)
# (1305, 4)
# (1203, 4)
# (307, 4)
# (307, 4)
# (348, 4)
# (396, 4)
# (350, 4)
# (92, 4)
# (101, 4)
# (97, 4)
# (112, 4)
# (122, 4)
# (332, 4)
# (279, 4)
# (320, 4)
# (327, 4)
# (344, 4)
# (125, 4)
# (134, 4)
# (122, 4)
# (106, 4)
# (151, 4)
# (98, 4)
# (87, 4)
# (111, 4)
# (103, 4)
# (81, 4)
# (250, 4)
# (220, 4)
# (270, 4)
# (236, 4)
# (207, 4)
# (2037, 4)
# (1870, 4)
# (1790, 4)
# (441, 4)
# (481, 4)
# (485, 4)
# (519, 4)
# (482, 4)
# (849, 4)
# (954, 4)
# (959, 4)
# (886, 4)
# (878, 4)
# (364, 4)
# (363, 4)
# (389, 4)
# (354, 4)
# (353, 4)
# (164, 4)
# (195, 4)
# (180, 4)
# (168, 4)
# (183, 4)
# (278, 4)
# (271, 4)
# (257, 4)
# (258, 4)
# (237, 4)
# (92, 4)
# (155, 4)
# (116, 4)
# (93, 4)
# (95, 4)
# (54, 4)
# (59, 4)
# (87, 4)
# (90, 4)
# (116, 4)
# (91, 4)
# (107, 4)
# (264, 4)
# (312, 4)
# (244, 4)
# (222, 4)
# (188, 4)
# (83, 4)
# (86, 4)
# (73, 4)
# (70, 4)
# (90, 4)
# (46, 4)
# (37, 4)
# (51, 4)
# (38, 4)
# (46, 4)
# (231, 4)
# (254, 4)
# (201, 4)
# (238, 4)
# (282, 4)
# (31, 4)
# (34, 4)
# (28, 4)
# (30, 4)
# (28, 4)
# (1133, 4)
# (1559, 4)
# (1266, 4)
# (1430, 4)
# (1156, 4)
# (806, 4)
# (775, 4)
# (870, 4)
# (935, 4)
# (859, 4)
# (216, 4)
# (165, 4)
# (153, 4)
# (189, 4)
# (169, 4)
# (96, 4)
# (103, 4)
# (87, 4)
# (84, 4)
# (110, 4)
# (428, 4)
# (421, 4)
# (493, 4)
# (502, 4)
# (426, 4)
# (350, 4)
# (324, 4)
# (341, 4)
# (357, 4)
# (364, 4)
# (385, 4)
# (373, 4)
# (332, 4)
# (414, 4)
# (379, 4)
# (118, 4)
# (100, 4)
# (111, 4)
# (136, 4)
# (115, 4)
# (227, 4)
# (197, 4)
# (248, 4)
# (239, 4)
# (226, 4)
# (60, 4)
# (72, 4)
# (82, 4)
# (74, 4)
# (67, 4)
# (34, 4)
# (35, 4)
# (41, 4)
# (36, 4)
# (38, 4)
# (231, 4)
# (186, 4)
# (223, 4)
# (224, 4)
# (232, 4)
# (616, 4)
# (459, 4)
# (555, 4)
# (674, 4)
# (805, 4)
# (1367, 4)
# (1396, 4)
# (1293, 4)
# (1416, 4)
# (1331, 4)
# (827, 4)
# (861, 4)
# (1036, 4)
# (829, 4)
# (780, 4)
# (365, 4)
# (401, 4)
# (410, 4)
# (314, 4)
# (369, 4)
# (381, 4)
# (440, 4)
# (409, 4)
# (377, 4)
# (381, 4)
# (87, 4)
# (76, 4)
# (79, 4)
# (69, 4)
# (67, 4)
# (78, 4)
# (93, 4)
# (119, 4)
# (90, 4)
# (121, 4)
# (104, 4)
# (92, 4)
# (100, 4)
# (99, 4)
# (119, 4)
# (106, 4)
# (158, 4)
# (131, 4)
# (126, 4)
# (114, 4)
# (500, 4)
# (490, 4)
# (518, 4)
# (535, 4)
# (468, 4)
# (536, 4)
# (512, 4)
# (419, 4)
# (471, 4)
# (510, 4)
# (184, 4)
# (213, 4)
# (180, 4)
# (180, 4)
# (202, 4)
# (38, 4)
# (34, 4)
# (40, 4)
# (16, 4)
# (48, 4)
# (78, 4)
# (67, 4)
# (77, 4)
# (72, 4)
# (75, 4)
# (65, 4)
# (60, 4)
# (43, 4)
# (45, 4)
# (62, 4)
# (1187, 4)
# (1185, 4)
# (1522, 4)
# (1738, 4)
# (1305, 4)
# (656, 4)
# (640, 4)
# (727, 4)
# (658, 4)
# (689, 4)
# (229, 4)
# (219, 4)
# (218, 4)
# (212, 4)
# (258, 4)
# (1446, 4)
# (1607, 4)
# (1416, 4)
# (1220, 4)
# (1475, 4)
# (613, 4)
# (521, 4)
# (563, 4)
# (655, 4)
# (640, 4)
# (2042, 4)
# (1241, 4)
# (976, 4)
# (1084, 4)
# (1272, 4)
# (891, 4)
# (600, 4)
# (625, 4)
# (616, 4)
# (634, 4)
# (696, 4)
# (318, 4)
# (294, 4)
# (314, 4)
# (295, 4)
# (348, 4)
# (114, 4)
# (97, 4)
# (128, 4)
# (117, 4)
# (134, 4)
# (1550, 4)
# (1470, 4)
# (1614, 4)
# (1413, 4)
# (1524, 4)
# (184, 4)
# (265, 4)
# (231, 4)
# (224, 4)
# (228, 4)
# (216, 4)
# 246
# (218, 4)
# 247
# (225, 4)
# 248
# (202, 4)
# 249
# (190, 4)
# 250
# (154, 4)
# 251
# (154, 4)
# 252
# (183, 4)
# 253
# (153, 4)
# 254
# (161, 4)
# 255
# (206, 4)
# (204, 4)
# (252, 4)
# (220, 4)
# (257, 4)
# (25, 4)
# (27, 4)
# (32, 4)
# (1562, 4)
# (1672, 4)
# (1987, 4)
# (1519, 4)
# (1290, 4)
# (568, 4)
# (607, 4)
# (574, 4)
# (563, 4)
# (581, 4)
# (582, 4)
# (564, 4)
# (496, 4)
# (636, 4)
# (649, 4)
# (408, 4)
# (373, 4)
# (394, 4)
# (354, 4)
# (437, 4)
# (331, 4)
# (326, 4)
# (283, 4)
# (361, 4)
# (264, 4)
# (96, 4)
# (81, 4)
# (79, 4)
# (73, 4)
# (70, 4)
# (286, 4)
# (287, 4)
# (338, 4)
# (384, 4)
# (364, 4)
# (75, 4)
# 256
# (73, 4)
# 257
# (84, 4)
# 258
# (77, 4)
# 259
# (84, 4)
# 260
# (30, 4)
# (81, 4)
# (96, 4)
# (119, 4)
# (103, 4)
# (133, 4)
# (80, 4)
# (68, 4)
# (92, 4)
# (69, 4)
# (83, 4)
# (55, 4)
# (73, 4)
# (69, 4)
# (68, 4)
# (231, 4)
# (208, 4)
# (242, 4)
# (228, 4)
# (229, 4)
# (1572, 4)
# (1637, 4)
# (1677, 4)
# (1594, 4)
# (1516, 4)
# (1034, 4)
# (1192, 4)
# (1205, 4)
# (970, 4)
# (873, 4)
# (236, 4)
# (248, 4)
# (227, 4)
# (230, 4)
# (211, 4)
# (163, 4)
# (101, 4)
# (121, 4)
# (138, 4)
# (136, 4)
# (66, 4)
# (59, 4)
# (66, 4)
# (51, 4)
# (82, 4)
# (600, 4)
# 261
# (606, 4)
# 262
# (514, 4)
# 263
# (603, 4)
# 264
# (546, 4)
# 265
# (284, 4)
# 266
# (213, 4)
# 267
# (286, 4)
# 268
# (222, 4)
# 269
# (269, 4)
# 270
# (281, 4)
# 271
# (282, 4)
# 272
# (296, 4)
# 273
# (317, 4)
# 274
# (280, 4)
# 275
# (191, 4)
# 276
# (181, 4)
# 277
# (226, 4)
# 278
# (195, 4)
# 279
# (154, 4)
# 280
# (180, 4)
# (164, 4)
# (167, 4)
# (193, 4)
# (189, 4)
# (1255, 4)
# 281
# (1144, 4)
# 282
# (1142, 4)
# 283
# (1226, 4)
# 284
# (1114, 4)
# 285
# (1498, 4)
# (1516, 4)
# (2035, 4)
# (1609, 4)
# (1728, 4)
# (513, 4)
# (484, 4)
# (564, 4)
# (513, 4)
# (563, 4)
# (309, 4)
# (371, 4)
# (382, 4)
# (323, 4)
# (349, 4)
# (1799, 4)
# (1625, 4)
# (1506, 4)
# (553, 4)
# 286
# (607, 4)
# 287
# (462, 4)
# 288
# (637, 4)
# 289
# (605, 4)
# 290
# (52, 4)
# (365, 4)
# (355, 4)
# (369, 4)
# (303, 4)
# (369, 4)
# (346, 4)
# 291
# (379, 4)
# 292
# (358, 4)
# 293
# (324, 4)
# 294
# (350, 4)
# 295
# (177, 4)
# 296
# (250, 4)
# 297
# (238, 4)
# 298
# (241, 4)
# 299
# (221, 4)
# 300
# (14, 4)
# (28, 4)
# (30, 4)
# (15, 4)
# (37, 4)
# (1905, 4)
# (1646, 4)
# (1820, 4)
# (161, 4)
# 301
# (144, 4)
# 302
# (158, 4)
# 303
# (140, 4)
# 304
# (152, 4)
# 305
# (1975, 4)
# (1250, 4)
# 306
# (1199, 4)
# 307
# (1286, 4)
# 308
# (1311, 4)
# 309
# (1331, 4)
# 310
# (964, 4)
# (941, 4)
# (948, 4)
# (927, 4)
# (952, 4)
# (748, 4)
# (768, 4)
# (794, 4)
# (803, 4)
# (793, 4)
# (629, 4)
# (555, 4)
# (609, 4)
# (633, 4)
# (700, 4)
# (156, 4)
# (199, 4)
# (134, 4)
# (143, 4)
# (161, 4)
# (103, 4)
# (115, 4)
# (123, 4)
# (94, 4)
# (104, 4)
# (550, 4)
# (551, 4)
# (482, 4)
# (555, 4)
# (598, 4)
# (275, 4)
# (301, 4)
# (325, 4)
# (305, 4)
# (253, 4)
# (610, 4)
# (641, 4)
# (575, 4)
# (664, 4)
# (591, 4)
# (326, 4)
# (355, 4)
# (321, 4)
# (372, 4)
# (376, 4)
# (108, 4)
# (87, 4)
# (77, 4)
# (95, 4)
# (96, 4)
# (1802, 4)
# (1515, 4)
# (1830, 4)
# (1926, 4)
# (1827, 4)
# (1182, 4)
# (1161, 4)
# (1242, 4)
# (1307, 4)
# (1209, 4)
# (181, 4)
# (156, 4)
# (170, 4)
# (153, 4)
# (148, 4)
# (46, 4)
# (45, 4)
# (41, 4)
# (44, 4)
# (41, 4)
# (2029, 4)
# (1819, 4)
# (1522, 4)
# (1876, 4)
# (1773, 4)
# (1718, 4)
# (219, 4)
# (260, 4)
# (187, 4)
# (219, 4)
# (218, 4)
# (351, 4)
# (357, 4)
# (307, 4)
# (364, 4)
# (347, 4)
# (1657, 4)
# (1797, 4)
# (1378, 4)
# (1498, 4)
# (1645, 4)
# (337, 4)
# 311
# (345, 4)
# 312
# (348, 4)
# 313
# (364, 4)
# 314
# (354, 4)
# 315
# (231, 4)
# (190, 4)
# (182, 4)
# (195, 4)
# (218, 4)
# (170, 4)
# (177, 4)
# (196, 4)
# (152, 4)
# (141, 4)
# (142, 4)
# (121, 4)
# (173, 4)
# (133, 4)
# (164, 4)
# (278, 4)
# (313, 4)
# (281, 4)
# (250, 4)
# (315, 4)
# (82, 4)
# (64, 4)
# (61, 4)
# (72, 4)
# (68, 4)
# (639, 4)
# (733, 4)
# (786, 4)
# (754, 4)
# (767, 4)
# (52, 4)
# (55, 4)
# (45, 4)
# (41, 4)
# (54, 4)
# (429, 4)
# (356, 4)
# (414, 4)
# (439, 4)
# (374, 4)
# (109, 4)
# (154, 4)
# (137, 4)
# (119, 4)
# (154, 4)
# (36, 4)
# (34, 4)
# (31, 4)
# (40, 4)
# (26, 4)
# (382, 4)
# (346, 4)
# (318, 4)
# (374, 4)
# (321, 4)
# (124, 4)
# 316
# (96, 4)
# 317
# (126, 4)
# 318
# (107, 4)
# 319
# (123, 4)
# 320
# (177, 4)
# (224, 4)
# (228, 4)
# (174, 4)
# (247, 4)
# (92, 4)
# (87, 4)
# (63, 4)
# (691, 4)
# (739, 4)
# (735, 4)
# (679, 4)
# (664, 4)
# (228, 4)
# (184, 4)
# (193, 4)
# (201, 4)
# (196, 4)
# (152, 4)
# (160, 4)
# (124, 4)
# (149, 4)
# (157, 4)
# (57, 4)
# (66, 4)
# (59, 4)
# (62, 4)
# (73, 4)
# (109, 4)
# (116, 4)
# (130, 4)
# (120, 4)
# (108, 4)
# (102, 4)
# (116, 4)
# (75, 4)
# (89, 4)
# (101, 4)
# (149, 4)
# (162, 4)
# (115, 4)
# (119, 4)
# (130, 4)
# (498, 4)
# (542, 4)
# (484, 4)
# (526, 4)
# (578, 4)
# (345, 4)
# (460, 4)
# (398, 4)
# (354, 4)
# (389, 4)
# (232, 4)
# (254, 4)
# (254, 4)
# (271, 4)
# (223, 4)
# (157, 4)
# (142, 4)
# (110, 4)
# (126, 4)
# (161, 4)
# (383, 4)
# (352, 4)
# (387, 4)
# (326, 4)
# (400, 4)
# (1831, 4)
# (1532, 4)
# (1628, 4)
# (1487, 4)
# (1670, 4)
# (1512, 4)
# (827, 4)
# (880, 4)
# (759, 4)
# (665, 4)
# (882, 4)
# (770, 4)
# (879, 4)
# (730, 4)
# (794, 4)
# (872, 4)
# (414, 4)
# (490, 4)
# (401, 4)
# (544, 4)
# (495, 4)
# (156, 4)
# (175, 4)
# (156, 4)
# (173, 4)
# (186, 4)
# (137, 4)
# (115, 4)
# (128, 4)
# (105, 4)
# (110, 4)
# (57, 4)
# (77, 4)
# (85, 4)
# (94, 4)
# (82, 4)
# (97, 4)
# (100, 4)
# (94, 4)
# (92, 4)
# (100, 4)
# (1519, 4)
# (1317, 4)
# (1633, 4)
# (1503, 4)
# (1599, 4)
# (1128, 4)
# (1053, 4)
# (1181, 4)
# (975, 4)
# (1150, 4)
# (240, 4)
# (278, 4)
# (278, 4)
# (282, 4)
# (272, 4)
# (242, 4)
# (282, 4)
# (240, 4)
# (232, 4)
# (301, 4)
# (648, 4)
# (620, 4)
# (620, 4)
# (653, 4)
# (665, 4)
# (878, 4)
# (934, 4)
# (927, 4)
# (819, 4)
# (946, 4)
# (1037, 4)
# (990, 4)
# (1111, 4)
# (926, 4)
# (1077, 4)
# (962, 4)
# (1080, 4)
# (1176, 4)
# (1027, 4)
# (855, 4)
# (526, 4)
# (551, 4)
# (662, 4)
# (585, 4)
# (643, 4)
# (1136, 4)
# (1224, 4)
# (1289, 4)
# (1142, 4)
# (1196, 4)
# (212, 4)
# (172, 4)
# (159, 4)
# (182, 4)
# (139, 4)
# (243, 4)
# (285, 4)
# (287, 4)
# (287, 4)
# (327, 4)
# (127, 4)
# (103, 4)
# (128, 4)
# (132, 4)
# (113, 4)
# (47, 4)
# (51, 4)
# (47, 4)
# (53, 4)
# (54, 4)
# (106, 4)
# (95, 4)
# (103, 4)
# (115, 4)
# (98, 4)
# (522, 4)
# (436, 4)
# (478, 4)
# (454, 4)
# (439, 4)
# (211, 4)
# (282, 4)
# (257, 4)
# (221, 4)
# (257, 4)
# (127, 4)
# (146, 4)
# (133, 4)
# (138, 4)
# (137, 4)
# (11, 4)
# (10, 4)
# (728, 4)
# (589, 4)
# (630, 4)
# (639, 4)
# (673, 4)
# (455, 4)
# (511, 4)
# (514, 4)
# (538, 4)
# (578, 4)
# (263, 4)
# (249, 4)
# (245, 4)
# (223, 4)
# (202, 4)
# (156, 4)
# (165, 4)
# (164, 4)
# (165, 4)
# (152, 4)
# (1303, 4)
# (1189, 4)
# (1157, 4)
# (1401, 4)
# (1201, 4)
# (266, 4)
# (295, 4)
# (286, 4)
# (272, 4)
# (323, 4)
# (102, 4)
# (90, 4)
# (103, 4)
# (98, 4)
# (91, 4)
# (77, 4)
# (61, 4)
# (62, 4)
# (55, 4)
# (76, 4)
# (62, 4)
# (88, 4)
# (69, 4)
# (82, 4)
# (75, 4)
# (206, 4)
# (251, 4)
# (203, 4)
# (285, 4)
# (239, 4)
# (1818, 4)
# (2017, 4)
# (1439, 4)
# (1365, 4)
# (1353, 4)
# (1458, 4)
# (1437, 4)
# (1506, 4)
# (1375, 4)
# (731, 4)
# (715, 4)
# (540, 4)
# (698, 4)
# (603, 4)
# (605, 4)
# (726, 4)
# (655, 4)
# (637, 4)
# (736, 4)
# (377, 4)
# (376, 4)
# (351, 4)
# (321, 4)
# (359, 4)
# (319, 4)
# (335, 4)
# (354, 4)
# (314, 4)
# (357, 4)
# (183, 4)
# (186, 4)
# (201, 4)
# (166, 4)
# (189, 4)
# (93, 4)
# (83, 4)
# (127, 4)
# (114, 4)
# (90, 4)
# (155, 4)
# (159, 4)
# (142, 4)
# (154, 4)
# (161, 4)
# (243, 4)
# (297, 4)
# (295, 4)
# (295, 4)
# (268, 4)
# (69, 4)
# 321
# (63, 4)
# 322
# (65, 4)
# 323
# (75, 4)
# 324
# (60, 4)
# 325
# (360, 4)
# (348, 4)
# (350, 4)
# (330, 4)
# (445, 4)
# (91, 4)
# (96, 4)
# (93, 4)
# (80, 4)
# (87, 4)
# (86, 4)
# (108, 4)
# (94, 4)
# (94, 4)
# (99, 4)
# (138, 4)
# (139, 4)
# (148, 4)
# (123, 4)
# (133, 4)
# (773, 4)
# (686, 4)
# (764, 4)
# (817, 4)
# (749, 4)
# (136, 4)
# (146, 4)
# (149, 4)
# (132, 4)
# (173, 4)
# (185, 4)
# (170, 4)
# (185, 4)
# (221, 4)
# (57, 4)
# (84, 4)
# (82, 4)
# (73, 4)
# (77, 4)
# (74, 4)
# (474, 4)
# (497, 4)
# (468, 4)
# (499, 4)
# (530, 4)
# (848, 4)
# (850, 4)
# (779, 4)
# (725, 4)
# (725, 4)
# (1610, 4)
# (1826, 4)
# (1640, 4)
# (1374, 4)
# (1452, 4)
# (356, 4)
# 326
# (320, 4)
# 327
# (420, 4)
# 328
# (352, 4)
# 329
# (384, 4)
# 330
# (618, 4)
# (819, 4)
# (688, 4)
# (742, 4)
# (725, 4)
# (530, 4)
# (455, 4)
# (471, 4)
# (428, 4)
# (612, 4)
# (358, 4)
# (333, 4)
# (390, 4)
# (419, 4)
# (358, 4)
# (213, 4)
# (225, 4)
# (229, 4)
# (229, 4)
# (230, 4)
# (175, 4)
# (195, 4)
# (175, 4)
# (191, 4)
# (163, 4)
# (110, 4)
# (133, 4)
# (115, 4)
# (125, 4)
# (154, 4)
# (182, 4)
# (168, 4)
# (203, 4)
# (177, 4)
# (187, 4)
# (1027, 4)
# (1193, 4)
# (1032, 4)
# (996, 4)
# (931, 4)
# (1924, 4)
# (1191, 4)
# (1386, 4)
# (1224, 4)
# (1251, 4)
# (1326, 4)
# (985, 4)
# (1136, 4)
# (933, 4)
# (907, 4)
# (981, 4)
# (71, 4)
# 331
# (71, 4)
# 332
# (73, 4)
# 333
# (68, 4)
# 334
# (60, 4)
# 335
# (32, 4)
# 336
# (33, 4)
# 337
# (35, 4)
# 338
# (36, 4)
# 339
# (39, 4)
# 340
# (284, 4)
# (246, 4)
# (353, 4)
# (276, 4)
# (266, 4)
# (32, 4)
# (88, 4)
# (94, 4)
# (97, 4)
# (104, 4)
# (105, 4)
# (816, 4)
# (814, 4)
# (670, 4)
# (864, 4)
# (689, 4)
# (204, 4)
# 341
# (208, 4)
# 342
# (196, 4)
# 343
# (248, 4)
# 344
# (201, 4)
# 345
# (385, 4)
# 346
# (393, 4)
# 347
# (457, 4)
# 348
# (443, 4)
# 349
# (411, 4)
# 350
# (261, 4)
# 351
# (220, 4)
# 352
# (259, 4)
# 353
# (251, 4)
# 354
# (259, 4)
# 355
# (170, 4)
# 356
# (180, 4)
# 357
# (151, 4)
# 358
# (165, 4)
# 359
# (167, 4)
# 360
# (174, 4)
# 361
# (180, 4)
# 362
# (211, 4)
# 363
# (172, 4)
# 364
# (168, 4)
# 365
# (195, 4)
# 366
# (212, 4)
# 367
# (239, 4)
# 368
# (243, 4)
# 369
# (236, 4)
# 370
# (185, 4)
# (136, 4)
# (155, 4)
# (164, 4)
# (141, 4)
# (53, 4)
# (51, 4)
# (405, 4)
# (387, 4)
# (408, 4)
# (426, 4)
# (369, 4)
# (1631, 4)
# (1785, 4)
# (1528, 4)
# (1798, 4)
# (1910, 4)
# (623, 4)
# (599, 4)
# (604, 4)
# (659, 4)
# (641, 4)
# (320, 4)
# (266, 4)
# (413, 4)
# (302, 4)
# (316, 4)
# (377, 4)
# (410, 4)
# (389, 4)
# (463, 4)
# (410, 4)
# (104, 4)
# (68, 4)
# (74, 4)
# (108, 4)
# (106, 4)
# (428, 4)
# (452, 4)
# (413, 4)
# (529, 4)
# (401, 4)
# (301, 4)
# (245, 4)
# (278, 4)
# (272, 4)
# (301, 4)
# (89, 4)
# (113, 4)
# (126, 4)
# (85, 4)
# (422, 4)
# (357, 4)
# (377, 4)
# (341, 4)
# (443, 4)
# (238, 4)
# (210, 4)
# (284, 4)
# (227, 4)
# (247, 4)
# (1001, 4)
# (843, 4)
# (784, 4)
# (948, 4)
# (1060, 4)
# (1602, 4)
# (1880, 4)
# (1762, 4)
# (1063, 4)
# (1184, 4)
# (1183, 4)
# (992, 4)
# (981, 4)
# (393, 4)
# (339, 4)
# (445, 4)
# (482, 4)
# (438, 4)
# (74, 4)
# (102, 4)
# (86, 4)
# (102, 4)
# (80, 4)
# (227, 4)
# (251, 4)
# (246, 4)
# (249, 4)
# (253, 4)
# (199, 4)
# (213, 4)
# (200, 4)
# (180, 4)
# (188, 4)
# (162, 4)
# (199, 4)
# (216, 4)
# (182, 4)
# (238, 4)
# (209, 4)
# 371
# (194, 4)
# 372
# (254, 4)
# 373
# (191, 4)
# 374
# (228, 4)
# 375
# (390, 4)
# 376
# (459, 4)
# 377
# (414, 4)
# 378
# (468, 4)
# 379
# (442, 4)
# 380
# (248, 4)
# 381
# (289, 4)
# 382
# (250, 4)
# 383
# (271, 4)
# 384
# (208, 4)
# 385
# (795, 4)
# 386
# (840, 4)
# 387
# (801, 4)
# 388
# (802, 4)
# 389
# (895, 4)
# 390
# (313, 4)
# (381, 4)
# (467, 4)
# (376, 4)
# (325, 4)
# (36, 4)
# 391
# (35, 4)
# 392
# (29, 4)
# 393
# (34, 4)
# 394
# (29, 4)
# 395
# (1245, 4)
# 396
# (1428, 4)
# 397
# (1354, 4)
# 398
# (1417, 4)
# 399
# (1378, 4)
# 400
# (1000, 4)
# (1226, 4)
# (1006, 4)
# (1126, 4)
# (1092, 4)
# (1105, 4)
# (1159, 4)
# (996, 4)
# (1188, 4)
# (982, 4)
# (125, 4)
# (162, 4)
# (134, 4)
# (149, 4)
# (173, 4)
# (1309, 4)
# (1561, 4)
# (1236, 4)
# (1527, 4)
# (1587, 4)
# (547, 4)
# 401
# (607, 4)
# 402
# (653, 4)
# 403
# (550, 4)
# 404
# (607, 4)
# 405
# (164, 4)
# (140, 4)
# (119, 4)
# (699, 4)
# (833, 4)
# (846, 4)
# (852, 4)
# (746, 4)
# (174, 4)
# 406
# (174, 4)
# 407
# (185, 4)
# 408
# (165, 4)
# 409
# (154, 4)
# 410
# (101, 4)
# 411
# (112, 4)
# 412
# (120, 4)
# 413
# (102, 4)
# 414
# (101, 4)
# 415
# (83, 4)
# 416
# (86, 4)
# 417
# (91, 4)
# 418
# (67, 4)
# 419
# (88, 4)
# 420
# (38, 4)
# 421
# (32, 4)
# 422
# (38, 4)
# 423
# (34, 4)
# 424
# (38, 4)
# 425
# (76, 4)
# (103, 4)
# (83, 4)
# (86, 4)
# (73, 4)
# (267, 4)
# (299, 4)
# (312, 4)
# (280, 4)
# (256, 4)
# (115, 4)
# (124, 4)
# (112, 4)
# (113, 4)
# (131, 4)
# (38, 4)
# (40, 4)
# (32, 4)
# (44, 4)
# (43, 4)
# (528, 4)
# (556, 4)
# (575, 4)
# (507, 4)
# (516, 4)
# (1917, 4)
# (1851, 4)
# (1849, 4)
# (1749, 4)
# (1793, 4)
# (891, 4)
# (936, 4)
# (910, 4)
# (917, 4)
# (991, 4)
# (739, 4)
# (542, 4)
# (659, 4)
# (718, 4)
# (666, 4)
# (464, 4)
# (396, 4)
# (373, 4)
# (408, 4)
# (409, 4)
# (198, 4)
# (190, 4)
# (202, 4)
# (162, 4)
# (202, 4)
# (192, 4)
# (148, 4)
# (175, 4)
# (148, 4)
# (154, 4)
# (619, 4)
# (616, 4)
# (547, 4)
# (491, 4)
# (565, 4)
# (358, 4)
# (407, 4)
# (433, 4)
# (426, 4)
# (328, 4)
# (1881, 4)
# (1501, 4)
# (1637, 4)
# (1922, 4)
# (815, 4)
# (929, 4)
# (748, 4)
# (777, 4)
# (944, 4)
# (230, 4)
# (241, 4)
# (303, 4)
# (230, 4)
# (248, 4)
# (71, 4)
# (63, 4)
# (46, 4)
# (66, 4)
# (53, 4)
# (169, 4)
# (125, 4)
# (201, 4)
# (195, 4)
# (171, 4)
# (208, 4)
# (182, 4)
# (185, 4)
# (180, 4)
# (159, 4)
# (194, 4)
# (207, 4)
# (183, 4)
# (167, 4)
# (188, 4)
# (223, 4)
# 426
# (253, 4)
# 427
# (203, 4)
# 428
# (239, 4)
# 429
# (217, 4)
# 430
# (357, 4)
# (318, 4)
# (359, 4)
# (325, 4)
# (364, 4)
# (284, 4)
# (328, 4)
# (354, 4)
# (364, 4)
# (353, 4)
# (66, 4)
# 431
# (64, 4)
# 432
# (69, 4)
# 433
# (70, 4)
# 434
# (79, 4)
# 435
# (63, 4)
# 436
# (69, 4)
# 437
# (66, 4)
# 438
# (55, 4)
# 439
# (67, 4)
# 440
# (150, 4)
# (138, 4)
# (135, 4)
# (144, 4)
# (123, 4)
# (78, 4)
# 441
# (76, 4)
# 442
# (67, 4)
# 443
# (61, 4)
# 444
# (69, 4)
# 445
# (70, 4)
# 446
# (51, 4)
# 447
# (73, 4)
# 448
# (69, 4)
# 449
# (67, 4)
# 450
# (61, 4)
# 451
# (51, 4)
# 452
# (56, 4)
# 453
# (62, 4)
# 454
# (62, 4)
# 455
# (108, 4)
# 456
# (109, 4)
# 457
# (121, 4)
# 458
# (88, 4)
# 459
# (110, 4)
# 460
# (1508, 4)
# (1339, 4)
# (1288, 4)
# (1060, 4)
# (1276, 4)
# (288, 4)
# (277, 4)
# (289, 4)
# (279, 4)
# (346, 4)
# (155, 4)
# (128, 4)
# (142, 4)
# (146, 4)
# (126, 4)
# (119, 4)
# (106, 4)
# (114, 4)
# (66, 4)
# (90, 4)
# (1120, 4)
# (1015, 4)
# (923, 4)
# (1134, 4)
# (934, 4)
# (160, 4)
# (143, 4)
# (104, 4)
# (159, 4)
# (117, 4)
# (129, 4)
# (174, 4)
# (146, 4)
# (145, 4)
# (159, 4)
# (79, 4)
# (65, 4)
# (75, 4)
# (89, 4)
# (54, 4)
# (85, 4)
# (87, 4)
# (109, 4)
# (100, 4)
# (98, 4)
# (139, 4)
# (147, 4)
# (180, 4)
# (142, 4)
# (174, 4)
# (225, 4)
# (207, 4)
# (243, 4)
# (222, 4)
# (233, 4)
# (985, 4)
# (852, 4)
# (1036, 4)
# (1033, 4)
# (935, 4)
# (1161, 4)
# (1694, 4)
# (1266, 4)
# (1775, 4)
# (1560, 4)
# (32, 4)
# (31, 4)
# (24, 4)
# (1952, 4)
# (1948, 4)
# (1732, 4)
# (639, 4)
# (598, 4)
# (641, 4)
# (857, 4)
# (630, 4)
# (841, 4)
# (713, 4)
# (718, 4)
# (963, 4)
# (817, 4)
# (49, 4)
# 461
# (61, 4)
# 462
# (61, 4)
# 463
# (74, 4)
# 464
# (62, 4)
# 465
# (199, 4)
# (203, 4)
# (199, 4)
# (200, 4)
# (183, 4)
# (36, 4)
# (30, 4)
# (33, 4)
# (43, 4)
# (134, 4)
# (120, 4)
# (119, 4)
# (134, 4)
# (119, 4)
# (80, 4)
# (66, 4)
# (66, 4)
# (76, 4)
# (74, 4)
# (52, 4)
# (37, 4)
# (40, 4)
# (44, 4)
# (64, 4)
# (149, 4)
# (124, 4)
# (116, 4)
# (130, 4)
# (106, 4)
# (1519, 4)
# (1734, 4)
# (1343, 4)
# (1478, 4)
# (1881, 4)
# (438, 4)
# (584, 4)
# (537, 4)
# (562, 4)
# (439, 4)
# (670, 4)
# 466
# (721, 4)
# 467
# (788, 4)
# 468
# (827, 4)
# 469
# (693, 4)
# 470
# (863, 4)
# (897, 4)
# (981, 4)
# (739, 4)
# (805, 4)
# (444, 4)
# (484, 4)
# (482, 4)
# (504, 4)
# (494, 4)
# (334, 4)
# (322, 4)
# (292, 4)
# (302, 4)
# (254, 4)
# (184, 4)
# (165, 4)
# (139, 4)
# (152, 4)
# (159, 4)
# (119, 4)
# (128, 4)
# (123, 4)
# (135, 4)
# (128, 4)
# (50, 4)
# (417, 4)
# (480, 4)
# (413, 4)
# (461, 4)
# (456, 4)
# (2028, 4)
# (1702, 4)
# (1675, 4)
# (1653, 4)
# (597, 4)
# (456, 4)
# (496, 4)
# (609, 4)
# (424, 4)
# (890, 4)
# (1301, 4)
# (1029, 4)
# (1128, 4)
# (1022, 4)
# (841, 4)
# (762, 4)
# (710, 4)
# (876, 4)
# (894, 4)
# (1147, 4)
# 471
# (995, 4)
# 472
# (1216, 4)
# 473
# (1249, 4)
# 474
# (1109, 4)
# 475
# (383, 4)
# (433, 4)
# (398, 4)
# (469, 4)
# (465, 4)
# (347, 4)
# (380, 4)
# (320, 4)
# (379, 4)
# (315, 4)
# (683, 4)
# 476
# (632, 4)
# 477
# (585, 4)
# 478
# (641, 4)
# 479
# (668, 4)
# 480
# 481
# (1935, 4)
# 482
# 483
# (1818, 4)
# 484
# (2036, 4)
# 485
# (1045, 4)
# 486
# (841, 4)
# 487
# (878, 4)
# 488
# (787, 4)
# 489
# (728, 4)
# 490
# 491
# 492
# 493
# 494
# 495
# (292, 4)
# (240, 4)
# (260, 4)
# (257, 4)
# (306, 4)
# (853, 4)
# (785, 4)
# (670, 4)
# (669, 4)
# (767, 4)
# (35, 4)
# (267, 4)
# (264, 4)
# (263, 4)
# (299, 4)
# (254, 4)
# (1503, 4)
# (1703, 4)
# (1806, 4)
# (1550, 4)
# (1837, 4)
# (383, 4)
# (437, 4)
# (386, 4)
# (441, 4)
# (419, 4)
# (254, 4)
# (269, 4)
# (318, 4)
# (297, 4)
# (277, 4)
# (73, 4)
# (57, 4)
# (85, 4)
# (83, 4)
# (66, 4)
# (77, 4)
# 496
# (88, 4)
# 497
# (88, 4)
# 498
# (73, 4)
# 499
# (75, 4)
# 500
# (222, 4)
# (249, 4)
# (259, 4)
# (215, 4)
# (209, 4)
# (1393, 4)
# (1431, 4)
# (1342, 4)
# (1263, 4)
# (1277, 4)
# (712, 4)
# (652, 4)
# (749, 4)
# (694, 4)
# (767, 4)
# (2021, 4)
# (944, 4)
# (819, 4)
# (716, 4)
# (965, 4)
# (837, 4)
# (71, 4)
# (66, 4)
# (70, 4)
# (82, 4)
# (125, 4)
# (138, 4)
# (145, 4)
# (155, 4)
# (148, 4)
# (138, 4)
# (129, 4)
# (76, 4)
# (131, 4)
# (126, 4)
# (313, 4)
# 501
# (280, 4)
# 502
# (332, 4)
# 503
# (353, 4)
# 504
# (325, 4)
# 505
# (189, 4)
# 506
# (192, 4)
# 507
# (209, 4)
# 508
# (194, 4)
# 509
# (182, 4)
# 510
# (42, 4)
# (42, 4)
# (30, 4)
# (795, 4)
# 511
# (821, 4)
# 512
# (823, 4)
# 513
# (795, 4)
# 514
# (930, 4)
# 515
# (27, 4)
# (26, 4)
# (897, 4)
# (981, 4)
# (1016, 4)
# (1020, 4)
# (921, 4)
# (178, 4)
# (137, 4)
# (177, 4)
# (148, 4)
# (143, 4)
# (529, 4)
# (397, 4)
# (443, 4)
# (417, 4)
# (469, 4)
# (259, 4)
# (262, 4)
# (243, 4)
# (273, 4)
# (312, 4)
# (260, 4)
# (300, 4)
# (299, 4)
# (326, 4)
# (290, 4)
# (198, 4)
# (235, 4)
# (249, 4)
# (189, 4)
# (197, 4)
# (39, 4)
# (470, 4)
# 516
# (461, 4)
# 517
# (457, 4)
# 518
# (444, 4)
# 519
# (476, 4)
# 520
# (218, 4)
# (265, 4)
# (281, 4)
# (237, 4)
# (223, 4)
# (432, 4)
# (463, 4)
# (331, 4)
# (398, 4)
# (382, 4)
# (52, 4)
# (47, 4)
# (1737, 4)
# (1838, 4)
# (1725, 4)
# (1909, 4)
# (1699, 4)
# (400, 4)
# (401, 4)
# (421, 4)
# (463, 4)
# (455, 4)
# (241, 4)
# 521
# (281, 4)
# 522
# (253, 4)
# 523
# (237, 4)
# 524
# (201, 4)
# 525
# (248, 4)
# (339, 4)
# (222, 4)
# (307, 4)
# (242, 4)
# (107, 4)
# (142, 4)
# (102, 4)
# (140, 4)
# (134, 4)
# (183, 4)
# (237, 4)
# (197, 4)
# (175, 4)
# (222, 4)
# (43, 4)
# 526
# (53, 4)
# 527
# (49, 4)
# 528
# (42, 4)
# 529
# (42, 4)
# 530
# (143, 4)
# (136, 4)
# (126, 4)
# (117, 4)
# (126, 4)
# (296, 4)
# (247, 4)
# (314, 4)
# (252, 4)
# (279, 4)
# (344, 4)
# (424, 4)
# (345, 4)
# (430, 4)
# (366, 4)
# (401, 4)
# (418, 4)
# (373, 4)
# (390, 4)
# (398, 4)
# (75, 4)
# (66, 4)
# (73, 4)
# (66, 4)
# (67, 4)
# (874, 4)
# 531
# (929, 4)
# 532
# (749, 4)
# 533
# (888, 4)
# 534
# (819, 4)
# 535
# (925, 4)
# 536
# (949, 4)
# 537
# (890, 4)
# 538
# (822, 4)
# 539
# (804, 4)
# 540
# (707, 4)
# 541
# (813, 4)
# 542
# (814, 4)
# 543
# (726, 4)
# 544
# (670, 4)
# 545
# (207, 4)
# 546
# (199, 4)
# 547
# (193, 4)
# 548
# (204, 4)
# 549
# (179, 4)
# 550
# (116, 4)
# 551
# (107, 4)
# 552
# (132, 4)
# 553
# (109, 4)
# 554
# (106, 4)
# 555
# (231, 4)
# 556
# (216, 4)
# 557
# (262, 4)
# 558
# (264, 4)
# 559
# (260, 4)
# 560
# (263, 4)
# 561
# (268, 4)
# 562
# (270, 4)
# 563
# (251, 4)
# 564
# (304, 4)
# 565
# (298, 4)
# 566
# (329, 4)
# 567
# (319, 4)
# 568
# (341, 4)
# 569
# (357, 4)
# 570
# (209, 4)
# 571
# (207, 4)
# 572
# (204, 4)
# 573
# (172, 4)
# 574
# (195, 4)
# 575
# (218, 4)
# 576
# (192, 4)
# 577
# (186, 4)
# 578
# (186, 4)
# 579
# (217, 4)
# 580
# (177, 4)
# 581
# (174, 4)
# 582
# (163, 4)
# 583
# (145, 4)
# 584
# (168, 4)
# 585
# (183, 4)
# 586
# (180, 4)
# 587
# (164, 4)
# 588
# (174, 4)
# 589
# (168, 4)
# 590
# (368, 4)
# (286, 4)
# (314, 4)
# (327, 4)
# (324, 4)
# (98, 4)
# (105, 4)
# (107, 4)
# (79, 4)
# (97, 4)
# (43, 4)
# (61, 4)
# (53, 4)
# (33, 4)
# (54, 4)
# (24, 4)
# (28, 4)
# (28, 4)
# (28, 4)
# (25, 4)
# (1103, 4)
# (1068, 4)
# (1021, 4)
# (920, 4)
# (1051, 4)
# (182, 4)
# (196, 4)
# (203, 4)
# (183, 4)
# (222, 4)
# (424, 4)
# (581, 4)
# (411, 4)
# (487, 4)
# (469, 4)
# (1176, 4)
# (1314, 4)
# (1511, 4)
# (1401, 4)
# (1221, 4)
# (492, 4)
# (487, 4)
# (458, 4)
# (496, 4)
# (562, 4)
# (159, 4)
# (153, 4)
# (168, 4)
# (172, 4)
# (159, 4)
# (82, 4)
# (69, 4)
# (90, 4)
# (80, 4)
# (79, 4)
# (403, 4)
# (409, 4)
# (403, 4)
# (484, 4)
# (490, 4)
# (278, 4)
# (268, 4)
# (253, 4)
# (239, 4)
# (285, 4)
# (107, 4)
# (128, 4)
# (106, 4)
# (82, 4)
# (96, 4)
# (108, 4)
# (105, 4)
# (104, 4)
# (115, 4)
# (111, 4)
# (352, 4)
# (433, 4)
# (385, 4)
# (352, 4)
# (347, 4)
# (170, 4)
# (148, 4)
# (153, 4)
# (191, 4)
# (161, 4)
# (137, 4)
# (112, 4)
# (135, 4)
# (111, 4)
# (120, 4)
# (80, 4)
# (86, 4)
# (95, 4)
# (87, 4)
# (78, 4)
# (72, 4)
# (56, 4)
# (57, 4)
# (70, 4)
# (66, 4)
# (116, 4)
# (160, 4)
# (187, 4)
# (142, 4)
# (180, 4)
# (1807, 4)
# (1999, 4)
# (212, 4)
# 591
# (200, 4)
# 592
# (176, 4)
# 593
# (230, 4)
# 594
# (203, 4)
# 595
# (173, 4)
# 596
# (160, 4)
# 597
# (148, 4)
# 598
# (136, 4)
# 599
# (144, 4)
# 600
# (150, 4)
# (170, 4)
# (168, 4)
# (168, 4)
# (131, 4)
# (43, 4)
# 601
# (43, 4)
# 602
# (49, 4)
# 603
# (42, 4)
# 604
# (54, 4)
# 605
# (2028, 4)
# (73, 4)
# 606
# (67, 4)
# 607
# (75, 4)
# 608
# (74, 4)
# 609
# (85, 4)
# 610
# (463, 4)
# (336, 4)
# (397, 4)
# (406, 4)
# (469, 4)
# (91, 4)
# (94, 4)
# (95, 4)
# (102, 4)
# (89, 4)
# (279, 4)
# (325, 4)
# (304, 4)
# (300, 4)
# (282, 4)
# (165, 4)
# (195, 4)
# (186, 4)
# (154, 4)
# (175, 4)
# (209, 4)
# (268, 4)
# (220, 4)
# (253, 4)
# (201, 4)
# (138, 4)
# (189, 4)
# (167, 4)
# (142, 4)
# (174, 4)
# (161, 4)
# (141, 4)
# (180, 4)
# (128, 4)
# (170, 4)
# (225, 4)
# (177, 4)
# (166, 4)
# (148, 4)
# (186, 4)
# (1592, 4)
# (1595, 4)
# (1937, 4)
# (1461, 4)
# (1754, 4)
# (775, 4)
# (896, 4)
# (969, 4)
# (782, 4)
# (817, 4)
# (642, 4)
# (677, 4)
# (737, 4)
# (696, 4)
# (670, 4)
# (361, 4)
# (429, 4)
# (349, 4)
# (430, 4)
# (427, 4)
# (369, 4)
# (375, 4)
# (403, 4)
# (379, 4)
# (406, 4)
# (354, 4)
# 611
# (417, 4)
# 612
# (383, 4)
# 613
# (420, 4)
# 614
# (487, 4)
# 615
# (124, 4)
# (99, 4)
# (112, 4)
# (80, 4)
# (120, 4)
# (147, 4)
# (119, 4)
# (103, 4)
# (147, 4)
# (138, 4)
# (70, 4)
# (77, 4)
# (62, 4)
# (72, 4)
# (79, 4)
# (285, 4)
# (246, 4)
# (234, 4)
# (285, 4)
# (282, 4)
# (612, 4)
# (570, 4)
# (599, 4)
# (626, 4)
# (533, 4)
# (669, 4)
# (616, 4)
# (711, 4)
# (685, 4)
# (717, 4)
# (1063, 4)
# (1018, 4)
# (942, 4)
# (1125, 4)
# (940, 4)
# (1190, 4)
# (1002, 4)
# (1026, 4)
# (1243, 4)
# (1117, 4)
# (405, 4)
# (391, 4)
# (397, 4)
# (406, 4)
# (393, 4)
# (188, 4)
# (180, 4)
# (185, 4)
# (250, 4)
# (213, 4)
# (294, 4)
# (281, 4)
# (246, 4)
# (327, 4)
# (304, 4)
# (1251, 4)
# (979, 4)
# (1064, 4)
# (933, 4)
# (1052, 4)
# (1063, 4)
# (1396, 4)
# (1073, 4)
# (1002, 4)
# (1088, 4)
# (1098, 4)
# (963, 4)
# (908, 4)
# (921, 4)
# (805, 4)
# (377, 4)
# (356, 4)
# (320, 4)
# (292, 4)
# (243, 4)
# (381, 4)
# (352, 4)
# (317, 4)
# (401, 4)
# (457, 4)
# (63, 4)
# (80, 4)
# (59, 4)
# (63, 4)
# (73, 4)
# (56, 4)
# (60, 4)
# (62, 4)
# (56, 4)
# (51, 4)
# (298, 4)
# (350, 4)
# (392, 4)
# (296, 4)
# (353, 4)
# (1516, 4)
# (1594, 4)
# (1774, 4)
# (1548, 4)
# (1878, 4)
# (396, 4)
# (340, 4)
# (291, 4)
# (397, 4)
# (370, 4)
# (503, 4)
# (478, 4)
# (538, 4)
# (530, 4)
# (553, 4)
# (1044, 4)
# (1420, 4)
# (1244, 4)
# (1188, 4)
# (1364, 4)
# (529, 4)
# (518, 4)
# (648, 4)
# (605, 4)
# (587, 4)
# (90, 4)
# (112, 4)
# (126, 4)
# (99, 4)
# (99, 4)
# (60, 4)
# (819, 4)
# (711, 4)
# (898, 4)
# (750, 4)
# (790, 4)
# (38, 4)
# (26, 4)
# (27, 4)
# (26, 4)
# (34, 4)
# (48, 4)
# (79, 4)
# (77, 4)
# (214, 4)
# (225, 4)
# (233, 4)
# (217, 4)
# (190, 4)
# (35, 4)
# (29, 4)
# (47, 4)
# (103, 4)
# (136, 4)
# (99, 4)
# (188, 4)
# (125, 4)
# (54, 4)
# (59, 4)
# (78, 4)
# (50, 4)
# (49, 4)
# (990, 4)
# (863, 4)
# (821, 4)
# (856, 4)
# (978, 4)
# (1701, 4)
# (1757, 4)
# (1817, 4)
# (1593, 4)
# (1554, 4)
# (190, 4)
# (200, 4)
# (208, 4)
# (203, 4)
# (168, 4)
# (107, 4)
# (91, 4)
# (100, 4)
# (101, 4)
# (91, 4)
# (359, 4)
# (311, 4)
# (348, 4)
# (340, 4)
# (314, 4)
# (1770, 4)
# (1741, 4)
# (1768, 4)
# (1936, 4)
# (105, 4)
# (140, 4)
# (116, 4)
# (116, 4)
# (130, 4)
# (704, 4)
# (876, 4)
# (746, 4)
# (805, 4)
# (828, 4)
# (363, 4)
# (559, 4)
# (456, 4)
# (479, 4)
# (505, 4)
# (254, 4)
# (240, 4)
# (234, 4)
# (276, 4)
# (271, 4)
# (161, 4)
# (172, 4)
# (173, 4)
# (165, 4)
# (177, 4)
# (48, 4)
# (50, 4)
# (1086, 4)
# (710, 4)
# (676, 4)
# (819, 4)
# (1055, 4)
# (1160, 4)
# (1448, 4)
# (1348, 4)
# (1356, 4)
# (1261, 4)
# (1154, 4)
# (1106, 4)
# (1107, 4)
# (1143, 4)
# (1003, 4)
# (296, 4)
# (315, 4)
# (358, 4)
# (372, 4)
# (299, 4)
# (432, 4)
# (492, 4)
# (500, 4)
# (429, 4)
# (456, 4)
# (75, 4)
# (106, 4)
# (81, 4)
# (73, 4)
# (68, 4)
# (50, 4)
# (58, 4)
# (54, 4)
# (51, 4)
# (1120, 4)
# (1067, 4)
# (1110, 4)
# (1121, 4)
# (1154, 4)
# (901, 4)
# (907, 4)
# (940, 4)
# (760, 4)
# (930, 4)
# (80, 4)
# 616
# (56, 4)
# 617
# (74, 4)
# 618
# (63, 4)
# 619
# (84, 4)
# 620
# (346, 4)
# (282, 4)
# (246, 4)
# (308, 4)
# (316, 4)
# (190, 4)
# (206, 4)
# (194, 4)
# (148, 4)
# (211, 4)
# (97, 4)
# (86, 4)
# (80, 4)
# (84, 4)
# (99, 4)
# (246, 4)
# (259, 4)
# (284, 4)
# (228, 4)
# (249, 4)
# (249, 4)
# (249, 4)
# (255, 4)
# (265, 4)
# (267, 4)
# (717, 4)
# (809, 4)
# (878, 4)
# (721, 4)
# (653, 4)
# (2042, 4)
# (1971, 4)
# (1802, 4)
# (785, 4)
# (900, 4)
# (828, 4)
# (739, 4)
# (893, 4)
# (764, 4)
# (848, 4)
# (761, 4)
# (777, 4)
# (758, 4)
# (373, 4)
# (321, 4)
# (308, 4)
# (324, 4)
# (292, 4)
# (304, 4)
# (366, 4)
# (301, 4)
# (279, 4)
# (292, 4)
# (689, 4)
# 621
# (697, 4)
# 622
# (640, 4)
# 623
# (732, 4)
# 624
# (787, 4)
# 625
# (1924, 4)
# (1986, 4)
# (1916, 4)
# (1710, 4)
# (778, 4)
# (825, 4)
# (626, 4)
# (765, 4)
# (700, 4)
# (412, 4)
# (453, 4)
# (416, 4)
# (514, 4)
# (422, 4)
# (75, 4)
# (105, 4)
# (106, 4)
# (98, 4)
# (100, 4)
# (99, 4)
# (95, 4)
# (89, 4)
# (75, 4)
# (107, 4)
# (250, 4)
# (237, 4)
# (189, 4)
# (222, 4)
# (186, 4)
# (192, 4)
# (190, 4)
# (180, 4)
# (159, 4)
# (190, 4)
# (103, 4)
# (129, 4)
# (118, 4)
# (122, 4)
# (88, 4)
# (83, 4)
# (86, 4)
# (92, 4)
# (76, 4)
# (64, 4)
# (167, 4)
# (205, 4)
# (205, 4)
# (146, 4)
# (197, 4)
# (157, 4)
# (130, 4)
# (193, 4)
# (180, 4)
# (171, 4)
# (102, 4)
# (123, 4)
# (110, 4)
# (105, 4)
# (104, 4)
# (49, 4)
# (49, 4)
# (65, 4)
# (54, 4)
# (62, 4)
# (290, 4)
# (254, 4)
# (261, 4)
# (247, 4)
# (230, 4)
# (31, 4)
# (28, 4)
# (34, 4)
# (36, 4)
# (32, 4)
# (682, 4)
# (729, 4)
# (694, 4)
# (699, 4)
# (614, 4)
# (59, 4)
# (55, 4)
# (45, 4)
# (47, 4)
# (68, 4)
# (71, 4)
# (87, 4)
# (65, 4)
# (62, 4)
# (94, 4)
# (1880, 4)
# (1112, 4)
# (868, 4)
# (825, 4)
# (983, 4)
# (871, 4)
# (1670, 4)
# (1582, 4)
# (1602, 4)
# (1532, 4)
# (1692, 4)
# (429, 4)
# 626
# (404, 4)
# 627
# (469, 4)
# 628
# (405, 4)
# 629
# (399, 4)
# 630
# (353, 4)
# (350, 4)
# (308, 4)
# (384, 4)
# (325, 4)
# (33, 4)
# (48, 4)
# (30, 4)
# (35, 4)
# (31, 4)
# (108, 4)
# 631
# (109, 4)
# 632
# (109, 4)
# 633
# (122, 4)
# 634
# (108, 4)
# 635
# (334, 4)
# (299, 4)
# (334, 4)
# (337, 4)
# (306, 4)
# (232, 4)
# (212, 4)
# (178, 4)
# (199, 4)
# (186, 4)
# (158, 4)
# (149, 4)
# (180, 4)
# (164, 4)
# (129, 4)
# (693, 4)
# (759, 4)
# (877, 4)
# (737, 4)
# (823, 4)
# (2037, 4)
# (1964, 4)
# (2022, 4)
# (1693, 4)
# (1760, 4)
# (1593, 4)
# (1909, 4)
# (1679, 4)
# (1962, 4)
# (827, 4)
# (780, 4)
# (946, 4)
# (1022, 4)
# (678, 4)
# (758, 4)
# (917, 4)
# (830, 4)
# (809, 4)
# (855, 4)
# (776, 4)
# (713, 4)
# (664, 4)
# (708, 4)
# (633, 4)
# (86, 4)
# 636
# (62, 4)
# 637
# (67, 4)
# 638
# (67, 4)
# 639
# (53, 4)
# 640
# (38, 4)
# 641
# (37, 4)
# 642
# (54, 4)
# 643
# (37, 4)
# 644
# (43, 4)
# 645
# (35, 4)
# 646
# (37, 4)
# 647
# (38, 4)
# 648
# (37, 4)
# 649
# (34, 4)
# 650
# (2021, 4)
# (1727, 4)
# (1788, 4)
# (1620, 4)
# (1711, 4)
# (402, 4)
# 651
# (361, 4)
# 652
# (404, 4)
# 653
# (399, 4)
# 654
# (392, 4)
# 655
# (222, 4)
# 656
# (226, 4)
# 657
# (219, 4)
# 658
# (221, 4)
# 659
# (246, 4)
# 660
# (219, 4)
# 661
# (193, 4)
# 662
# (202, 4)
# 663
# (210, 4)
# 664
# (176, 4)
# 665
# (250, 4)
# (343, 4)
# (297, 4)
# (294, 4)
# (334, 4)
# (232, 4)
# (210, 4)
# (187, 4)
# (198, 4)
# (234, 4)
# (762, 4)
# 666
# (816, 4)
# 667
# (705, 4)
# 668
# (720, 4)
# 669
# (695, 4)
# 670
# (158, 4)
# (179, 4)
# (179, 4)
# (168, 4)
# (145, 4)
# (218, 4)
# (210, 4)
# (174, 4)
# (224, 4)
# (222, 4)
# (261, 4)
# (275, 4)
# (243, 4)
# (233, 4)
# (253, 4)
# (1098, 4)
# (922, 4)
# (948, 4)
# (788, 4)
# (950, 4)
# (584, 4)
# (591, 4)
# (568, 4)
# (664, 4)
# (627, 4)
# (446, 4)
# (416, 4)
# (492, 4)
# (440, 4)
# (545, 4)
# (390, 4)
# (390, 4)
# (335, 4)
# (391, 4)
# (449, 4)
# (250, 4)
# (233, 4)
# (238, 4)
# (240, 4)
# (275, 4)
# (157, 4)
# (168, 4)
# (158, 4)
# (141, 4)
# (169, 4)
# (116, 4)
# (101, 4)
# (71, 4)
# (71, 4)
# (70, 4)
# (63, 4)
# (80, 4)
# (78, 4)
# (70, 4)
# (63, 4)
# (73, 4)
# (385, 4)
# (375, 4)
# (537, 4)
# (489, 4)
# (511, 4)
# (61, 4)
# (76, 4)
# (78, 4)
# (78, 4)
# (63, 4)
# (166, 4)
# (173, 4)
# (151, 4)
# (178, 4)
# (137, 4)
# (165, 4)
# (179, 4)
# (203, 4)
# (193, 4)
# (194, 4)
# (205, 4)
# (191, 4)
# (165, 4)
# (213, 4)
# (201, 4)
# (792, 4)
# (1026, 4)
# (785, 4)
# (949, 4)
# (731, 4)
# (881, 4)
# (867, 4)
# (762, 4)
# (772, 4)
# (775, 4)
# (878, 4)
# (960, 4)
# (845, 4)
# (946, 4)
# (1086, 4)
# (748, 4)
# (967, 4)
# (943, 4)
# (1056, 4)
# (814, 4)
# (429, 4)
# (440, 4)
# (509, 4)
# (463, 4)
# (505, 4)
# (1987, 4)
# (1777, 4)
# (1713, 4)
# (157, 4)
# (138, 4)
# (134, 4)
# (162, 4)
# (171, 4)
# (730, 4)
# (647, 4)
# (720, 4)
# (544, 4)
# (748, 4)
# (165, 4)
# (220, 4)
# (228, 4)
# (165, 4)
# (182, 4)
# (46, 4)
# (48, 4)
# (36, 4)
# (54, 4)
# (474, 4)
# (435, 4)
# (558, 4)
# (517, 4)
# (491, 4)
# (534, 4)
# (542, 4)
# (657, 4)
# (488, 4)
# (647, 4)
# (360, 4)
# (389, 4)
# (353, 4)
# (368, 4)
# (382, 4)
# (101, 4)
# (134, 4)
# (141, 4)
# (107, 4)
# (130, 4)
# (102, 4)
# (88, 4)
# (92, 4)
# (99, 4)
# (85, 4)
# (40, 4)
# 671
# (38, 4)
# 672
# (38, 4)
# 673
# (37, 4)
# 674
# (40, 4)
# 675
# (602, 4)
# 676
# (697, 4)
# 677
# (743, 4)
# 678
# (734, 4)
# 679
# (672, 4)
# 680
# (102, 4)
# 681
# (111, 4)
# 682
# (92, 4)
# 683
# (114, 4)
# 684
# (107, 4)
# 685
# (1175, 4)
# (1191, 4)
# (1183, 4)
# (1041, 4)
# (1271, 4)
# (371, 4)
# (403, 4)
# (355, 4)
# (364, 4)
# (297, 4)
# (867, 4)
# (820, 4)
# (921, 4)
# (998, 4)
# (1030, 4)
# (1037, 4)
# (1170, 4)
# (988, 4)
# (1005, 4)
# (1128, 4)
# (669, 4)
# (647, 4)
# (616, 4)
# (594, 4)
# (577, 4)
# (333, 4)
# (282, 4)
# (315, 4)
# (351, 4)
# (351, 4)
# (519, 4)
# (604, 4)
# (572, 4)
# (709, 4)
# (634, 4)
# (501, 4)
# 686
# (585, 4)
# 687
# (506, 4)
# 688
# (530, 4)
# 689
# (565, 4)
# 690
# (255, 4)
# (280, 4)
# (300, 4)
# (262, 4)
# (252, 4)
# (164, 4)
# (185, 4)
# (174, 4)
# (204, 4)
# (168, 4)
# (41, 4)
# (56, 4)
# (59, 4)
# (111, 4)
# (126, 4)
# (96, 4)
# (92, 4)
# (98, 4)
# (1729, 4)
# (1830, 4)
# (1567, 4)
# (1808, 4)
# (1619, 4)
# (1954, 4)
# (775, 4)
# (600, 4)
# (722, 4)
# (563, 4)
# (538, 4)
# (1981, 4)
# (1959, 4)
# (1373, 4)
# (1653, 4)
# (1715, 4)
# (572, 4)
# (553, 4)
# (537, 4)
# (470, 4)
# (561, 4)
# (317, 4)
# (297, 4)
# (264, 4)
# (310, 4)
# (264, 4)
# (173, 4)
# (161, 4)
# (146, 4)
# (200, 4)
# (180, 4)
# (1030, 4)
# (811, 4)
# (956, 4)
# (926, 4)
# (977, 4)
# (1955, 4)
# (1861, 4)
# (1420, 4)
# (1341, 4)
# (1831, 4)
# (1704, 4)
# (1131, 4)
# (1368, 4)
# (1320, 4)
# (1101, 4)
# (1248, 4)
# (576, 4)
# (714, 4)
# (575, 4)
# (640, 4)
# (557, 4)
# (530, 4)
# (489, 4)
# (439, 4)
# (488, 4)
# (441, 4)
# (85, 4)
# (93, 4)
# (73, 4)
# (67, 4)
# (79, 4)
# (153, 4)
# (179, 4)
# (186, 4)
# (220, 4)
# (197, 4)
# (103, 4)
# (96, 4)
# (103, 4)
# (103, 4)
# (1475, 4)
# (1652, 4)
# (1643, 4)
# (1353, 4)
# (1513, 4)
# (1211, 4)
# (1098, 4)
# (1415, 4)
# (1345, 4)
# (1196, 4)
# (1020, 4)
# (912, 4)
# (866, 4)
# (894, 4)
# (879, 4)
# (339, 4)
# (308, 4)
# (318, 4)
# (278, 4)
# (291, 4)
# (926, 4)
# (1013, 4)
# (1003, 4)
# (1158, 4)
# (886, 4)
# (504, 4)
# (642, 4)
# (593, 4)
# (569, 4)
# (619, 4)
# (953, 4)
# (819, 4)
# (774, 4)
# (947, 4)
# (788, 4)
# (54, 4)
# 691
# (75, 4)
# 692
# (64, 4)
# 693
# (54, 4)
# 694
# (73, 4)
# 695
# (28, 4)
# 696
# (25, 4)
# 697
# (30, 4)
# 698
# (30, 4)
# 699
# (25, 4)
# 700
# (15, 4)
# 701
# (14, 4)
# 702
# (11, 4)
# 703
# (9, 4)
# 704
# (8, 4)
# 705
# (325, 4)
# (365, 4)
# (372, 4)
# (354, 4)
# (333, 4)
# (1311, 4)
# (1137, 4)
# (1247, 4)
# (1308, 4)
# (1191, 4)
# (104, 4)
# (133, 4)
# (140, 4)
# (132, 4)
# (124, 4)
# (173, 4)
# 706
# (137, 4)
# 707
# (136, 4)
# 708
# (135, 4)
# 709
# (140, 4)
# 710
# (425, 4)
# (515, 4)
# (448, 4)
# (616, 4)
# (500, 4)
# (1844, 4)
# (1313, 4)
# (1348, 4)
# (1259, 4)
# (1358, 4)
# (66, 4)
# (91, 4)
# (102, 4)
# (55, 4)
# (101, 4)
# (123, 4)
# (103, 4)
# (111, 4)
# (144, 4)
# (141, 4)
# (101, 4)
# (98, 4)
# (127, 4)
# (112, 4)
# (113, 4)
# (79, 4)
# (79, 4)
# (75, 4)
# (77, 4)
# (361, 4)
# (379, 4)
# (411, 4)
# (433, 4)
# (431, 4)
# (462, 4)
# (428, 4)
# (487, 4)
# (363, 4)
# (452, 4)
# (230, 4)
# (269, 4)
# (250, 4)
# (254, 4)
# (246, 4)
# (216, 4)
# (214, 4)
# (226, 4)
# (183, 4)
# (222, 4)
# (512, 4)
# (414, 4)
# (377, 4)
# (461, 4)
# (586, 4)
# (111, 4)
# (118, 4)
# (78, 4)
# (99, 4)
# (82, 4)
# (77, 4)
# (46, 4)
# (64, 4)
# (108, 4)
# (74, 4)
# (58, 4)
# (47, 4)
# (63, 4)
# (179, 4)
# (208, 4)
# (180, 4)
# (229, 4)
# (187, 4)
# (267, 4)
# (190, 4)
# (204, 4)
# (256, 4)
# (205, 4)
# (64, 4)
# (60, 4)
# (78, 4)
# (66, 4)
# (67, 4)
# (269, 4)
# (241, 4)
# (247, 4)
# (238, 4)
# (228, 4)
# (123, 4)
# (112, 4)
# (139, 4)
# (123, 4)
# (94, 4)
# (52, 4)
# (46, 4)
# (53, 4)
# (59, 4)
# (80, 4)
# (871, 4)
# 711
# (891, 4)
# 712
# (793, 4)
# 713
# (782, 4)
# 714
# (834, 4)
# 715
# (451, 4)
# 716
# (391, 4)
# 717
# (424, 4)
# 718
# (439, 4)
# 719
# (443, 4)
# 720
# (451, 4)
# 721
# (429, 4)
# 722
# (477, 4)
# 723
# (513, 4)
# 724
# (479, 4)
# 725
# (275, 4)
# (277, 4)
# (270, 4)
# (296, 4)
# (251, 4)
# (718, 4)
# 726
# (733, 4)
# 727
# (651, 4)
# 728
# (605, 4)
# 729
# (759, 4)
# 730
# (175, 4)
# (170, 4)
# (150, 4)
# (188, 4)
# (219, 4)
# (747, 4)
# 731
# (866, 4)
# 732
# (795, 4)
# 733
# (778, 4)
# 734
# (742, 4)
# 735
# (1066, 4)
# (1048, 4)
# (935, 4)
# (949, 4)
# (889, 4)
# (451, 4)
# (613, 4)
# (492, 4)
# (511, 4)
# (477, 4)
# (144, 4)
# 736
# (161, 4)
# 737
# (150, 4)
# 738
# (174, 4)
# 739
# (145, 4)
# 740
# (106, 4)
# 741
# (91, 4)
# 742
# (87, 4)
# 743
# (96, 4)
# 744
# (117, 4)
# 745
# (92, 4)
# 746
# (88, 4)
# 747
# (88, 4)
# 748
# (106, 4)
# 749
# (80, 4)
# 750
# (13, 4)
# 751
# (12, 4)
# 752
# (13, 4)
# 753
# (12, 4)
# 754
# (14, 4)
# 755
# (130, 4)
# (138, 4)
# (145, 4)
# (162, 4)
# (155, 4)
# (475, 4)
# (495, 4)
# (468, 4)
# (434, 4)
# (546, 4)
# (25, 4)
# (1257, 4)
# (1466, 4)
# (1422, 4)
# (1169, 4)
# (1308, 4)
# (1167, 4)
# (1126, 4)
# (1239, 4)
# (1336, 4)
# (1303, 4)
# (640, 4)
# (533, 4)
# (545, 4)
# (505, 4)
# (577, 4)
# (109, 4)
# (116, 4)
# (145, 4)
# (148, 4)
# (134, 4)
# (143, 4)
# (91, 4)
# (80, 4)
# (69, 4)
# (77, 4)
# (76, 4)
# (34, 4)
# (47, 4)
# (35, 4)
# (32, 4)
# (44, 4)
# (923, 4)
# (965, 4)
# (758, 4)
# (1080, 4)
# (856, 4)
# (1418, 4)
# (1188, 4)
# (1556, 4)
# (1541, 4)
# (1388, 4)
# (339, 4)
# (314, 4)
# (379, 4)
# (349, 4)
# (339, 4)
# (668, 4)
# (620, 4)
# (592, 4)
# (633, 4)
# (639, 4)
# (133, 4)
# (122, 4)
# (119, 4)
# (115, 4)
# (117, 4)
# (671, 4)
# (721, 4)
# (870, 4)
# (679, 4)
# (659, 4)
# (482, 4)
# (572, 4)
# (526, 4)
# (609, 4)
# (678, 4)
# (451, 4)
# (351, 4)
# (372, 4)
# (403, 4)
# (386, 4)
# (999, 4)
# 756
# (860, 4)
# 757
# (858, 4)
# 758
# (812, 4)
# 759
# (853, 4)
# 760
# (41, 4)
# (26, 4)
# (320, 4)
# (252, 4)
# (290, 4)
# (342, 4)
# (360, 4)
# (276, 4)
# (310, 4)
# (326, 4)
# (322, 4)
# (321, 4)
# (322, 4)
# (299, 4)
# (312, 4)
# (385, 4)
# (375, 4)
# (77, 4)
# (77, 4)
# (77, 4)
# (92, 4)
# (83, 4)
# (58, 4)
# 761
# (53, 4)
# 762
# (52, 4)
# 763
# (57, 4)
# 764
# (66, 4)
# 765
# (73, 4)
# 766
# (84, 4)
# 767
# (99, 4)
# 768
# (86, 4)
# 769
# (92, 4)
# 770
# (275, 4)
# (227, 4)
# (299, 4)
# (242, 4)
# (269, 4)
# (63, 4)
# 771
# (64, 4)
# 772
# (58, 4)
# 773
# (61, 4)
# 774
# (67, 4)
# 775
# (414, 4)
# 776
# (458, 4)
# 777
# (474, 4)
# 778
# (384, 4)
# 779
# (491, 4)
# 780
# (291, 4)
# 781
# (308, 4)
# 782
# (285, 4)
# 783
# (308, 4)
# 784
# (299, 4)
# 785
# (587, 4)
# 786
# (612, 4)
# 787
# (726, 4)
# 788
# (594, 4)
# 789
# (702, 4)
# 790
# (675, 4)
# 791
# (739, 4)
# 792
# (670, 4)
# 793
# (722, 4)
# 794
# (702, 4)
# 795
# (510, 4)
# 796
# (485, 4)
# 797
# (503, 4)
# 798
# (475, 4)
# 799
# (380, 4)
# 800
# (680, 4)
# 801
# (628, 4)
# 802
# (616, 4)
# 803
# (698, 4)
# 804
# (558, 4)
# 805
# (760, 4)
# 806
# (720, 4)
# 807
# (731, 4)
# 808
# (662, 4)
# 809
# (732, 4)
# 810
# (567, 4)
# 811
# (584, 4)
# 812
# (531, 4)
# 813
# (626, 4)
# 814
# (572, 4)
# 815
# (515, 4)
# 816
# (498, 4)
# 817
# (468, 4)
# 818
# (522, 4)
# 819
# (507, 4)
# 820
# (47, 4)
# (48, 4)
# (87, 4)
# (84, 4)
# (87, 4)
# (98, 4)
# (79, 4)
# (133, 4)
# (150, 4)
# (164, 4)
# (165, 4)
# (161, 4)
# (100, 4)
# (61, 4)
# (55, 4)
# (56, 4)
# (93, 4)
# (82, 4)
# (91, 4)
# (93, 4)
# (71, 4)
# (225, 4)
# ...
# (254, 4)
# (266, 4)
# (293, 4)
# (269, 4)
# (259, 4)
# (322, 4)
# (300, 4)
# (77, 4)
# (90, 4)
# (88, 4)
# (88, 4)
# (96, 4)
# (113, 4)
# (153, 4)
# (148, 4)
# (127, 4)
# (105, 4)
# (253, 4)
# (259, 4)
# (235, 4)
# (242, 4)
# (206, 4)
# (172, 4)
# (139, 4)
# (189, 4)
# (196, 4)
# (151, 4)
# (683, 4)
# (538, 4)
# (693, 4)
# (557, 4)
# (570, 4)
# (50, 4)
# (59, 4)
# (53, 4)
# (47, 4)
# (72, 4)
# (50, 4)
# (50, 4)
# (53, 4)
# (55, 4)
# (50, 4)
# (70, 4)
# (25, 4)
# (55, 4)
# (37, 4)
# (71, 4)
# (793, 4)
# (747, 4)
# (649, 4)
# (735, 4)
# (753, 4)
# (1213, 4)
# (1344, 4)
# (1384, 4)
# (1338, 4)
# (1311, 4)
# (1321, 4)
# (1062, 4)
# (1151, 4)
# (1110, 4)
# (1135, 4)
# (201, 4)
# (294, 4)
# (298, 4)
# (266, 4)
# (215, 4)
# (208, 4)
# (161, 4)
# (149, 4)
# (163, 4)
# (152, 4)
# (164, 4)
# (142, 4)
# (505, 4)
# 10483
# (505, 4)
# 10484
# (476, 4)
# 10485
# (518, 4)
# 10486
# (511, 4)
# 10487
# (101, 4)
# 10488
# (71, 4)
# 10489
# (93, 4)
# 10490
# (93, 4)
# 10491
# (88, 4)
# 10492
# (143, 4)
# 10493
# (137, 4)
# 10494
# (122, 4)
# 10495
# (127, 4)
# 10496
# (124, 4)
# 10497
# (61, 4)
# (70, 4)
# (66, 4)
# (60, 4)
# (69, 4)
# (345, 4)
# (365, 4)
# (301, 4)
# (328, 4)
# (322, 4)
# (335, 4)
# (387, 4)
# (431, 4)
# (380, 4)
# (288, 4)
# (412, 4)
# (469, 4)
# (431, 4)
# (433, 4)
# (417, 4)
# (1004, 4)
# (1143, 4)
# (1281, 4)
# (1403, 4)
# (1082, 4)
# (1123, 4)
# (1361, 4)
# (1166, 4)
# (1458, 4)
# (1250, 4)
# (85, 4)
# (74, 4)
# (83, 4)
# (106, 4)
# (73, 4)
# (183, 4)
# (235, 4)
# (235, 4)
# (241, 4)
# (231, 4)
# (927, 4)
# (925, 4)
# (1038, 4)
# (838, 4)
# (806, 4)
# (655, 4)
# (757, 4)
# (636, 4)
# (752, 4)
# (624, 4)
# (331, 4)
# (305, 4)
# (353, 4)
# (332, 4)
# (306, 4)
# (225, 4)
# (242, 4)
# (187, 4)
# (194, 4)
# (193, 4)
# (454, 4)
# (508, 4)
# (545, 4)
# (408, 4)
# (530, 4)
# (85, 4)
# (93, 4)
# (104, 4)
# (84, 4)
# (90, 4)
# (52, 4)
# (72, 4)
# (72, 4)
# (63, 4)
# (66, 4)
# (284, 4)
# (265, 4)
# (283, 4)
# (301, 4)
# (268, 4)
# (371, 4)
# (392, 4)
# (431, 4)
# (370, 4)
# (357, 4)
# (312, 4)
# (266, 4)
# (286, 4)
# (273, 4)
# (285, 4)
# (146, 4)
# (166, 4)
# (134, 4)
# (143, 4)
# (162, 4)
# (1416, 4)
# (1533, 4)
# (1510, 4)
# (1594, 4)
# (1545, 4)
# (32, 4)
# (60, 4)
# (65, 4)
# (70, 4)
# (59, 4)
# (66, 4)
# (231, 4)
# (179, 4)
# (195, 4)
# (210, 4)
# (168, 4)
# (1468, 4)
# 10498
# (1236, 4)
# 10499
# (1249, 4)
# 10500
# (1189, 4)
# 10501
# (1454, 4)
# 10502
# (184, 4)
# (173, 4)
# (170, 4)
# (174, 4)
# (180, 4)
# (53, 4)
# (57, 4)
# (65, 4)
# (57, 4)
# (422, 4)
# (387, 4)
# (390, 4)
# (466, 4)
# (384, 4)
# (195, 4)
# (211, 4)
# (212, 4)
# (177, 4)
# (210, 4)
# (1878, 4)
# (1787, 4)
# (1655, 4)
# (1352, 4)
# (1530, 4)
# (1545, 4)
# (1405, 4)
# (1438, 4)
# (221, 4)
# (257, 4)
# (249, 4)
# (239, 4)
# (289, 4)
# (167, 4)
# (225, 4)
# (202, 4)
# (184, 4)
# (199, 4)
# (330, 4)
# 10503
# (298, 4)
# 10504
# (263, 4)
# 10505
# (315, 4)
# 10506
# (339, 4)
# 10507
# (242, 4)
# 10508
# (239, 4)
# 10509
# (243, 4)
# 10510
# (246, 4)
# 10511
# (232, 4)
# 10512
# (164, 4)
# 10513
# (167, 4)
# 10514
# (162, 4)
# 10515
# (172, 4)
# 10516
# (147, 4)
# 10517
# (158, 4)
# 10518
# (148, 4)
# 10519
# (182, 4)
# 10520
# (155, 4)
# 10521
# (183, 4)
# 10522
# (297, 4)
# (328, 4)
# (276, 4)
# (271, 4)
# (306, 4)
# (994, 4)
# (983, 4)
# (1099, 4)
# (858, 4)
# (848, 4)
# (126, 4)
# (117, 4)
# (126, 4)
# (131, 4)
# (143, 4)
# (35, 4)
# (33, 4)
# (31, 4)
# (21, 4)
# (32, 4)
# (902, 4)
# (1073, 4)
# (1039, 4)
# (967, 4)
# (878, 4)
# (130, 4)
# (146, 4)
# (116, 4)
# (120, 4)
# (122, 4)
# (97, 4)
# (47, 4)
# (45, 4)
# (54, 4)
# (94, 4)
# (48, 4)
# (31, 4)
# (33, 4)
# (51, 4)
# (454, 4)
# (427, 4)
# (397, 4)
# (344, 4)
# (409, 4)
# (1067, 4)
# (1136, 4)
# (1250, 4)
# (1206, 4)
# (1288, 4)
# (234, 4)
# (230, 4)
# (246, 4)
# (211, 4)
# (225, 4)
# (69, 4)
# (95, 4)
# (59, 4)
# (66, 4)
# (79, 4)
# (277, 4)
# (305, 4)
# (254, 4)
# (278, 4)
# (290, 4)
# (1920, 4)
# (926, 4)
# (949, 4)
# (973, 4)
# (1112, 4)
# (1077, 4)
# (1066, 4)
# (964, 4)
# (860, 4)
# (951, 4)
# (953, 4)
# (1076, 4)
# (1004, 4)
# (952, 4)
# (927, 4)
# (1008, 4)
# (668, 4)
# (666, 4)
# (545, 4)
# (573, 4)
# (530, 4)
# (1274, 4)
# (1088, 4)
# (1160, 4)
# (1249, 4)
# (1165, 4)
# (138, 4)
# 10523
# (162, 4)
# 10524
# (154, 4)
# 10525
# (149, 4)
# 10526
# (145, 4)
# 10527
# (175, 4)
# (193, 4)
# (173, 4)
# (209, 4)
# (186, 4)
# (273, 4)
# (286, 4)
# (239, 4)
# (276, 4)
# (316, 4)
# (119, 4)
# (129, 4)
# (117, 4)
# (100, 4)
# (1148, 4)
# (910, 4)
# (1160, 4)
# (1028, 4)
# (929, 4)
# (233, 4)
# (177, 4)
# (224, 4)
# (198, 4)
# (247, 4)
# (83, 4)
# (91, 4)
# (80, 4)
# (94, 4)
# (98, 4)
# (131, 4)
# (139, 4)
# (119, 4)
# (130, 4)
# (102, 4)
# (150, 4)
# (140, 4)
# (153, 4)
# (191, 4)
# (144, 4)
# (810, 4)
# 10528
# (758, 4)
# 10529
# (895, 4)
# 10530
# (771, 4)
# 10531
# (836, 4)
# 10532
# (465, 4)
# (583, 4)
# (512, 4)
# (496, 4)
# (521, 4)
# (561, 4)
# (608, 4)
# (614, 4)
# (530, 4)
# (528, 4)
# (407, 4)
# (437, 4)
# (499, 4)
# (403, 4)
# (474, 4)
# (774, 4)
# (824, 4)
# (720, 4)
# (866, 4)
# (794, 4)
# (474, 4)
# (555, 4)
# (453, 4)
# (676, 4)
# (519, 4)
# (232, 4)
# (265, 4)
# (233, 4)
# (247, 4)
# (232, 4)
# (167, 4)
# (189, 4)
# (141, 4)
# (175, 4)
# (178, 4)
# (1424, 4)
# (965, 4)
# (1106, 4)
# (1114, 4)
# (1092, 4)
# (688, 4)
# (816, 4)
# (714, 4)
# (679, 4)
# (834, 4)
# (103, 4)
# (78, 4)
# (100, 4)
# (82, 4)
# (97, 4)
# (88, 4)
# (144, 4)
# (116, 4)
# (126, 4)
# (128, 4)
# (62, 4)
# (55, 4)
# (92, 4)
# (77, 4)
# (88, 4)
# (67, 4)
# (67, 4)
# (75, 4)
# (76, 4)
# (260, 4)
# (256, 4)
# (212, 4)
# (273, 4)
# (221, 4)
# (149, 4)
# (193, 4)
# (177, 4)
# (167, 4)
# (188, 4)
# (169, 4)
# (161, 4)
# (159, 4)
# (140, 4)
# (130, 4)
# (1939, 4)
# (2018, 4)
# (2033, 4)
# (1778, 4)
# (1679, 4)
# (1664, 4)
# (1412, 4)
# (1683, 4)
# (1740, 4)
# (966, 4)
# (934, 4)
# (979, 4)
# (905, 4)
# (1015, 4)
# (765, 4)
# (790, 4)
# (802, 4)
# (698, 4)
# (703, 4)
# (307, 4)
# (277, 4)
# (312, 4)
# (289, 4)
# (335, 4)
# (98, 4)
# (119, 4)
# (89, 4)
# (107, 4)
# (112, 4)
# (90, 4)
# (194, 4)
# (133, 4)
# (129, 4)
# (112, 4)
# (66, 4)
# (101, 4)
# (102, 4)
# (93, 4)
# (111, 4)
# (110, 4)
# (392, 4)
# (336, 4)
# (400, 4)
# (416, 4)
# (429, 4)
# (136, 4)
# (168, 4)
# (124, 4)
# (114, 4)
# (138, 4)
# (147, 4)
# (133, 4)
# (139, 4)
# (141, 4)
# (125, 4)
# (864, 4)
# 10533
# (899, 4)
# 10534
# (732, 4)
# 10535
# (795, 4)
# 10536
# (882, 4)
# 10537
# (319, 4)
# 10538
# (325, 4)
# 10539
# (317, 4)
# 10540
# (291, 4)
# 10541
# (338, 4)
# 10542
# (231, 4)
# 10543
# (272, 4)
# 10544
# (244, 4)
# 10545
# (261, 4)
# 10546
# (290, 4)
# 10547
# (1832, 4)
# (1623, 4)
# (1720, 4)
# (1777, 4)
# (336, 4)
# (265, 4)
# (273, 4)
# (291, 4)
# (287, 4)
# (314, 4)
# (298, 4)
# (328, 4)
# (363, 4)
# (355, 4)
# (151, 4)
# (175, 4)
# (151, 4)
# (147, 4)
# (159, 4)
# (93, 4)
# (108, 4)
# (86, 4)
# (124, 4)
# (117, 4)
# (1633, 4)
# (1764, 4)
# (1638, 4)
# (1718, 4)
# (1919, 4)
# (1283, 4)
# (1243, 4)
# (1125, 4)
# (1303, 4)
# (1280, 4)
# (423, 4)
# (470, 4)
# (431, 4)
# (396, 4)
# (480, 4)
# (225, 4)
# 10548
# (207, 4)
# 10549
# (211, 4)
# 10550
# (197, 4)
# 10551
# (196, 4)
# 10552
# (855, 4)
# 10553
# (868, 4)
# 10554
# (789, 4)
# 10555
# (959, 4)
# 10556
# (986, 4)
# 10557
# (473, 4)
# 10558
# (504, 4)
# 10559
# (458, 4)
# 10560
# (535, 4)
# 10561
# (509, 4)
# 10562
# (316, 4)
# 10563
# (348, 4)
# 10564
# (338, 4)
# 10565
# (342, 4)
# 10566
# (318, 4)
# 10567
# (306, 4)
# 10568
# (272, 4)
# 10569
# (284, 4)
# 10570
# (291, 4)
# 10571
# (306, 4)
# 10572
# (316, 4)
# 10573
# (293, 4)
# 10574
# (265, 4)
# 10575
# (262, 4)
# 10576
# (351, 4)
# 10577
# (315, 4)
# 10578
# (343, 4)
# 10579
# (319, 4)
# 10580
# (358, 4)
# 10581
# (343, 4)
# 10582
# (190, 4)
# (262, 4)
# (215, 4)
# (221, 4)
# (208, 4)
# (46, 4)
# (45, 4)
# (45, 4)
# (42, 4)
# (424, 4)
# (355, 4)
# (367, 4)
# (422, 4)
# (497, 4)
# (169, 4)
# 10583
# (170, 4)
# 10584
# (204, 4)
# 10585
# (186, 4)
# 10586
# (170, 4)
# 10587
# (262, 4)
# (215, 4)
# (182, 4)
# (233, 4)
# (235, 4)
# (87, 4)
# (89, 4)
# (83, 4)
# (97, 4)
# (70, 4)
# (139, 4)
# (131, 4)
# (116, 4)
# (115, 4)
# (120, 4)
# (117, 4)
# (130, 4)
# (144, 4)
# (134, 4)
# (126, 4)
# (106, 4)
# (79, 4)
# (103, 4)
# (68, 4)
# (124, 4)
# (70, 4)
# (68, 4)
# (125, 4)
# (59, 4)
# (76, 4)
# (77, 4)
# (55, 4)
# (59, 4)
# (1722, 4)
# (1812, 4)
# (1727, 4)
# (1791, 4)
# (245, 4)
# (235, 4)
# (267, 4)
# (232, 4)
# (285, 4)
# (124, 4)
# (134, 4)
# (140, 4)
# (122, 4)
# (145, 4)
# (205, 4)
# (205, 4)
# (222, 4)
# (208, 4)
# (215, 4)
# (57, 4)
# (77, 4)
# (74, 4)
# (68, 4)
# (60, 4)
# (181, 4)
# (162, 4)
# (204, 4)
# (158, 4)
# (161, 4)
# (345, 4)
# (308, 4)
# (324, 4)
# (338, 4)
# (288, 4)
# (1915, 4)
# (1625, 4)
# (1686, 4)
# (1787, 4)
# (1963, 4)
# (209, 4)
# (282, 4)
# (243, 4)
# (255, 4)
# (235, 4)
# (169, 4)
# (209, 4)
# (181, 4)
# (207, 4)
# (189, 4)
# (62, 4)
# (52, 4)
# (69, 4)
# (56, 4)
# (47, 4)
# (31, 4)
# 10588
# (28, 4)
# 10589
# (32, 4)
# 10590
# (30, 4)
# 10591
# (29, 4)
# 10592
# (52, 4)
# (1126, 4)
# (1457, 4)
# (1285, 4)
# (733, 4)
# (970, 4)
# (216, 4)
# (219, 4)
# (177, 4)
# (193, 4)
# (208, 4)
# (36, 4)
# (33, 4)
# (34, 4)
# (2009, 4)
# (1606, 4)
# (1672, 4)
# (1851, 4)
# (497, 4)
# (460, 4)
# (363, 4)
# (462, 4)
# (373, 4)
# (330, 4)
# (297, 4)
# (335, 4)
# (291, 4)
# (380, 4)
# (285, 4)
# (251, 4)
# (244, 4)
# (243, 4)
# (261, 4)
# (160, 4)
# (222, 4)
# (196, 4)
# (219, 4)
# (216, 4)
# (1212, 4)
# 10593
# (1103, 4)
# 10594
# (1266, 4)
# 10595
# (1392, 4)
# 10596
# (1228, 4)
# 10597
# (92, 4)
# (51, 4)
# (76, 4)
# (61, 4)
# (94, 4)
# (72, 4)
# (73, 4)
# (72, 4)
# (78, 4)
# (84, 4)
# (196, 4)
# (220, 4)
# (194, 4)
# (219, 4)
# (206, 4)
# (148, 4)
# (163, 4)
# (150, 4)
# (166, 4)
# (169, 4)
# (126, 4)
# (171, 4)
# (123, 4)
# (129, 4)
# (100, 4)
# (143, 4)
# (106, 4)
# (161, 4)
# (105, 4)
# (140, 4)
# (168, 4)
# (160, 4)
# (128, 4)
# (187, 4)
# (163, 4)
# (99, 4)
# (88, 4)
# (89, 4)
# (106, 4)
# (110, 4)
# (115, 4)
# (81, 4)
# (92, 4)
# (71, 4)
# (77, 4)
# (89, 4)
# (71, 4)
# (75, 4)
# (94, 4)
# (66, 4)
# (238, 4)
# (168, 4)
# (203, 4)
# (209, 4)
# (183, 4)
# (123, 4)
# (98, 4)
# (134, 4)
# (146, 4)
# (92, 4)
# (104, 4)
# (129, 4)
# (143, 4)
# (122, 4)
# (132, 4)
# (43, 4)
# (55, 4)
# (51, 4)
# (41, 4)
# (43, 4)
# (112, 4)
# (128, 4)
# (105, 4)
# (157, 4)
# (106, 4)
# (119, 4)
# (145, 4)
# (160, 4)
# (141, 4)
# (141, 4)
# (149, 4)
# (168, 4)
# (165, 4)
# (159, 4)
# (145, 4)
# (239, 4)
# (174, 4)
# (258, 4)
# (201, 4)
# (240, 4)
# (427, 4)
# 10598
# (487, 4)
# 10599
# (437, 4)
# 10600
# (540, 4)
# 10601
# (450, 4)
# 10602
# (307, 4)
# 10603
# (288, 4)
# 10604
# (308, 4)
# 10605
# (295, 4)
# 10606
# (269, 4)
# 10607
# (884, 4)
# (804, 4)
# (744, 4)
# (780, 4)
# (776, 4)
# (153, 4)
# (162, 4)
# (121, 4)
# (137, 4)
# (119, 4)
# (863, 4)
# 10608
# (833, 4)
# 10609
# (809, 4)
# 10610
# (633, 4)
# 10611
# (679, 4)
# 10612
# (209, 4)
# (175, 4)
# (240, 4)
# (165, 4)
# (183, 4)
# (1822, 4)
# (1896, 4)
# (85, 4)
# (106, 4)
# (95, 4)
# (116, 4)
# (106, 4)
# (295, 4)
# (308, 4)
# (269, 4)
# (262, 4)
# (270, 4)
# (1130, 4)
# (1169, 4)
# (1079, 4)
# (1354, 4)
# (1242, 4)
# (48, 4)
# (242, 4)
# (255, 4)
# (257, 4)
# (261, 4)
# (306, 4)
# (255, 4)
# (260, 4)
# (245, 4)
# (278, 4)
# (225, 4)
# (326, 4)
# (331, 4)
# (409, 4)
# (326, 4)
# (337, 4)
# (725, 4)
# (896, 4)
# (706, 4)
# (771, 4)
# (931, 4)
# (426, 4)
# (455, 4)
# (476, 4)
# (384, 4)
# (513, 4)
# (1098, 4)
# 10613
# (912, 4)
# 10614
# (1076, 4)
# 10615
# (1033, 4)
# 10616
# (1096, 4)
# 10617
# (811, 4)
# (1246, 4)
# (1548, 4)
# (1027, 4)
# (1122, 4)
# (987, 4)
# (1010, 4)
# (959, 4)
# (973, 4)
# (889, 4)
# (989, 4)
# (1146, 4)
# (846, 4)
# (902, 4)
# (667, 4)
# (557, 4)
# (646, 4)
# (610, 4)
# (488, 4)
# (536, 4)
# (376, 4)
# (333, 4)
# (334, 4)
# (336, 4)
# (348, 4)
# (127, 4)
# (155, 4)
# (130, 4)
# (127, 4)
# (136, 4)
# (101, 4)
# (100, 4)
# (101, 4)
# (82, 4)
# (98, 4)
# (42, 4)
# (39, 4)
# (39, 4)
# (49, 4)
# (39, 4)
# (297, 4)
# (336, 4)
# (319, 4)
# (386, 4)
# (365, 4)
# (270, 4)
# (273, 4)
# (300, 4)
# (282, 4)
# (261, 4)
# (1467, 4)
# (1564, 4)
# (1499, 4)
# (1603, 4)
# (1416, 4)
# (1003, 4)
# (975, 4)
# (1006, 4)
# (972, 4)
# (1108, 4)
# (266, 4)
# (224, 4)
# (211, 4)
# (201, 4)
# (233, 4)
# (91, 4)
# (88, 4)
# (84, 4)
# (96, 4)
# (97, 4)
# (529, 4)
# (538, 4)
# (490, 4)
# (507, 4)
# (611, 4)
# (371, 4)
# (358, 4)
# (372, 4)
# (381, 4)
# (327, 4)
# (409, 4)
# (427, 4)
# (461, 4)
# (388, 4)
# (340, 4)
# (349, 4)
# (332, 4)
# (288, 4)
# (327, 4)
# (336, 4)
# (1804, 4)
# (1709, 4)
# (2041, 4)
# (1893, 4)
# (2043, 4)
# (972, 4)
# (885, 4)
# (950, 4)
# (864, 4)
# (993, 4)
# (528, 4)
# (686, 4)
# (499, 4)
# (530, 4)
# (581, 4)
# (278, 4)
# (224, 4)
# (235, 4)
# (264, 4)
# (255, 4)
# (1572, 4)
# (1978, 4)
# (1808, 4)
# (1610, 4)
# (1586, 4)
# (687, 4)
# (563, 4)
# (707, 4)
# (681, 4)
# (659, 4)
# (153, 4)
# 10618
# (156, 4)
# 10619
# (131, 4)
# 10620
# (161, 4)
# 10621
# (150, 4)
# 10622
# (169, 4)
# (167, 4)
# (154, 4)
# (156, 4)
# (144, 4)
# (61, 4)
# (89, 4)
# (85, 4)
# (103, 4)
# (68, 4)
# (401, 4)
# (397, 4)
# (393, 4)
# (465, 4)
# (526, 4)
# (131, 4)
# (141, 4)
# (146, 4)
# (145, 4)
# (126, 4)
# (939, 4)
# (863, 4)
# (989, 4)
# (1132, 4)
# (888, 4)
# (1178, 4)
# (1112, 4)
# (918, 4)
# (1159, 4)
# (963, 4)
# (758, 4)
# (673, 4)
# (695, 4)
# (688, 4)
# (679, 4)
# (303, 4)
# (265, 4)
# (314, 4)
# (253, 4)
# (276, 4)
# (210, 4)
# (172, 4)
# (178, 4)
# (201, 4)
# (374, 4)
# (319, 4)
# (312, 4)
# (339, 4)
# (306, 4)
# (130, 4)
# (141, 4)
# (119, 4)
# (121, 4)
# (136, 4)
# (264, 4)
# (299, 4)
# (217, 4)
# (242, 4)
# (281, 4)
# (67, 4)
# (67, 4)
# (70, 4)
# (752, 4)
# (714, 4)
# (746, 4)
# (730, 4)
# (695, 4)
# (1468, 4)
# (1199, 4)
# (1353, 4)
# (1401, 4)
# (1343, 4)
# (1124, 4)
# (1128, 4)
# (1046, 4)
# (1133, 4)
# (890, 4)
# (734, 4)
# (780, 4)
# (837, 4)
# (890, 4)
# (879, 4)
# (897, 4)
# (728, 4)
# (645, 4)
# (693, 4)
# (850, 4)
# (490, 4)
# (479, 4)
# (551, 4)
# (528, 4)
# (499, 4)
# (286, 4)
# (311, 4)
# (317, 4)
# (318, 4)
# (302, 4)
# (298, 4)
# (237, 4)
# (284, 4)
# (221, 4)
# (290, 4)
# (151, 4)
# (128, 4)
# (127, 4)
# (205, 4)
# (150, 4)
# (118, 4)
# (100, 4)
# (126, 4)
# (100, 4)
# (95, 4)
# (79, 4)
# (118, 4)
# (88, 4)
# (78, 4)
# (77, 4)
# (91, 4)
# (91, 4)
# (67, 4)
# (90, 4)
# (66, 4)
# (331, 4)
# (367, 4)
# (372, 4)
# (376, 4)
# (407, 4)
# (1399, 4)
# (1386, 4)
# (1254, 4)
# (1096, 4)
# (1231, 4)
# (509, 4)
# (525, 4)
# (505, 4)
# (584, 4)
# (608, 4)
# (481, 4)
# (548, 4)
# (550, 4)
# (518, 4)
# (546, 4)
# (762, 4)
# (1034, 4)
# (805, 4)
# (676, 4)
# (770, 4)
# (671, 4)
# (612, 4)
# (671, 4)
# (744, 4)
# (673, 4)
# (72, 4)
# (68, 4)
# (66, 4)
# (72, 4)
# (54, 4)
# (186, 4)
# (231, 4)
# (278, 4)
# (236, 4)
# (260, 4)
# (89, 4)
# (92, 4)
# (186, 4)
# (327, 4)
# (266, 4)
# (211, 4)
# (209, 4)
# (626, 4)
# (705, 4)
# (562, 4)
# (673, 4)
# (565, 4)
# (171, 4)
# 10623
# (214, 4)
# 10624
# (194, 4)
# 10625
# (233, 4)
# 10626
# (171, 4)
# 10627
# (104, 4)
# 10628
# (97, 4)
# 10629
# (87, 4)
# 10630
# (105, 4)
# 10631
# (90, 4)
# 10632
# (86, 4)
# 10633
# (89, 4)
# 10634
# (77, 4)
# 10635
# (78, 4)
# 10636
# (88, 4)
# 10637
# (36, 4)
# 10638
# (34, 4)
# 10639
# (38, 4)
# 10640
# (38, 4)
# 10641
# (42, 4)
# 10642
# (45, 4)
# (52, 4)
# (37, 4)
# (51, 4)
# (55, 4)
# (935, 4)
# 10643
# (950, 4)
# 10644
# (969, 4)
# 10645
# (1048, 4)
# 10646
# (975, 4)
# 10647
# (523, 4)
# (568, 4)
# (428, 4)
# (503, 4)
# (536, 4)
# (831, 4)
# (662, 4)
# (677, 4)
# (555, 4)
# (712, 4)
# (1866, 4)
# (1520, 4)
# (1349, 4)
# (1428, 4)
# (1485, 4)
# (1020, 4)
# (1280, 4)
# (1185, 4)
# (1230, 4)
# (1080, 4)
# (474, 4)
# (419, 4)
# (462, 4)
# (463, 4)
# (533, 4)
# (333, 4)
# (311, 4)
# (358, 4)
# (301, 4)
# (384, 4)
# (117, 4)
# 10648
# (144, 4)
# 10649
# (141, 4)
# 10650
# (131, 4)
# 10651
# (136, 4)
# 10652
# (237, 4)
# (251, 4)
# (171, 4)
# (193, 4)
# (227, 4)
# (139, 4)
# (160, 4)
# (133, 4)
# (182, 4)
# (171, 4)
# (461, 4)
# (506, 4)
# (618, 4)
# (565, 4)
# (640, 4)
# (121, 4)
# (109, 4)
# (112, 4)
# (131, 4)
# (131, 4)
# (61, 4)
# (77, 4)
# (97, 4)
# (1127, 4)
# 10653
# (1189, 4)
# 10654
# (1176, 4)
# 10655
# (934, 4)
# 10656
# (1229, 4)
# 10657
# (39, 4)
# (46, 4)
# (59, 4)
# (82, 4)
# (60, 4)
# (130, 4)
# (113, 4)
# (108, 4)
# (126, 4)
# (121, 4)
# (58, 4)
# (59, 4)
# (62, 4)
# (66, 4)
# (36, 4)
# (25, 4)
# (22, 4)
# (46, 4)
# (44, 4)
# (127, 4)
# (97, 4)
# (110, 4)
# (131, 4)
# (118, 4)
# (275, 4)
# (298, 4)
# (319, 4)
# (324, 4)
# (289, 4)
# (42, 4)
# (76, 4)
# (86, 4)
# (82, 4)
# (60, 4)
# (45, 4)
# (13, 4)
# (43, 4)
# (38, 4)
# (40, 4)
# (137, 4)
# (180, 4)
# (181, 4)
# (157, 4)
# (146, 4)
# (1456, 4)
# 10658
# (1433, 4)
# 10659
# (1320, 4)
# 10660
# (1529, 4)
# 10661
# (1121, 4)
# 10662
# (108, 4)
# (140, 4)
# (129, 4)
# (104, 4)
# (155, 4)
# (248, 4)
# (229, 4)
# (226, 4)
# (265, 4)
# (208, 4)
# (894, 4)
# (922, 4)
# (1156, 4)
# (882, 4)
# (1029, 4)
# (133, 4)
# (172, 4)
# (150, 4)
# (129, 4)
# (176, 4)
# (66, 4)
# (74, 4)
# (69, 4)
# (68, 4)
# (70, 4)
# (48, 4)
# (45, 4)
# (42, 4)
# (42, 4)
# (37, 4)
# (513, 4)
# (556, 4)
# (558, 4)
# (688, 4)
# (632, 4)
# (63, 4)
# 10663
# (73, 4)
# 10664
# (77, 4)
# 10665
# (79, 4)
# 10666
# (78, 4)
# 10667
# (1044, 4)
# (1183, 4)
# (1099, 4)
# (1124, 4)
# (1079, 4)
# (1707, 4)
# (1763, 4)
# (1484, 4)
# (1679, 4)
# (1480, 4)
# (528, 4)
# (561, 4)
# (519, 4)
# (448, 4)
# (516, 4)
# (84, 4)
# 10668
# (108, 4)
# 10669
# (109, 4)
# 10670
# (95, 4)
# 10671
# (95, 4)
# 10672
# (26, 4)
# 10673
# (35, 4)
# 10674
# (40, 4)
# 10675
# (27, 4)
# 10676
# (34, 4)
# 10677
# (18, 4)
# 10678
# (12, 4)
# 10679
# (12, 4)
# 10680
# (17, 4)
# 10681
# (160, 4)
# (154, 4)
# (136, 4)
# (166, 4)
# (158, 4)
# (233, 4)
# 10682
# (242, 4)
# 10683
# (228, 4)
# 10684
# (261, 4)
# 10685
# (237, 4)
# 10686
# (246, 4)
# 10687
# (199, 4)
# 10688
# (221, 4)
# 10689
# (207, 4)
# 10690
# (190, 4)
# 10691
# (246, 4)
# (206, 4)
# (210, 4)
# (175, 4)
# (219, 4)
# (55, 4)
# (46, 4)
# (35, 4)
# (40, 4)
# (39, 4)
# (496, 4)
# (615, 4)
# (565, 4)
# (541, 4)
# (581, 4)
# (344, 4)
# (278, 4)
# (303, 4)
# (280, 4)
# (330, 4)
# (153, 4)
# (143, 4)
# (122, 4)
# (119, 4)
# (156, 4)
# (157, 4)
# (161, 4)
# (201, 4)
# (146, 4)
# (149, 4)
# (103, 4)
# (95, 4)
# (83, 4)
# (94, 4)
# (102, 4)
# (112, 4)
# (108, 4)
# (114, 4)
# (102, 4)
# (98, 4)
# (32, 4)
# (1621, 4)
# (1676, 4)
# (2026, 4)
# (1855, 4)
# (1218, 4)
# (1263, 4)
# (1492, 4)
# (1366, 4)
# (1295, 4)
# (796, 4)
# (764, 4)
# (829, 4)
# (801, 4)
# (890, 4)
# (348, 4)
# (389, 4)
# (316, 4)
# (302, 4)
# (314, 4)
# (128, 4)
# (107, 4)
# (105, 4)
# (122, 4)
# (104, 4)
# (1561, 4)
# (1785, 4)
# (1593, 4)
# (1709, 4)
# (1698, 4)
# (1925, 4)
# (1929, 4)
# (1680, 4)
# (1841, 4)
# (1708, 4)
# (1574, 4)
# (515, 4)
# (609, 4)
# (514, 4)
# (588, 4)
# (673, 4)
# (73, 4)
# (61, 4)
# (77, 4)
# (70, 4)
# (58, 4)
# (800, 4)
# (730, 4)
# (720, 4)
# (674, 4)
# (658, 4)
# (493, 4)
# (404, 4)
# (394, 4)
# (344, 4)
# (370, 4)
# (171, 4)
# (157, 4)
# (139, 4)
# (151, 4)
# (182, 4)
# (28, 4)
# (41, 4)
# (28, 4)
# (1042, 4)
# (1148, 4)
# (1205, 4)
# (1048, 4)
# (1321, 4)
# (154, 4)
# (146, 4)
# (141, 4)
# (128, 4)
# (148, 4)
# (373, 4)
# (428, 4)
# (424, 4)
# (424, 4)
# (429, 4)
# (617, 4)
# (606, 4)
# (528, 4)
# (601, 4)
# (706, 4)
# (221, 4)
# (228, 4)
# (238, 4)
# (187, 4)
# (237, 4)
# (78, 4)
# (73, 4)
# (57, 4)
# (64, 4)
# (62, 4)
# (109, 4)
# (102, 4)
# (101, 4)
# (94, 4)
# (108, 4)
# (1008, 4)
# (982, 4)
# (1438, 4)
# (1309, 4)
# (1117, 4)
# (1252, 4)
# (1099, 4)
# (1408, 4)
# (1348, 4)
# (1314, 4)
# (345, 4)
# (355, 4)
# (299, 4)
# (379, 4)
# (360, 4)
# (1007, 4)
# (1281, 4)
# (1145, 4)
# (1225, 4)
# (839, 4)
# (532, 4)
# (559, 4)
# (642, 4)
# (517, 4)
# (551, 4)
# (494, 4)
# (459, 4)
# (479, 4)
# (459, 4)
# (564, 4)
# (243, 4)
# (190, 4)
# (196, 4)
# (211, 4)
# (224, 4)

# %%
print(count, count_0, count1, count2, count3)
# Out:
# (6117, 8128, 9482, 8180, 8180)

# %%
# points in each window:2048
# number of windows
#

def get_list(start_idx,end_idx,num_points=1024,ensure_all=True):
    """
    param:
    start_idx  : list of indexes of the starting point in each window
    end_idx    : list of indees of ending point in each window
    NOTES: we used two lists because we ran into issues with tensorflow when we used tuples,
           this is a quick hack to avoid that
    num_points : number of points to be sampled from i.e number of points in each window
    ensure_all : in the case that there are fewwer than required points ensures all points are picked atleast once if selected as True
    
    
    returns:
    out:  an array of size 
          
          num_windowsxnum_pointsx1
          
          this will be used inside tensorflow to divide into windows 
          after we pass the points trough pointnet
    """
    
    out= []
    for i in range(np.shape(start_idx)[0]):
        
        if end_idx[i]-start_idx[i]+1<num_points:
            indexes=np.arange(start_idx[i],end_idx[i]+1)
            indexes2=np.random.choice(indexes, num_points-np.shape(indexes)[0],replace=True)
            indexes=np.concatenate((indexes,indexes2))
        else:
            indexes=np.random.choice(np.arange(start_idx[i],end_idx[i]+1),num_points,replace=False)
        out.append(np.reshape(indexes,(-1,1)))
    
    return np.array(out)

# %%
import tf_util #for conv2d
from model_util import NUM_HEADING_BIN, NUM_SIZE_CLUSTER, NUM_OBJECT_POINT
from model_util import point_cloud_masking, get_center_regression_net
from model_util import placeholder_inputs, parse_output_to_tensors, get_loss

# %%
# https://github.com/ailias/Focal-Loss-implement-on-Tensorflow/blob/master/focal_loss.py


from tensorflow.python.ops import array_ops

def focal_loss(sigmoid_p, target_tensor, weights=None, alpha=0.99, gamma=2):
    r"""Compute focal loss for predictions.
        Multi-labels Focal loss formula:
            FL = -alpha * (z-p)^gamma * log(p) -(1-alpha) * p^gamma * log
            (1-p)
                 ,which alpha = 0.25, gamma = 2, p = sigmoid(x), z = target_tensor.
    Args:
     prediction_tensor: A float tensor of shape [batch_size, num_anchors,
        num_classes] representing the predicted logits for each class
     target_tensor: A float tensor of shape [batch_size, num_anchors,
        num_classes] representing one-hot encoded classification targets
     weights: A float tensor of shape [batch_size, num_anchors]
     alpha: A scalar tensor for focal loss alpha hyper-parameter
     gamma: A scalar tensor for focal loss gamma hyper-parameter
    Returns:
        loss: A (scalar) tensor representing the value of the loss function
    """
    #sigmoid_p = tf.nn.sigmoid(prediction_tensor)
    zeros = array_ops.zeros_like(target_tensor, dtype=target_tensor.dtype)
    
    # For poitive prediction, only need consider front part loss, back part is 0;
    # target_tensor > zeros <=> z=1, so poitive coefficient = z - p.
    pos_p_sub = array_ops.where(target_tensor > zeros, target_tensor - sigmoid_p, zeros)
    
    # For negative prediction, only need consider back part loss, front part is 0;
    # target_tensor > zeros <=> z=1, so negative coefficient = 0.
    neg_p_sub = array_ops.where(target_tensor > zeros, zeros, sigmoid_p)
    per_entry_cross_ent = - alpha * (pos_p_sub ** gamma) * tf.log(tf.clip_by_value(sigmoid_p, 1e-8, 1.0)) \
                          - (1.0 - alpha) * (neg_p_sub ** gamma) * tf.log(tf.clip_by_value(1.0 - sigmoid_p, 1e-8, 1.0))
    return tf.reduce_sum(per_entry_cross_ent)

# %%
# def classification_net(point_cloud, label_out_5, label_out_1, label_out_2, label_out_3, label_out_4, idx5, idx1, idx2, idx3, idx4, 
#                             is_training=True, bn_decay=True):
def classification_net(point_cloud, label_out_5,  idx5, 
                            is_training=True, bn_decay=True):
    '''
    3D PointNet network.
    param:
    
    point_cloud: TF tensor in shape (1,N,4)
                 frustum point clouds with XYZ and intensity in point channels
                 XYZs are in frustum coordinate
    label_out: TF tensor in shape (1,1)
            length-1 vector indicating the classification as car or background
    
    ??????????????????????????????????????????????????????????????????????????????????????
    
    is_training: TF boolean scalar
    bn_decay: TF float scalar
    end_points: dict                 SHOULD CHANGE THIS
    Output:                                         
    logits: TF tensor in shape (B,N,2), scores for bkg/clutter and object
    end_points: dict
    ??????????????????????????????????????????????????????????????????????????????????????
    '''
    
    batch_size = point_cloud.get_shape()[0].value #1 in our case
    num_point = point_cloud.get_shape()[1].value  #N in our case
  
    net = tf.expand_dims(point_cloud, 2)
    #print(net.get_shape())

    net = tf_util.conv2d(net, 64, [1,1],
                         padding='VALID', stride=[1,1],
                         bn=True, is_training=is_training,
                         scope='conv1', bn_decay=bn_decay)
    net = tf_util.conv2d(net, 64, [1,1],
                         padding='VALID', stride=[1,1],
                         bn=True, is_training=is_training,
                         scope='conv2', bn_decay=bn_decay)
    point_feat = tf_util.conv2d(net, 64, [1,1],
                         padding='VALID', stride=[1,1],
                         bn=True, is_training=is_training,
                         scope='conv3', bn_decay=bn_decay)
    net = tf_util.conv2d(point_feat, 128, [1,1],
                         padding='VALID', stride=[1,1],
                         bn=True, is_training=is_training,
                         scope='conv4', bn_decay=bn_decay)
    features = tf_util.conv2d(net, 1024, [1,1],
                         padding='VALID', stride=[1,1],
                         bn=True, is_training=is_training,
                         scope='conv5', bn_decay=bn_decay)
    
    features=tf.squeeze(features,axis=2)
    features=tf.squeeze(features,axis=0)   

    #features=tf.placeholder(tf.float32,[1,1024,4])

    def fn(x):
        return tf.gather_nd(features,x)
    
    windows_5 =tf.map_fn(fn,idx5,dtype=tf.float32)
#     windows_1 = tf.map_fn(fn,idx1,dtype=tf.float32)
#     windows_2 = tf.map_fn(fn,idx2,dtype=tf.float32)
#     windows_3 = tf.map_fn(fn,idx3,dtype=tf.float32)
#     windows_4 = tf.map_fn(fn,idx4,dtype=tf.float32)
    
    windows_5_1024 = tf.reduce_max(windows_5,axis=1)
#     windows_1_1024 = tf.reduce_max(windows_1,axis=1)
#     windows_2_1024 = tf.reduce_max(windows_2,axis=1)
#     windows_3_1024 = tf.reduce_max(windows_3,axis=1)
#     windows_4_1024 = tf.reduce_max(windows_4,axis=1)
    
    
    winex_5 =  tf.reshape(windows_5_1024,shape=[-1,1,1,1024])
#     winex_1 =  tf.reshape(windows_1_1024,shape=[-1,1,1,1024])
#     winex_2 =  tf.reshape(windows_2_1024,shape=[-1,1,1,1024])
#     winex_3 =  tf.reshape(windows_3_1024,shape=[-1,1,1,1024])
#     winex_4 =  tf.reshape(windows_4_1024,shape=[-1,1,1,1024])
   
    winex = tf.concat([winex_5], axis=0)
    label_out = tf.concat([label_out_5],axis=0)

    
    
#     winex = tf.concat([winex_5, winex_1, winex_2, winex_3, winex_4], axis=0)
#     label_out = tf.concat([label_out_5,label_out_1, label_out_2, label_out_3, label_out_4],axis=0)

    #classification head
    d1 = tf_util.conv2d(winex, 512, [1,1],
                             padding='VALID', stride=[1,1],
                             bn=True, is_training=is_training,
                             scope='dense1', bn_decay=bn_decay)
    d2 = tf_util.conv2d(d1, 256, [1,1],
                             padding='VALID', stride=[1,1],
                             bn=True, is_training=is_training,
                             scope='dense2', bn_decay=bn_decay)
    d2=tf.layers.dropout(d2,rate=0.5, training=is_training, name='drop1')
    
    logits = tf_util.conv2d(d2, 1, [1,1],
                             padding='VALID', stride=[1,1],
                             bn=True, is_training=is_training,
                             scope='out', bn_decay=bn_decay, activation_fn=None)
    
    logits = tf.squeeze(logits)
    logits=tf.reshape(tf.squeeze(logits),(1,-1))
    sig = tf.sigmoid(logits)

    #sig = tf.reshape(tf.squeeze(sig),(-1,1))
    y=tf.reshape(sig,[-1])
    
    max_ind = tf.argmax(y)
    
    tp = tf.equal(label_out[max_ind], 1)
    
    
    differentiable_round = tf.maximum(y-0.499,0)
    differentiable_round = differentiable_round * 10000
    y_pred = tf.minimum(differentiable_round, 1)
    #y_pred=tf.round(y)
    
    true_pos  = tf.reduce_sum(tf.cast(tf.logical_and(tf.cast(label_out,tf.bool),tf.cast(y_pred,tf.bool)),tf.float32))
    
    false_pos = tf.reduce_sum(tf.cast(tf.logical_and(tf.logical_not(tf.cast(label_out,tf.bool)),tf.cast(y_pred,tf.bool)),tf.float32))
    true_neg  = tf.reduce_sum(tf.cast(tf.logical_not(tf.logical_or(tf.cast(label_out, tf.bool),\
                                                                   tf.cast(y_pred, tf.bool))),tf.float32))
    false_neg = tf.reduce_sum(tf.cast(tf.logical_and(tf.logical_not\
                                                     (tf.cast(y_pred,tf.bool)),tf.cast(label_out,tf.bool)),tf.float32))
    return sig,logits, label_out,true_pos,false_pos,true_neg,false_neg, tp, max_ind

# %%
tf.reset_default_graph()
with tf.device('/device:GPU:0'):
    num_points_5 =512
#     num_points_1 = 512
#     num_points_2 = 512
#     num_points_3 = 512
#     num_points_4 = 512
    
    inputs=tf.placeholder(tf.float32,[None,2048,4])#put placeholder

    idx_5 =tf.placeholder(tf.int32,[None,num_points_5,1])

#     idx_1 = tf.placeholder(tf.int32,[None,num_points_1,1])
    
#     idx_2 = tf.placeholder(tf.int32,[None,num_points_2,1])

#     idx_3 = tf.placeholder(tf.int32,[None,num_points_3,1])
    
#     idx_4 = tf.placeholder(tf.int32,[None,num_points_4,1])

    is_training = tf.placeholder(tf.bool)
    

    label_out_5 = tf.placeholder(tf.int32, [None])
#     label_out_1 = tf.placeholder(tf.int32, [None])
#     label_out_2 = tf.placeholder(tf.int32, [None])
#     label_out_3 = tf.placeholder(tf.int32, [None])
#     label_out_4 = tf.placeholder(tf.int32, [None])

    sig,logits, label_out,tp,fp,tn,fn, tp_num, maxi = classification_net(inputs, label_out_5, \
                                         idx_5, is_training)
    
    
#     sig,logits, label_out,tp,fp,tn,fn = classification_net(inputs, label_out_5, label_out_1,label_out_2, label_out_3, label_out_4, \
#                                          idx_5, idx_1, idx_2, idx_3, idx_4, is_training)
    
    func_fl = focal_loss(tf.squeeze(sig),tf.squeeze(tf.cast(label_out, tf.float32)), gamma=0.75, alpha=0.25)
    print(label_out.get_shape())
#     loss=tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(
#     labels=tf.reshape(tf.cast(label_out,tf.float32),(-1,1)),
#     logits=tf.reshape(logits,(-1,1))))

    loss = tf.reduce_mean(func_fl)
#     tpr=tf.divide(tf.cast(tp,tf.float32),tf.add(tp,fp))
#     tnr=tf.divide(tf.cast(tn,tf.float32),tf.add(tn,fn))
#     loss=tf.reduce_sum(tf.constant(1.0)-tf.scalar_mul(0.5,tf.add(tpr,tnr)))
    
    
    optimizer = tf.train.AdamOptimizer(1e-5)
    #train_step=optimizer.minimize(loss)
    update_ops = tf.get_collection(tf.GraphKeys.UPDATE_OPS)
    with tf.control_dependencies(update_ops):
        train_op = optimizer.minimize(loss)
# Out:
# (?,)

# %%
from tensorflow.python import debug

# %%
import datetime
import logging
from random import shuffle
#logging.basicConfig(filename='run_1.log',level=logging.DEBUG)
from tensorflow.python import debug as tf_debug
print(datetime.datetime.now().strftime("%a, %d %B %Y %I:%M:%S"))

IOU_list = []
saver = tf.train.Saver()
trix=[cc for cc in range(TRAIN_DATASET.__len__())]
shuffle(trix)
prob = []
with tf.Session(config=tf.ConfigProto(allow_soft_placement=True, log_device_placement=True)) as sess:
    #sess=tf_debug.LocalCLIDebugWrapperSession(sess)
    sess.run(tf.global_variables_initializer())
    variables_names = [v.name for v in tf.trainable_variables()]
    values = sess.run(variables_names)
    for k, v in zip(variables_names, values):
        print "Variable: ", k
        print "Shape: ", v.shape
    # uncomment this when we want to load the checkpoint model
    #saver.restore(sess, "./checkpoints/model_new_labels_0_3827.ckpt")
    
    

    
    
    
    
    
    
    
    for j in range(0,15):   
        total_tp=0
        total_fp=0
        total_tn=0
        total_fn=0
        total_tpnums = 0
        total_fpnums = 0
        total_fnnums = 0
        
        
        print(datetime.datetime.now().strftime("%a, %d %B %Y %I:%M:%S"))
        
        print('Epoch Number........................................',j)
        pedc=0
        
        for i in trix:
        #todo reformat code to have lists instead of many variable
            if TRAIN_DATASET.type_list[i]=='Pedestrian':
                pedc+=1
                if pedc%500==0:
                    total_tp=0
                    total_fp=0
                    total_tn=0
                    total_fn=0
                    total_tpnums = 0
                    total_fpnums = 0
                    total_fnnums = 0
                point_set,labels,a,b,c,d,e,f,cls = TRAIN_DATASET.__getitem__(i)

                index = np.argsort(point_set[:,2])
                point_set = point_set[index]
                labels = labels[index]

                corners_gt = TRAIN_DATASET.get_center_view_box3d(i)
                
                #print(point_set.shape)

                s5,e5,l = indices(1.0,0.1,point_set,labels, corners_gt)
        
                #l1 = (l1>=0.6)
                
                print('Label shape', l.shape)

#                 s1, e1, l1 = indices(i, 1.1, 0.2)

#                 s2, e2, l2 = indices(i, 1.3, 0.2)

#                 s3, e3, l3 = indices(i, 0.7, 0.1)

#                 s4, e4, l4 = indices(i, 0.5, 0.1)
                
                if s5.size :#and s2.size and s3.size and s4.size and s1.size:

                    ind_5 = get_list(s5,e5, num_points=512)

#                     ind_1 = get_list(s1,e1, num_points=512)

#                     ind_2 = get_list(s2,e2, num_points=512)

#                     ind_3 = get_list(s3,e3, num_points=512)

#                     ind_4 = get_list(s4,e4, num_points=512)
#                     t_windows=s1.shape[0]+s2.shape[0]+s3.shape[0]+s4.shape[0]+s5.shape[0]

                    point_set = np.expand_dims(point_set, axis=0)
                        
                    _, x,tpos,fpos,tneg,fneg, tpnums =sess.run([train_op, loss,tp,fp,tn,fn, tp_num],feed_dict={idx_5:ind_5,\
                                                               label_out_5: l.astype(np.int32),\
                                                               inputs:point_set, is_training: True})
                    total_tp+=tpos
                    total_fp+=fpos
                    total_tn+=tneg
                    total_fn+=fneg
                    total_tpnums+= tpnums
                    total_fpnums+= (1-tpnums)
                    total_fnnums+= (1-tpnums)
                    print('----------------------------------------------------------------------------------')
                    print('Epoch ', j , 'Loss for the current example ',i,' = ', x,'pedc = ',pedc)
                    #logging.info('Loss for the current example ',i,' = ', x)
                    print('Metrics for current example: TP=',tpos,' FP=',fpos,' TN=',tneg,' FN=',fneg)
                    #logging.info('Metrics for current example: TP=',tpos,' FP=',fpos,' TN=',tneg,' FN=',fneg)  # will not print anything
                    #print('Cumulative metrics: TP=',total_tp,' FP=',total_fp,' TN=',total_tn,' FN=',total_fn)
                    print('Cumulative metrics: Precision = ',(total_tp*1.0)/(total_tp+total_fp),\
                          ' Recall = ',(total_tp*1.0)/(total_tp+total_fn))
                    #logging.info('Cumulative metrics: Precision = ',(total_tp*1.0)/(total_tp+total_fp),\
                    #      ' Recall = ',(total_tp*1.0)/(total_tp+total_fn))
                    print('Single metrics: Precision = ',(total_tpnums*1.0)/(total_tpnums+total_fpnums),\
                          ' Recall = ',(total_tpnums*1.0)/(total_tpnums+total_fnnums))
                    print('----------------------------------------------------------------------------------')
                    
                    if(pedc%5000==0):
                        save_path = saver.save(sess, "./checkpoints/model_new_labels_pointwiseIOU_"+str(j)+'_'+str(pedc)+".ckpt")
                    

                #print(c)
                #print(n)
            #i += 1
        #-----------------------------------------------------------------------------------------------#
        print('&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&')
        k = 0
        Vtotal_tp=0
        Vtotal_fp=0
        Vtotal_tn=0
        Vtotal_fn=0
        Vtotal_tpnums = 0
        Vtotal_fpnums = 0
        Vtotal_fnnums = 0
        while k<len(VAL_DATASET):
        #todo reformat code to have lists instead of many variable

            if VAL_DATASET.type_list[k]=='Pedestrian':

                point_set,labels,a,b,c,d,e,f,cls = VAL_DATASET.__getitem__(k)

                index = np.argsort(point_set[:,2])
                point_set = point_set[index]
                labels = labels[index]

                
                corners_gt = VAL_DATASET.get_center_view_box3d(k)
                
                #print(point_set.shape)

                s5,e5,l = indices(1.0,0.1,point_set,labels, corners_gt)
                
                #l1 = l1>0.5

#                 s1, e1, l1 = indices(k, 1.1, 0.2, 'val')

#                 s2, e2, l2 = indices(k, 1.3, 0.2, 'val')

#                 s3, e3, l3 = indices(k, 0.7, 0.1, 'val')

#                 s4, e4, l4 = indices(k, 0.5, 0.1, 'val')

                if s5.size :#and s2.size and s3.size and s4.size and s1.size:

                    ind_5 = get_list(s5,e5, num_points=512)

#                     ind_1 = get_list(s1,e1, num_points=512)

#                     ind_2 = get_list(s2,e2, num_points=512)

#                     ind_3 = get_list(s3,e3, num_points=512)

#                     ind_4 = get_list(s4,e4, num_points=512)

#                     t_windows=s1.shape[0]+s2.shape[0]+s3.shape[0]+s4.shape[0]+s5.shape[0]

                    point_set = np.expand_dims(point_set, axis=0)
                    print(Vtotal_tp)
                    x,tpos,fpos,tneg,fneg, tp_nums, maxind =sess.run([loss,tp,fp,tn,fn, tp_num, maxi],feed_dict={idx_5:ind_5, \
                                                               label_out_5: l.astype(np.int32), inputs:point_set, is_training: True})


                    #window_points = ind_5[maxind]

                    #window_points = point_set[0,ind_5[maxind].reshape((-1))][:,:3]
                    #min_x, min_y, min_z = np.min(window_points,axis=0)
                    #max_x, max_y, max_z = np.max(window_points,axis=0)
                    #corners = [[min_x,max_y,max_z],[min_x,max_y,min_z],[max_x,max_y,min_z],[max_x,max_y,max_z],\
                    #           [min_x,min_y,max_z],[min_x,min_y,min_z],[max_x,min_y,min_z],[max_x,min_y,max_z]]
                    #corners=np.array(corners)
                    #corners_gt = VAL_DATASET.get_center_view_box3d(k)
                    #IOU, IOU_2D, inter, inter_vol = box_util.box3d_iou(corners, corners_gt)
                    #print('IOUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUU')
                    #print(IOU, IOU_2D, inter, inter_vol)
                    #IOU_list.append([IOU, IOU_2D, inter, inter_vol, k])
                    #if inter>0.4:
                    #    c += 1
                    #    if inter>0.5:
                    #        c1 += 1
                    #if inter_vol>0.4:
                    #    c2 += 1
                    #    if inter_vol>0.5:
                    #        c3 +=1 

                    print(Vtotal_tp)
                    Vtotal_tp +=tpos
                    Vtotal_fp +=fpos
                    Vtotal_tn +=tneg
                    Vtotal_fn +=fneg
                    Vtotal_tpnums+= tp_nums
                    Vtotal_fpnums+= (1-tp_nums)
                    Vtotal_fnnums+= (1-tp_nums)
                    print('&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&')
                    print('Epoch ', j , 'Loss for the current example ',k,' = ', x)
                    #logging.info('Loss for the current example ',i,' = ', x)
                    print('Metrics for current example: TP=',tpos,' FP=',fpos,' TN=',tneg,' FN=',fneg)
                    #logging.info('Metrics for current example: TP=',tpos,' FP=',fpos,' TN=',tneg,' FN=',fneg)  # will not print anything
                    #print('Cumulative metrics: TP=',total_tp,' FP=',total_fp,' TN=',total_tn,' FN=',total_fn)
                    print('Cumulative metrics: Precision = ',(Vtotal_tp*1.0)/(Vtotal_tp+Vtotal_fp),\
                          ' Recall = ',(Vtotal_tp*1.0)/(Vtotal_tp+Vtotal_fn))

                    print('Single metrics: Precision = ',(Vtotal_tpnums*1.0)/(Vtotal_tpnums+Vtotal_fpnums),\
                          ' Recall = ',(Vtotal_tpnums*1.0)/(Vtotal_tpnums+Vtotal_fnnums))
                    #logging.info('Cumulative metrics: Precision = ',(Vtotal_tp*1.0)/(Vtotal_tp+Vtotal_fp),\
                    #      ' Recall = ',(Vtotal_tp*1.0)/(Vtotal_tp+Vtotal_fn))
                    print('&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&')

            k += 1

        #----------------------------------------------------------------------------------------------#
#         prob = sess.run([sig],feed_dict={idx_5:ind_5, idx_1:ind_1, idx_2:ind_2, idx_3:ind_3, idx_4:ind_4,\
#                                                        label_out_5: l5.astype(np.int32), label_out_1: l1.astype(np.int32),\
#                                                        label_out_2: l2.astype(np.int32), label_out_3: l3.astype(np.int32),\
#                                                        label_out_4: l4.astype(np.int32), inputs:point_set,  is_training: False})
#         print(prob)
        print(ind_5)
        print(label_out_5)
        prob = sess.run([sig],feed_dict={idx_5:ind_5,  \
                                                       label_out_5: l1.astype(np.int32), inputs:point_set,  is_training: True})
        print(prob)
print(datetime.datetime.now().strftime("%a, %d %B %Y %I:%M:%S") )
# Out:
# Wed, 16 May 2018 01:02:15
# Variable:  conv1/weights:0
# Shape:  (1, 1, 4, 64)
# Variable:  conv1/biases:0
# Shape:  (64,)
# Variable:  conv1/bn/beta:0
# Shape:  (64,)
# Variable:  conv1/bn/gamma:0
# Shape:  (64,)
# Variable:  conv2/weights:0
# Shape:  (1, 1, 64, 64)
# Variable:  conv2/biases:0
# Shape:  (64,)
# Variable:  conv2/bn/beta:0
# Shape:  (64,)
# Variable:  conv2/bn/gamma:0
# Shape:  (64,)
# Variable:  conv3/weights:0
# Shape:  (1, 1, 64, 64)
# Variable:  conv3/biases:0
# Shape:  (64,)
# Variable:  conv3/bn/beta:0
# Shape:  (64,)
# Variable:  conv3/bn/gamma:0
# Shape:  (64,)
# Variable:  conv4/weights:0
# Shape:  (1, 1, 64, 128)
# Variable:  conv4/biases:0
# Shape:  (128,)
# Variable:  conv4/bn/beta:0
# Shape:  (128,)
# Variable:  conv4/bn/gamma:0
# Shape:  (128,)
# Variable:  conv5/weights:0
# Shape:  (1, 1, 128, 1024)
# Variable:  conv5/biases:0
# Shape:  (1024,)
# Variable:  conv5/bn/beta:0
# Shape:  (1024,)
# Variable:  conv5/bn/gamma:0
# Shape:  (1024,)
# Variable:  dense1/weights:0
# Shape:  (1, 1, 1024, 512)
# Variable:  dense1/biases:0
# Shape:  (512,)
# Variable:  dense1/bn/beta:0
# Shape:  (512,)
# Variable:  dense1/bn/gamma:0
# Shape:  (512,)
# Variable:  dense2/weights:0
# Shape:  (1, 1, 512, 256)
# Variable:  dense2/biases:0
# Shape:  (256,)
# Variable:  dense2/bn/beta:0
# Shape:  (256,)
# Variable:  dense2/bn/gamma:0
# Shape:  (256,)
# Variable:  out/weights:0
# Shape:  (1, 1, 256, 1)
# Variable:  out/biases:0
# Shape:  (1,)
# Variable:  out/bn/beta:0
# Shape:  (1,)
# Variable:  out/bn/gamma:0
# Shape:  (1,)
# Wed, 16 May 2018 01:02:15
# ('Epoch Number........................................', 0)
# ('Label shape', (37,))
# ----------------------------------------------------------------------------------
# ('Epoch ', 0, 'Loss for the current example ', 44020, ' = ', 13.662626, 'pedc = ', 1)
# ('Metrics for current example: TP=', 4.0, ' FP=', 15.0, ' TN=', 14.0, ' FN=', 4.0)
# ('Cumulative metrics: Precision = ', 0.21052631578947367, ' Recall = ', 0.5)
# ('Single metrics: Precision = ', 0.0, ' Recall = ', 0.0)
# ----------------------------------------------------------------------------------
# ('Label shape', (190,))
# ----------------------------------------------------------------------------------
# ('Epoch ', 0, 'Loss for the current example ', 24608, ' = ', 79.01495, 'pedc = ', 2)
# ('Metrics for current example: TP=', 0.0, ' FP=', 93.0, ' TN=', 94.0, ' FN=', 3.0)
# ('Cumulative metrics: Precision = ', 0.03571428571428571, ' Recall = ', 0.36363636363636365)
# ('Single metrics: Precision = ', 0.0, ' Recall = ', 0.0)
# ----------------------------------------------------------------------------------
# ('Label shape', (68,))
# ----------------------------------------------------------------------------------
# ('Epoch ', 0, 'Loss for the current example ', 46419, ' = ', 27.685286, 'pedc = ', 3)
# ('Metrics for current example: TP=', 2.0, ' FP=', 37.0, ' TN=', 27.0, ' FN=', 2.0)
# ('Cumulative metrics: Precision = ', 0.039735099337748346, ' Recall = ', 0.4)
# ('Single metrics: Precision = ', 0.0, ' Recall = ', 0.0)
# ----------------------------------------------------------------------------------
# ('Label shape', (131,))
# ----------------------------------------------------------------------------------
# ('Epoch ', 0, 'Loss for the current example ', 29216, ' = ', 52.671253, 'pedc = ', 4)
# ('Metrics for current example: TP=', 5.0, ' FP=', 66.0, ' TN=', 58.0, ' FN=', 2.0)
# ('Cumulative metrics: Precision = ', 0.04954954954954955, ' Recall = ', 0.5)
# ('Single metrics: Precision = ', 0.0, ' Recall = ', 0.0)
# ----------------------------------------------------------------------------------
# ('Label shape', (55,))
# ----------------------------------------------------------------------------------
# ('Epoch ', 0, 'Loss for the current example ', 13108, ' = ', 22.908897, 'pedc = ', 5)
# ('Metrics for current example: TP=', 0.0, ' FP=', 27.0, ' TN=', 27.0, ' FN=', 1.0)
# ('Cumulative metrics: Precision = ', 0.04417670682730924, ' Recall = ', 0.4782608695652174)
# ('Single metrics: Precision = ', 0.0, ' Recall = ', 0.0)
# ----------------------------------------------------------------------------------
# ('Label shape', (83,))
# ----------------------------------------------------------------------------------
# ('Epoch ', 0, 'Loss for the current example ', 19715, ' = ', 30.681292, 'pedc = ', 6)
# ('Metrics for current example: TP=', 6.0, ' FP=', 37.0, ' TN=', 37.0, ' FN=', 3.0)
# ('Cumulative metrics: Precision = ', 0.05821917808219178, ' Recall = ', 0.53125)
# ('Single metrics: Precision = ', 0.0, ' Recall = ', 0.0)
# ----------------------------------------------------------------------------------
# ('Label shape', (167,))
# ----------------------------------------------------------------------------------
# ('Epoch ', 0, 'Loss for the current example ', 13510, ' = ', 69.66443, 'pedc = ', 7)
# ('Metrics for current example: TP=', 3.0, ' FP=', 86.0, ' TN=', 77.0, ' FN=', 1.0)
# ('Cumulative metrics: Precision = ', 0.05249343832020997, ' Recall = ', 0.5555555555555556)
# ('Single metrics: Precision = ', 0.0, ' Recall = ', 0.0)
# ----------------------------------------------------------------------------------
# ('Label shape', (60,))
# ----------------------------------------------------------------------------------
# ('Epoch ', 0, 'Loss for the current example ', 21594, ' = ', 25.124098, 'pedc = ', 8)
# ('Metrics for current example: TP=', 0.0, ' FP=', 23.0, ' TN=', 34.0, ' FN=', 3.0)
# ('Cumulative metrics: Precision = ', 0.04950495049504951, ' Recall = ', 0.5128205128205128)
# ('Single metrics: Precision = ', 0.0, ' Recall = ', 0.0)
# ----------------------------------------------------------------------------------
# ('Label shape', (23,))
# ----------------------------------------------------------------------------------
# ('Epoch ', 0, 'Loss for the current example ', 49051, ' = ', 8.125568, 'pedc = ', 9)
# ('Metrics for current example: TP=', 2.0, ' FP=', 11.0, ' TN=', 10.0, ' FN=', 0.0)
# ('Cumulative metrics: Precision = ', 0.05275779376498801, ' Recall = ', 0.5365853658536586)
# ('Single metrics: Precision = ', 0.0, ' Recall = ', 0.0)
# ----------------------------------------------------------------------------------
# ('Label shape', (22,))
# ----------------------------------------------------------------------------------
# ('Epoch ', 0, 'Loss for the current example ', 64337, ' = ', 7.6166563, 'pedc = ', 10)
# ('Metrics for current example: TP=', 2.0, ' FP=', 11.0, ' TN=', 8.0, ' FN=', 1.0)
# ('Cumulative metrics: Precision = ', 0.05581395348837209, ' Recall = ', 0.5454545454545454)
# ('Single metrics: Precision = ', 0.1, ' Recall = ', 0.1)
# ----------------------------------------------------------------------------------
# ('Label shape', (71,))
# ----------------------------------------------------------------------------------
# ('Epoch ', 0, 'Loss for the current example ', 40849, ' = ', 29.286396, 'pedc = ', 11)
# ('Metrics for current example: TP=', 0.0, ' FP=', 28.0, ' TN=', 41.0, ' FN=', 2.0)
# ('Cumulative metrics: Precision = ', 0.05240174672489083, ' Recall = ', 0.5217391304347826)
# ('Single metrics: Precision = ', 0.09090909090909091, ' Recall = ', 0.09090909090909091)
# ----------------------------------------------------------------------------------
# ('Label shape', (156,))
# ----------------------------------------------------------------------------------
# ('Epoch ', 0, 'Loss for the current example ', 28898, ' = ', 63.261467, 'pedc = ', 12)
# ('Metrics for current example: TP=', 3.0, ' FP=', 69.0, ' TN=', 80.0, ' FN=', 4.0)
# ('Cumulative metrics: Precision = ', 0.0509433962264151, ' Recall = ', 0.5094339622641509)
# ('Single metrics: Precision = ', 0.08333333333333333, ' Recall = ', 0.08333333333333333)
# ----------------------------------------------------------------------------------
# ('Label shape', (77,))
# ----------------------------------------------------------------------------------
# ('Epoch ', 0, 'Loss for the current example ', 41484, ' = ', 30.245262, 'pedc = ', 13)
# ('Metrics for current example: TP=', 3.0, ' FP=', 32.0, ' TN=', 39.0, ' FN=', 3.0)
# ('Cumulative metrics: Precision = ', 0.05309734513274336, ' Recall = ', 0.5084745762711864)
# ('Single metrics: Precision = ', 0.07692307692307693, ' Recall = ', 0.07692307692307693)
# ----------------------------------------------------------------------------------
# ('Label shape', (18,))
# ----------------------------------------------------------------------------------
# ('Epoch ', 0, 'Loss for the current example ', 62270, ' = ', 6.8890877, 'pedc = ', 14)
# ('Metrics for current example: TP=', 2.0, ' FP=', 10.0, ' TN=', 6.0, ' FN=', 0.0)
# ('Cumulative metrics: Precision = ', 0.05545927209705372, ' Recall = ', 0.5245901639344263)
# ('Single metrics: Precision = ', 0.07142857142857142, ' Recall = ', 0.07142857142857142)
# ----------------------------------------------------------------------------------
# ('Label shape', (74,))
# ----------------------------------------------------------------------------------
# ('Epoch ', 0, 'Loss for the current example ', 69976, ' = ', 29.77584, 'pedc = ', 15)
# ('Metrics for current example: TP=', 2.0, ' FP=', 41.0, ' TN=', 31.0, ' FN=', 0.0)
# ('Cumulative metrics: Precision = ', 0.054838709677419356, ' Recall = ', 0.5396825396825397)
# ('Single metrics: Precision = ', 0.06666666666666667, ' Recall = ', 0.06666666666666667)
# ----------------------------------------------------------------------------------
# ('Label shape', (64,))
# ----------------------------------------------------------------------------------
# ('Epoch ', 0, 'Loss for the current example ', 23699, ' = ', 26.539944, 'pedc = ', 16)
# ('Metrics for current example: TP=', 0.0, ' FP=', 29.0, ' TN=', 33.0, ' FN=', 2.0)
# ('Cumulative metrics: Precision = ', 0.05238828967642527, ' Recall = ', 0.5230769230769231)
# ('Single metrics: Precision = ', 0.0625, ' Recall = ', 0.0625)
# ----------------------------------------------------------------------------------
# ('Label shape', (42,))
# ----------------------------------------------------------------------------------
# ('Epoch ', 0, 'Loss for the current example ', 24853, ' = ', 15.680473, 'pedc = ', 17)
# ('Metrics for current example: TP=', 3.0, ' FP=', 16.0, ' TN=', 21.0, ' FN=', 2.0)
# ('Cumulative metrics: Precision = ', 0.05538922155688623, ' Recall = ', 0.5285714285714286)
# ('Single metrics: Precision = ', 0.058823529411764705, ' Recall = ', 0.058823529411764705)
# ----------------------------------------------------------------------------------
# ('Label shape', (39,))
# ----------------------------------------------------------------------------------
# ('Epoch ', 0, 'Loss for the current example ', 20470, ' = ', 14.434225, 'pedc = ', 18)
# ('Metrics for current example: TP=', 3.0, ' FP=', 16.0, ' TN=', 20.0, ' FN=', 0.0)
# ('Cumulative metrics: Precision = ', 0.05822416302765648, ' Recall = ', 0.547945205479452)
# ('Single metrics: Precision = ', 0.05555555555555555, ' Recall = ', 0.05555555555555555)
# ----------------------------------------------------------------------------------
# ('Label shape', (138,))
# ----------------------------------------------------------------------------------
# ('Epoch ', 0, 'Loss for the current example ', 19487, ' = ', 57.25831, 'pedc = ', 19)
# ('Metrics for current example: TP=', 1.0, ' FP=', 68.0, ' TN=', 67.0, ' FN=', 2.0)
# ('Cumulative metrics: Precision = ', 0.05423280423280423, ' Recall = ', 0.5394736842105263)
# ('Single metrics: Precision = ', 0.05263157894736842, ' Recall = ', 0.05263157894736842)
# ----------------------------------------------------------------------------------
# ('Label shape', (93,))
# ----------------------------------------------------------------------------------
# ('Epoch ', 0, 'Loss for the current example ', 65368, ' = ', 38.004425, 'pedc = ', 20)
# ('Metrics for current example: TP=', 1.0, ' FP=', 43.0, ' TN=', 48.0, ' FN=', 1.0)
# ('Cumulative metrics: Precision = ', 0.0525, ' Recall = ', 0.5384615384615384)
# ('Single metrics: Precision = ', 0.05, ' Recall = ', 0.05)
# ----------------------------------------------------------------------------------
# ('Label shape', (48,))
# ----------------------------------------------------------------------------------
# ('Epoch ', 0, 'Loss for the current example ', 63382, ' = ', 14.513542, 'pedc = ', 21)
# ('Metrics for current example: TP=', 3.0, ' FP=', 19.0, ' TN=', 26.0, ' FN=', 0.0)
# ('Cumulative metrics: Precision = ', 0.05474452554744526, ' Recall = ', 0.5555555555555556)
# ('Single metrics: Precision = ', 0.09523809523809523, ' Recall = ', 0.09523809523809523)
# ----------------------------------------------------------------------------------
# ('Label shape', (26,))
# ----------------------------------------------------------------------------------
# ('Epoch ', 0, 'Loss for the current example ', 21126, ' = ', 8.797079, 'pedc = ', 22)
# ('Metrics for current example: TP=', 3.0, ' FP=', 13.0, ' TN=', 10.0, ' FN=', 0.0)
# ('Cumulative metrics: Precision = ', 0.057279236276849645, ' Recall = ', 0.5714285714285714)
# ('Single metrics: Precision = ', 0.09090909090909091, ' Recall = ', 0.09090909090909091)
# ----------------------------------------------------------------------------------
# ('Label shape', (92,))
# ----------------------------------------------------------------------------------
# ('Epoch ', 0, 'Loss for the current example ', 32452, ' = ', 34.80585, 'pedc = ', 23)
# ('Metrics for current example: TP=', 4.0, ' FP=', 43.0, ' TN=', 45.0, ' FN=', 0.0)
# ('Cumulative metrics: Precision = ', 0.05875706214689266, ' Recall = ', 0.5909090909090909)
# ('Single metrics: Precision = ', 0.13043478260869565, ' Recall = ', 0.13043478260869565)
# ----------------------------------------------------------------------------------
# ('Label shape', (64,))
# ----------------------------------------------------------------------------------
# ('Epoch ', 0, 'Loss for the current example ', 47919, ' = ', 23.242142, 'pedc = ', 24)
# ('Metrics for current example: TP=', 2.0, ' FP=', 31.0, ' TN=', 31.0, ' FN=', 0.0)
# ('Cumulative metrics: Precision = ', 0.058823529411764705, ' Recall = ', 0.6)
# ('Single metrics: Precision = ', 0.16666666666666666, ' Recall = ', 0.16666666666666666)
# ----------------------------------------------------------------------------------
# ('Label shape', (22,))
# ----------------------------------------------------------------------------------
# ('Epoch ', 0, 'Loss for the current example ', 46459, ' = ', 9.355728, 'pedc = ', 25)
# ('Metrics for current example: TP=', 0.0, ' FP=', 12.0, ' TN=', 9.0, ' FN=', 1.0)
# ('Cumulative metrics: Precision = ', 0.05806451612903226, ' Recall = ', 0.5934065934065934)
# ('Single metrics: Precision = ', 0.16, ' Recall = ', 0.16)
# ----------------------------------------------------------------------------------
# ('Label shape', (44,))
# ----------------------------------------------------------------------------------
# ('Epoch ', 0, 'Loss for the current example ', 60575, ' = ', 18.68369, 'pedc = ', 26)
# ('Metrics for current example: TP=', 0.0, ' FP=', 21.0, ' TN=', 23.0, ' FN=', 0.0)
# ('Cumulative metrics: Precision = ', 0.056782334384858045, ' Recall = ', 0.5934065934065934)
# ('Single metrics: Precision = ', 0.15384615384615385, ' Recall = ', 0.15384615384615385)
# ----------------------------------------------------------------------------------
# ('Label shape', (180,))
# ----------------------------------------------------------------------------------
# ('Epoch ', 0, 'Loss for the current example ', 46731, ' = ', 72.55453, 'pedc = ', 27)
# ('Metrics for current example: TP=', 4.0, ' FP=', 93.0, ' TN=', 83.0, ' FN=', 0.0)
# ('Cumulative metrics: Precision = ', 0.05534351145038168, ' Recall = ', 0.6105263157894737)
# ('Single metrics: Precision = ', 0.14814814814814814, ' Recall = ', 0.14814814814814814)
# ----------------------------------------------------------------------------------
# ('Label shape', (45,))
# ----------------------------------------------------------------------------------
# ('Epoch ', 0, 'Loss for the current example ', 37437, ' = ', 14.50858, 'pedc = ', 28)
# ('Metrics for current example: TP=', 3.0, ' FP=', 16.0, ' TN=', 26.0, ' FN=', 0.0)
# ('Cumulative metrics: Precision = ', 0.05716963448922212, ' Recall = ', 0.6224489795918368)
# ('Single metrics: Precision = ', 0.17857142857142858, ' Recall = ', 0.17857142857142858)
# ----------------------------------------------------------------------------------
# ('Label shape', (46,))
# ----------------------------------------------------------------------------------
# ('Epoch ', 0, 'Loss for the current example ', 11274, ' = ', 17.969852, 'pedc = ', 29)
# ('Metrics for current example: TP=', 2.0, ' FP=', 20.0, ' TN=', 21.0, ' FN=', 3.0)
# ('Cumulative metrics: Precision = ', 0.05785123966942149, ' Recall = ', 0.6116504854368932)
# ('Single metrics: Precision = ', 0.1724137931034483, ' Recall = ', 0.1724137931034483)
# ----------------------------------------------------------------------------------
# ('Label shape', (178,))
# ----------------------------------------------------------------------------------
# ('Epoch ', 0, 'Loss for the current example ', 13505, ' = ', 68.05615, 'pedc = ', 30)
# ('Metrics for current example: TP=', 7.0, ' FP=', 80.0, ' TN=', 91.0, ' FN=', 0.0)
# ('Cumulative metrics: Precision = ', 0.05952380952380952, ' Recall = ', 0.6363636363636364)
# ('Single metrics: Precision = ', 0.16666666666666666, ' Recall = ', 0.16666666666666666)
# ----------------------------------------------------------------------------------
# ('Label shape', (27,))
# ----------------------------------------------------------------------------------
# ('Epoch ', 0, 'Loss for the current example ', 34182, ' = ', 9.930479, 'pedc = ', 31)
# ('Metrics for current example: TP=', 2.0, ' FP=', 14.0, ' TN=', 11.0, ' FN=', 0.0)
# ('Cumulative metrics: Precision = ', 0.06040268456375839, ' Recall = ', 0.6428571428571429)
# ('Single metrics: Precision = ', 0.1935483870967742, ' Recall = ', 0.1935483870967742)
# ----------------------------------------------------------------------------------
# ('Label shape', (76,))
# ----------------------------------------------------------------------------------
# ('Epoch ', 0, 'Loss for the current example ', 21572, ' = ', 30.511673, 'pedc = ', 32)
# ('Metrics for current example: TP=', 2.0, ' FP=', 34.0, ' TN=', 39.0, ' FN=', 1.0)
# ('Cumulative metrics: Precision = ', 0.06026058631921824, ' Recall = ', 0.6434782608695652)
# ('Single metrics: Precision = ', 0.1875, ' Recall = ', 0.1875)
# ----------------------------------------------------------------------------------
# ('Label shape', (14,))
# ----------------------------------------------------------------------------------
# ('Epoch ', 0, 'Loss for the current example ', 56335, ' = ', 3.0177083, 'pedc = ', 33)
# ('Metrics for current example: TP=', 2.0, ' FP=', 4.0, ' TN=', 8.0, ' FN=', 0.0)
# ('Cumulative metrics: Precision = ', 0.06158833063209076, ' Recall = ', 0.6495726495726496)
# ('Single metrics: Precision = ', 0.21212121212121213, ' Recall = ', 0.21212121212121213)
# ----------------------------------------------------------------------------------
# ('Label shape', (39,))
# ----------------------------------------------------------------------------------
# ('Epoch ', 0, 'Loss for the current example ', 15640, ' = ', 14.295899, 'pedc = ', 34)
# ('Metrics for current example: TP=', 3.0, ' FP=', 16.0, ' TN=', 19.0, ' FN=', 1.0)
# ('Cumulative metrics: Precision = ', 0.06304868316041501, ' Recall = ', 0.6528925619834711)
# ('Single metrics: Precision = ', 0.20588235294117646, ' Recall = ', 0.20588235294117646)
# ----------------------------------------------------------------------------------
# ('Label shape', (30,))
# ----------------------------------------------------------------------------------
# ('Epoch ', 0, 'Loss for the current example ', 7667, ' = ', 8.403162, 'pedc = ', 35)
# ('Metrics for current example: TP=', 5.0, ' FP=', 11.0, ' TN=', 14.0, ' FN=', 0.0)
# ('Cumulative metrics: Precision = ', 0.06619385342789598, ' Recall = ', 0.6666666666666666)
# ('Single metrics: Precision = ', 0.22857142857142856, ' Recall = ', 0.22857142857142856)
# ----------------------------------------------------------------------------------
# ('Label shape', (87,))
# ----------------------------------------------------------------------------------
# ('Epoch ', 0, 'Loss for the current example ', 11479, ' = ', 29.084492, 'pedc = ', 36)
# ('Metrics for current example: TP=', 8.0, ' FP=', 37.0, ' TN=', 42.0, ' FN=', 0.0)
# ('Cumulative metrics: Precision = ', 0.0700152207001522, ' Recall = ', 0.6865671641791045)
# ('Single metrics: Precision = ', 0.25, ' Recall = ', 0.25)
# ----------------------------------------------------------------------------------
# ('Label shape', (43,))
# ----------------------------------------------------------------------------------
# ('Epoch ', 0, 'Loss for the current example ', 32878, ' = ', 15.810283, 'pedc = ', 37)
# ('Metrics for current example: TP=', 2.0, ' FP=', 20.0, ' TN=', 21.0, ' FN=', 0.0)
# ('Cumulative metrics: Precision = ', 0.07035928143712575, ' Recall = ', 0.6911764705882353)
# ('Single metrics: Precision = ', 0.2702702702702703, ' Recall = ', 0.2702702702702703)
# ----------------------------------------------------------------------------------
# ('Label shape', (32,))
# ----------------------------------------------------------------------------------
# ('Epoch ', 0, 'Loss for the current example ', 71037, ' = ', 11.956805, 'pedc = ', 38)
# ('Metrics for current example: TP=', 3.0, ' FP=', 10.0, ' TN=', 19.0, ' FN=', 0.0)
# ('Cumulative metrics: Precision = ', 0.07190511489992588, ' Recall = ', 0.697841726618705)
# ('Single metrics: Precision = ', 0.2631578947368421, ' Recall = ', 0.2631578947368421)
# ----------------------------------------------------------------------------------
# ('Label shape', (176,))
# ----------------------------------------------------------------------------------
# ('Epoch ', 0, 'Loss for the current example ', 56431, ' = ', 72.41956, 'pedc = ', 39)
# ('Metrics for current example: TP=', 3.0, ' FP=', 86.0, ' TN=', 84.0, ' FN=', 3.0)
# ('Cumulative metrics: Precision = ', 0.06954102920723226, ' Recall = ', 0.6896551724137931)
# ('Single metrics: Precision = ', 0.2564102564102564, ' Recall = ', 0.2564102564102564)
# ----------------------------------------------------------------------------------
# ('Label shape', (73,))
# ----------------------------------------------------------------------------------
# ('Epoch ', 0, 'Loss for the current example ', 55779, ' = ', 24.620068, 'pedc = ', 40)
# ('Metrics for current example: TP=', 7.0, ' FP=', 36.0, ' TN=', 30.0, ' FN=', 0.0)
# ('Cumulative metrics: Precision = ', 0.07224848075624578, ' Recall = ', 0.7039473684210527)
# ('Single metrics: Precision = ', 0.275, ' Recall = ', 0.275)
# ----------------------------------------------------------------------------------
# ('Label shape', (80,))
# ----------------------------------------------------------------------------------
# ('Epoch ', 0, 'Loss for the current example ', 35206, ' = ', 32.75486, 'pedc = ', 41)
# ('Metrics for current example: TP=', 1.0, ' FP=', 39.0, ' TN=', 40.0, ' FN=', 0.0)
# ('Cumulative metrics: Precision = ', 0.07100591715976332, ' Recall = ', 0.7058823529411765)
# ('Single metrics: Precision = ', 0.2682926829268293, ' Recall = ', 0.2682926829268293)
# ----------------------------------------------------------------------------------
# ('Label shape', (179,))
# ----------------------------------------------------------------------------------
# ('Epoch ', 0, 'Loss for the current example ', 41613, ' = ', 72.60149, 'pedc = ', 42)
# ('Metrics for current example: TP=', 4.0, ' FP=', 92.0, ' TN=', 82.0, ' FN=', 1.0)
# ('Cumulative metrics: Precision = ', 0.06926406926406926, ' Recall = ', 0.7088607594936709)
# ('Single metrics: Precision = ', 0.2619047619047619, ' Recall = ', 0.2619047619047619)
# ----------------------------------------------------------------------------------
# ('Label shape', (58,))
# ----------------------------------------------------------------------------------
# ('Epoch ', 0, 'Loss for the current example ', 22972, ' = ', 21.631596, 'pedc = ', 43)
# ('Metrics for current example: TP=', 3.0, ' FP=', 20.0, ' TN=', 34.0, ' FN=', 1.0)
# ('Cumulative metrics: Precision = ', 0.0701219512195122, ' Recall = ', 0.7098765432098766)
# ('Single metrics: Precision = ', 0.2558139534883721, ' Recall = ', 0.2558139534883721)
# ----------------------------------------------------------------------------------
# ('Label shape', (54,))
# ----------------------------------------------------------------------------------
# ('Epoch ', 0, 'Loss for the current example ', 18373, ' = ', 20.4944, 'pedc = ', 44)
# ('Metrics for current example: TP=', 2.0, ' FP=', 24.0, ' TN=', 28.0, ' FN=', 0.0)
# ('Cumulative metrics: Precision = ', 0.0702280912364946, ' Recall = ', 0.7134146341463414)
# ('Single metrics: Precision = ', 0.25, ' Recall = ', 0.25)
# ----------------------------------------------------------------------------------
# ('Label shape', (42,))
# ----------------------------------------------------------------------------------
# ('Epoch ', 0, 'Loss for the current example ', 28942, ' = ', 15.104714, 'pedc = ', 45)
# ('Metrics for current example: TP=', 4.0, ' FP=', 21.0, ' TN=', 15.0, ' FN=', 2.0)
# ('Cumulative metrics: Precision = ', 0.07155529272619751, ' Recall = ', 0.711764705882353)
# ('Single metrics: Precision = ', 0.24444444444444444, ' Recall = ', 0.24444444444444444)
# ----------------------------------------------------------------------------------
# ('Label shape', (106,))
# ----------------------------------------------------------------------------------
# ('Epoch ', 0, 'Loss for the current example ', 14468, ' = ', 43.527122, 'pedc = ', 46)
# ('Metrics for current example: TP=', 1.0, ' FP=', 50.0, ' TN=', 53.0, ' FN=', 2.0)
# ('Cumulative metrics: Precision = ', 0.07003444316877153, ' Recall = ', 0.7052023121387283)
# ('Single metrics: Precision = ', 0.2391304347826087, ' Recall = ', 0.2391304347826087)
# ----------------------------------------------------------------------------------
# ('Label shape', (160,))
# ----------------------------------------------------------------------------------
# ('Epoch ', 0, 'Loss for the current example ', 24618, ' = ', 67.35226, 'pedc = ', 47)
# ('Metrics for current example: TP=', 0.0, ' FP=', 84.0, ' TN=', 76.0, ' FN=', 0.0)
# ('Cumulative metrics: Precision = ', 0.06681270536692223, ' Recall = ', 0.7052023121387283)
# ('Single metrics: Precision = ', 0.23404255319148937, ' Recall = ', 0.23404255319148937)
# ----------------------------------------------------------------------------------
# ('Label shape', (46,))
# ----------------------------------------------------------------------------------
# ('Epoch ', 0, 'Loss for the current example ', 23943, ' = ', 18.592201, 'pedc = ', 48)
# ('Metrics for current example: TP=', 2.0, ' FP=', 18.0, ' TN=', 23.0, ' FN=', 3.0)
# ('Cumulative metrics: Precision = ', 0.06717226435536294, ' Recall = ', 0.6966292134831461)
# ('Single metrics: Precision = ', 0.22916666666666666, ' Recall = ', 0.22916666666666666)
# ----------------------------------------------------------------------------------
# ('Label shape', (15,))
# ----------------------------------------------------------------------------------
# ('Epoch ', 0, 'Loss for the current example ', 53223, ' = ', 2.946007, 'pedc = ', 49)
# ('Metrics for current example: TP=', 3.0, ' FP=', 2.0, ' TN=', 10.0, ' FN=', 0.0)
# ('Cumulative metrics: Precision = ', 0.06861156131820638, ' Recall = ', 0.7016574585635359)
# ('Single metrics: Precision = ', 0.24489795918367346, ' Recall = ', 0.24489795918367346)
# ----------------------------------------------------------------------------------
# ('Label shape', (23,))
# ----------------------------------------------------------------------------------
# ('Epoch ', 0, 'Loss for the current example ', 66141, ' = ', 4.7473655, 'pedc = ', 50)
# ('Metrics for current example: TP=', 4.0, ' FP=', 4.0, ' TN=', 15.0, ' FN=', 0.0)
# ('Cumulative metrics: Precision = ', 0.07046799354491662, ' Recall = ', 0.7081081081081081)
# ('Single metrics: Precision = ', 0.26, ' Recall = ', 0.26)
# ----------------------------------------------------------------------------------
# ('Label shape', (71,))
# ----------------------------------------------------------------------------------
# ('Epoch ', 0, 'Loss for the current example ', 5204, ' = ', 27.786934, 'pedc = ', 51)
# ('Metrics for current example: TP=', 2.0, ' FP=', 29.0, ' TN=', 40.0, ' FN=', 0.0)
# ('Cumulative metrics: Precision = ', 0.07037037037037037, ' Recall = ', 0.7112299465240641)
# ('Single metrics: Precision = ', 0.2549019607843137, ' Recall = ', 0.2549019607843137)
# ----------------------------------------------------------------------------------
# ('Label shape', (38,))
# ----------------------------------------------------------------------------------
# ('Epoch ', 0, 'Loss for the current example ', 21492, ' = ', 12.641359, 'pedc = ', 52)
# ('Metrics for current example: TP=', 5.0, ' FP=', 15.0, ' TN=', 18.0, ' FN=', 0.0)
# ('Cumulative metrics: Precision = ', 0.07225130890052356, ' Recall = ', 0.71875)
# ('Single metrics: Precision = ', 0.25, ' Recall = ', 0.25)
# ----------------------------------------------------------------------------------
# ('Label shape', (33,))
# ----------------------------------------------------------------------------------
# ('Epoch ', 0, 'Loss for the current example ', 67192, ' = ', 9.901943, 'pedc = ', 53)
# ('Metrics for current example: TP=', 3.0, ' FP=', 12.0, ' TN=', 18.0, ' FN=', 0.0)
# ('Cumulative metrics: Precision = ', 0.07324675324675324, ' Recall = ', 0.7230769230769231)
# ('Single metrics: Precision = ', 0.2641509433962264, ' Recall = ', 0.2641509433962264)
# ----------------------------------------------------------------------------------
# ('Label shape', (58,))
# ----------------------------------------------------------------------------------
# ('Epoch ', 0, 'Loss for the current example ', 6942, ' = ', 21.816492, 'pedc = ', 54)
# ('Metrics for current example: TP=', 2.0, ' FP=', 26.0, ' TN=', 30.0, ' FN=', 0.0)
# ('Cumulative metrics: Precision = ', 0.07322068612391193, ' Recall = ', 0.7258883248730964)
# ('Single metrics: Precision = ', 0.25925925925925924, ' Recall = ', 0.25925925925925924)
# ----------------------------------------------------------------------------------
# ('Label shape', (17,))
# ----------------------------------------------------------------------------------
# ('Epoch ', 0, 'Loss for the current example ', 54089, ' = ', 6.552674, 'pedc = ', 55)
# ('Metrics for current example: TP=', 1.0, ' FP=', 7.0, ' TN=', 9.0, ' FN=', 0.0)
# ('Cumulative metrics: Precision = ', 0.07343192248852626, ' Recall = ', 0.7272727272727273)
# ('Single metrics: Precision = ', 0.2545454545454545, ' Recall = ', 0.2545454545454545)
# ----------------------------------------------------------------------------------
# ('Label shape', (39,))
# ----------------------------------------------------------------------------------
# ('Epoch ', 0, 'Loss for the current example ', 43443, ' = ', 14.845358, 'pedc = ', 56)
# ('Metrics for current example: TP=', 1.0, ' FP=', 19.0, ' TN=', 19.0, ' FN=', 0.0)
# ('Cumulative metrics: Precision = ', 0.07319535588086824, ' Recall = ', 0.7286432160804021)
# ('Single metrics: Precision = ', 0.26785714285714285, ' Recall = ', 0.26785714285714285)
# ----------------------------------------------------------------------------------
# ('Label shape', (24,))
# ----------------------------------------------------------------------------------
# ('Epoch ', 0, 'Loss for the current example ', 53968, ' = ', 6.358068, 'pedc = ', 57)
# ('Metrics for current example: TP=', 3.0, ' FP=', 11.0, ' TN=', 9.0, ' FN=', 1.0)
# ('Cumulative metrics: Precision = ', 0.07418546365914787, ' Recall = ', 0.729064039408867)
# ('Single metrics: Precision = ', 0.2807017543859649, ' Recall = ', 0.2807017543859649)
# ----------------------------------------------------------------------------------
# ('Label shape', (53,))
# ----------------------------------------------------------------------------------
# ('Epoch ', 0, 'Loss for the current example ', 52112, ' = ', 21.934809, 'pedc = ', 58)
# ('Metrics for current example: TP=', 1.0, ' FP=', 22.0, ' TN=', 30.0, ' FN=', 0.0)
# ('Cumulative metrics: Precision = ', 0.07383548067393458, ' Recall = ', 0.7303921568627451)
# ('Single metrics: Precision = ', 0.27586206896551724, ' Recall = ', 0.27586206896551724)
# ----------------------------------------------------------------------------------
# ('Label shape', (46,))
# ----------------------------------------------------------------------------------
# ('Epoch ', 0, 'Loss for the current example ', 933, ' = ', 17.084124, 'pedc = ', 59)
# ('Metrics for current example: TP=', 2.0, ' FP=', 21.0, ' TN=', 23.0, ' FN=', 0.0)
# ('Cumulative metrics: Precision = ', 0.07398334149926507, ' Recall = ', 0.7330097087378641)
# ('Single metrics: Precision = ', 0.2711864406779661, ' Recall = ', 0.2711864406779661)
# ----------------------------------------------------------------------------------
# ('Label shape', (133,))
# ----------------------------------------------------------------------------------
# ('Epoch ', 0, 'Loss for the current example ', 12874, ' = ', 55.123463, 'pedc = ', 60)
# ('Metrics for current example: TP=', 1.0, ' FP=', 72.0, ' TN=', 59.0, ' FN=', 1.0)
# ('Cumulative metrics: Precision = ', 0.07190160832544938, ' Recall = ', 0.7307692307692307)
# ('Single metrics: Precision = ', 0.26666666666666666, ' Recall = ', 0.26666666666666666)
# ----------------------------------------------------------------------------------
# ('Label shape', (14,))
# ----------------------------------------------------------------------------------
# ('Epoch ', 0, 'Loss for the current example ', 59208, ' = ', 5.3629293, 'pedc = ', 61)
# ('Metrics for current example: TP=', 2.0, ' FP=', 5.0, ' TN=', 4.0, ' FN=', 3.0)
# ('Cumulative metrics: Precision = ', 0.07260726072607261, ' Recall = ', 0.7230046948356808)
# ('Single metrics: Precision = ', 0.26229508196721313, ' Recall = ', 0.26229508196721313)
# ----------------------------------------------------------------------------------
# ('Label shape', (56,))
# ----------------------------------------------------------------------------------
# ('Epoch ', 0, 'Loss for the current example ', 33356, ' = ', 22.244808, 'pedc = ', 62)
# ('Metrics for current example: TP=', 2.0, ' FP=', 24.0, ' TN=', 30.0, ' FN=', 0.0)
# ('Cumulative metrics: Precision = ', 0.07265952491849091, ' Recall = ', 0.7255813953488373)
# ('Single metrics: Precision = ', 0.25806451612903225, ' Recall = ', 0.25806451612903225)
# ----------------------------------------------------------------------------------
# ('Label shape', (67,))
# ----------------------------------------------------------------------------------
# ('Epoch ', 0, 'Loss for the current example ', 67487, ' = ', 27.412064, 'pedc = ', 63)
# ('Metrics for current example: TP=', 1.0, ' FP=', 31.0, ' TN=', 34.0, ' FN=', 1.0)
# ('Cumulative metrics: Precision = ', 0.07205139972464433, ' Recall = ', 0.7235023041474654)
# ('Single metrics: Precision = ', 0.25396825396825395, ' Recall = ', 0.25396825396825395)
# ----------------------------------------------------------------------------------
# ('Label shape', (92,))
# ----------------------------------------------------------------------------------
# ('Epoch ', 0, 'Loss for the current example ', 37688, ' = ', 36.59786, 'pedc = ', 64)
# ('Metrics for current example: TP=', 2.0, ' FP=', 47.0, ' TN=', 43.0, ' FN=', 0.0)
# ('Cumulative metrics: Precision = ', 0.07136445242369839, ' Recall = ', 0.726027397260274)
# ('Single metrics: Precision = ', 0.25, ' Recall = ', 0.25)
# ----------------------------------------------------------------------------------
# ('Label shape', (42,))
# ----------------------------------------------------------------------------------
# ('Epoch ', 0, 'Loss for the current example ', 19503, ' = ', 16.29768, 'pedc = ', 65)
# ('Metrics for current example: TP=', 1.0, ' FP=', 21.0, ' TN=', 20.0, ' FN=', 0.0)
# ('Cumulative metrics: Precision = ', 0.07111111111111111, ' Recall = ', 0.7272727272727273)
# ('Single metrics: Precision = ', 0.24615384615384617, ' Recall = ', 0.24615384615384617)
# ----------------------------------------------------------------------------------
# ('Label shape', (62,))
# ----------------------------------------------------------------------------------
# ('Epoch ', 0, 'Loss for the current example ', 14111, ' = ', 20.179934, 'pedc = ', 66)
# ('Metrics for current example: TP=', 6.0, ' FP=', 21.0, ' TN=', 35.0, ' FN=', 0.0)
# ('Cumulative metrics: Precision = ', 0.07290294246815986, ' Recall = ', 0.7345132743362832)
# ('Single metrics: Precision = ', 0.24242424242424243, ' Recall = ', 0.24242424242424243)
# ----------------------------------------------------------------------------------
# ('Label shape', (55,))
# ----------------------------------------------------------------------------------
# ('Epoch ', 0, 'Loss for the current example ', 15043, ' = ', 20.460588, 'pedc = ', 67)
# ('Metrics for current example: TP=', 2.0, ' FP=', 22.0, ' TN=', 31.0, ' FN=', 0.0)
# ('Cumulative metrics: Precision = ', 0.07301173402868318, ' Recall = ', 0.7368421052631579)
# ('Single metrics: Precision = ', 0.23880597014925373, ' Recall = ', 0.23880597014925373)
# ----------------------------------------------------------------------------------
# ('Label shape', (21,))
# ----------------------------------------------------------------------------------
# ('Epoch ', 0, 'Loss for the current example ', 49613, ' = ', 6.114541, 'pedc = ', 68)
# ('Metrics for current example: TP=', 3.0, ' FP=', 8.0, ' TN=', 10.0, ' FN=', 0.0)
# ('Cumulative metrics: Precision = ', 0.07396193771626297, ' Recall = ', 0.7402597402597403)
# ('Single metrics: Precision = ', 0.25, ' Recall = ', 0.25)
# ----------------------------------------------------------------------------------
# ('Label shape', (38,))
# ----------------------------------------------------------------------------------
# ('Epoch ', 0, 'Loss for the current example ', 70023, ' = ', 10.717126, 'pedc = ', 69)
# ('Metrics for current example: TP=', 5.0, ' FP=', 12.0, ' TN=', 21.0, ' FN=', 0.0)
# ('Cumulative metrics: Precision = ', 0.07556891369686561, ' Recall = ', 0.7457627118644068)
# ('Single metrics: Precision = ', 0.2608695652173913, ' Recall = ', 0.2608695652173913)
# ----------------------------------------------------------------------------------
# ('Label shape', (165,))
# ----------------------------------------------------------------------------------
# ('Epoch ', 0, 'Loss for the current example ', 24595, ' = ', 68.32185, 'pedc = ', 70)
# ('Metrics for current example: TP=', 2.0, ' FP=', 78.0, ' TN=', 85.0, ' FN=', 0.0)
# ('Cumulative metrics: Precision = ', 0.0738895807388958, ' Recall = ', 0.7478991596638656)
# ('Single metrics: Precision = ', 0.2571428571428571, ' Recall = ', 0.2571428571428571)
# ----------------------------------------------------------------------------------
# ('Label shape', (37,))
# ----------------------------------------------------------------------------------
# ('Epoch ', 0, 'Loss for the current example ', 17475, ' = ', 10.844658, 'pedc = ', 71)
# ('Metrics for current example: TP=', 4.0, ' FP=', 12.0, ' TN=', 21.0, ' FN=', 0.0)
# ('Cumulative metrics: Precision = ', 0.07505154639175257, ' Recall = ', 0.7520661157024794)
# ('Single metrics: Precision = ', 0.2676056338028169, ' Recall = ', 0.2676056338028169)
# ----------------------------------------------------------------------------------
# ('Label shape', (136,))
# ----------------------------------------------------------------------------------
# ('Epoch ', 0, 'Loss for the current example ', 33684, ' = ', 49.933212, 'pedc = ', 72)
# ('Metrics for current example: TP=', 8.0, ' FP=', 64.0, ' TN=', 64.0, ' FN=', 0.0)
# ('Cumulative metrics: Precision = ', 0.07609130957148579, ' Recall = ', 0.76)
# ('Single metrics: Precision = ', 0.2638888888888889, ' Recall = ', 0.2638888888888889)
# ----------------------------------------------------------------------------------
# ('Label shape', (188,))
# ----------------------------------------------------------------------------------
# ('Epoch ', 0, 'Loss for the current example ', 56433, ' = ', 76.212456, 'pedc = ', 73)
# ('Metrics for current example: TP=', 5.0, ' FP=', 98.0, ' TN=', 84.0, ' FN=', 1.0)
# ('Cumulative metrics: Precision = ', 0.075, ' Recall = ', 0.76171875)
# ('Single metrics: Precision = ', 0.2602739726027397, ' Recall = ', 0.2602739726027397)
# ----------------------------------------------------------------------------------
# ('Label shape', (78,))
# ----------------------------------------------------------------------------------
# ('Epoch ', 0, 'Loss for the current example ', 64650, ' = ', 30.02274, 'pedc = ', 74)
# ('Metrics for current example: TP=', 2.0, ' FP=', 40.0, ' TN=', 36.0, ' FN=', 0.0)
# ('Cumulative metrics: Precision = ', 0.07456472369417108, ' Recall = ', 0.7635658914728682)
# ('Single metrics: Precision = ', 0.2702702702702703, ' Recall = ', 0.2702702702702703)
# ----------------------------------------------------------------------------------
# ('Label shape', (79,))
# ----------------------------------------------------------------------------------
# ('Epoch ', 0, 'Loss for the current example ', 15627, ' = ', 29.307585, 'pedc = ', 75)
# ('Metrics for current example: TP=', 2.0, ' FP=', 39.0, ' TN=', 38.0, ' FN=', 0.0)
# ('Cumulative metrics: Precision = ', 0.07417070443533358, ' Recall = ', 0.7653846153846153)
# ('Single metrics: Precision = ', 0.26666666666666666, ' Recall = ', 0.26666666666666666)
# ----------------------------------------------------------------------------------
# ('Label shape', (17,))
# ----------------------------------------------------------------------------------
# ('Epoch ', 0, 'Loss for the current example ', 67522, ' = ', 6.4603486, 'pedc = ', 76)
# ('Metrics for current example: TP=', 1.0, ' FP=', 8.0, ' TN=', 8.0, ' FN=', 0.0)
# ('Cumulative metrics: Precision = ', 0.07429420505200594, ' Recall = ', 0.7662835249042146)
# ('Single metrics: Precision = ', 0.2631578947368421, ' Recall = ', 0.2631578947368421)
# ----------------------------------------------------------------------------------
# ('Label shape', (134,))
# ----------------------------------------------------------------------------------
# ('Epoch ', 0, 'Loss for the current example ', 33847, ' = ', 50.550896, 'pedc = ', 77)
# ('Metrics for current example: TP=', 4.0, ' FP=', 64.0, ' TN=', 66.0, ' FN=', 0.0)
# ('Cumulative metrics: Precision = ', 0.07391304347826087, ' Recall = ', 0.769811320754717)
# ('Single metrics: Precision = ', 0.2597402597402597, ' Recall = ', 0.2597402597402597)
# ----------------------------------------------------------------------------------
# ('Label shape', (28,))
# ----------------------------------------------------------------------------------
# ('Epoch ', 0, 'Loss for the current example ', 60749, ' = ', 6.682054, 'pedc = ', 78)
# ('Metrics for current example: TP=', 5.0, ' FP=', 10.0, ' TN=', 13.0, ' FN=', 0.0)
# ('Cumulative metrics: Precision = ', 0.07531531531531531, ' Recall = ', 0.774074074074074)
# ('Single metrics: Precision = ', 0.2692307692307692, ' Recall = ', 0.2692307692307692)
# ----------------------------------------------------------------------------------
# ('Label shape', (9,))
# ----------------------------------------------------------------------------------
# ('Epoch ', 0, 'Loss for the current example ', 41386, ' = ', 3.7848086, 'pedc = ', 79)
# ('Metrics for current example: TP=', 0.0, ' FP=', 3.0, ' TN=', 3.0, ' FN=', 3.0)
# ('Cumulative metrics: Precision = ', 0.07523398128149748, ' Recall = ', 0.7655677655677655)
# ('Single metrics: Precision = ', 0.26582278481012656, ' Recall = ', 0.26582278481012656)
# ----------------------------------------------------------------------------------
# ('Label shape', (28,))
# ----------------------------------------------------------------------------------
# ('Epoch ', 0, 'Loss for the current example ', 64324, ' = ', 11.8884735, 'pedc = ', 80)
# ('Metrics for current example: TP=', 0.0, ' FP=', 12.0, ' TN=', 15.0, ' FN=', 1.0)
# ('Cumulative metrics: Precision = ', 0.07491039426523298, ' Recall = ', 0.7627737226277372)
# ('Single metrics: Precision = ', 0.2625, ' Recall = ', 0.2625)
# ----------------------------------------------------------------------------------
# ('Label shape', (99,))
# ----------------------------------------------------------------------------------
# ('Epoch ', 0, 'Loss for the current example ', 49683, ' = ', 39.14681, 'pedc = ', 81)
# ('Metrics for current example: TP=', 3.0, ' FP=', 49.0, ' TN=', 47.0, ' FN=', 0.0)
# ('Cumulative metrics: Precision = ', 0.07459535538353272, ' Recall = ', 0.7653429602888087)
# ('Single metrics: Precision = ', 0.25925925925925924, ' Recall = ', 0.25925925925925924)
# ----------------------------------------------------------------------------------
# ('Label shape', (46,))
# ----------------------------------------------------------------------------------
# ('Epoch ', 0, 'Loss for the current example ', 64286, ' = ', 16.26613, 'pedc = ', 82)
# ('Metrics for current example: TP=', 3.0, ' FP=', 15.0, ' TN=', 28.0, ' FN=', 0.0)
# ('Cumulative metrics: Precision = ', 0.07517482517482517, ' Recall = ', 0.7678571428571429)
# ('Single metrics: Precision = ', 0.2682926829268293, ' Recall = ', 0.2682926829268293)
# ----------------------------------------------------------------------------------
# ('Label shape', (191,))

# %%
len(VAL_DATASET)
# Out:
# 15589

# %%
np.sum(np.array(IOU_list[:][2])>0.5)
# Out:
# 1

# %%
np.sum((np.array(IOU_list)[:,0])>=0.1)
# Out:
# 1699

# %%
print('&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&')
    k = 0
    Vtotal_tp=0
    Vtotal_fp=0
    Vtotal_tn=0
    Vtotal_fn=0
    Vtotal_tpnums = 0
    Vtotal_fpnums = 0
    Vtotal_fnnums = 0
    c = 0
    c1 = 0
    c2 = 0
    c3 = 0
    while k<len(VAL_DATASET):
        #todo reformat code to have lists instead of many variable

            if VAL_DATASET.type_list[k]=='Pedestrian':

                point_set,labels,a,b,c,d,e,f,cls = VAL_DATASET.__getitem__(k)

                index = np.argsort(point_set[:,2])
                point_set = point_set[index]
                labels = labels[index]

                
                corners_gt = VAL_DATASET.get_center_view_box3d(k)
                
                #print(point_set.shape)

                s5,e5,l = indices(0.85,0.1,point_set,labels, corners_gt)
                
                #l1 = l1>0.5

#                 s1, e1, l1 = indices(k, 1.1, 0.2, 'val')

#                 s2, e2, l2 = indices(k, 1.3, 0.2, 'val')

#                 s3, e3, l3 = indices(k, 0.7, 0.1, 'val')

#                 s4, e4, l4 = indices(k, 0.5, 0.1, 'val')

                if s5.size :#and s2.size and s3.size and s4.size and s1.size:

                    ind_5 = get_list(s5,e5, num_points=512)

#                     ind_1 = get_list(s1,e1, num_points=512)

#                     ind_2 = get_list(s2,e2, num_points=512)

#                     ind_3 = get_list(s3,e3, num_points=512)

#                     ind_4 = get_list(s4,e4, num_points=512)

#                     t_windows=s1.shape[0]+s2.shape[0]+s3.shape[0]+s4.shape[0]+s5.shape[0]

                    point_set = np.expand_dims(point_set, axis=0)
                    print(Vtotal_tp)
                    x,tpos,fpos,tneg,fneg, tp_nums, maxind =sess.run([loss,tp,fp,tn,fn, tp_num, maxi],feed_dict={idx_5:ind_5, \
                                                               label_out_5: l1.astype(np.int32), inputs:point_set, is_training: True})


                    #window_points = ind_5[maxind]

                    window_points = point_set[0,ind_5[maxind].reshape((-1))][:,:3]
                    min_x, min_y, min_z = np.min(window_points,axis=0)
                    max_x, max_y, max_z = np.max(window_points,axis=0)
                    corners = [[min_x,max_y,max_z],[min_x,max_y,min_z],[max_x,max_y,min_z],[max_x,max_y,max_z],\
                               [min_x,min_y,max_z],[min_x,min_y,min_z],[max_x,min_y,min_z],[max_x,min_y,max_z]]
                    corners=np.array(corners)
                    corners_gt = VAL_DATASET.get_center_view_box3d(k)
                    IOU, IOU_2D, inter, inter_vol = box_util.box3d_iou(corners, corners_gt)
                    print('IOUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUUU')
                    print(IOU, IOU_2D, inter, inter_vol)
                    IOU_list.append([IOU, IOU_2D, inter, inter_vol, k])
                    if inter>0.4:
                        c += 1
                        if inter>0.5:
                            c1 += 1
                    if inter_vol>0.4:
                        c2 += 1
                        if inter_vol>0.5:
                            c3 +=1 

                    print(Vtotal_tp)
                    Vtotal_tp +=tpos
                    Vtotal_fp +=fpos
                    Vtotal_tn +=tneg
                    Vtotal_fn +=fneg
                    Vtotal_tpnums+= tp_nums
                    Vtotal_fpnums+= (1-tp_nums)
                    Vtotal_fnnums+= (1-tp_nums)
                    print('&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&')
                    print('Epoch ', j , 'Loss for the current example ',k,' = ', x)
                    #logging.info('Loss for the current example ',i,' = ', x)
                    print('Metrics for current example: TP=',tpos,' FP=',fpos,' TN=',tneg,' FN=',fneg)
                    #logging.info('Metrics for current example: TP=',tpos,' FP=',fpos,' TN=',tneg,' FN=',fneg)  # will not print anything
                    #print('Cumulative metrics: TP=',total_tp,' FP=',total_fp,' TN=',total_tn,' FN=',total_fn)
                    print('Cumulative metrics: Precision = ',(Vtotal_tp*1.0)/(Vtotal_tp+Vtotal_fp),\
                          ' Recall = ',(Vtotal_tp*1.0)/(Vtotal_tp+Vtotal_fn))

                    print('Single metrics: Precision = ',(Vtotal_tpnums*1.0)/(Vtotal_tpnums+Vtotal_fpnums),\
                          ' Recall = ',(Vtotal_tpnums*1.0)/(Vtotal_tpnums+Vtotal_fnnums))
                    #logging.info('Cumulative metrics: Precision = ',(Vtotal_tp*1.0)/(Vtotal_tp+Vtotal_fp),\
                    #      ' Recall = ',(Vtotal_tp*1.0)/(Vtotal_tp+Vtotal_fn))
                    print('&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&')

            k += 1
